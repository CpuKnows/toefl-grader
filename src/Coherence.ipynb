# %% [markdown]
# # Annotation Template

# %%
import json
import re
import pandas as pd
import nltk
import numpy as np

from nltk.tree import Tree
# This uses corenlp server! Will need to alter code if using JAR files directly
# https://stanfordnlp.github.io/CoreNLP/corenlp-server.html
from nltk.parse.corenlp import CoreNLPParser
from nltk.tag.stanford import CoreNLPTagger, CoreNLPPOSTagger, CoreNLPNERTagger

# For spelling checker
from enchant import Dict as dictionary
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Careful! CoreNLPTagger, CoreNLPPOSTagger, and CoreNLPNERTagger will all be replaced in the next NLTK version (3.2.6)
parser = CoreNLPParser(url='http://localhost:9000')
#pos_tagger = CoreNLPPOSTagger(url='http://localhost:9000')
#ner_tagger = CoreNLPNERTagger(url='http://localhost:9000')
pos_tagger = CoreNLPTagger(tagtype='pos', url='http://localhost:9000')
ner_tagger = CoreNLPTagger(tagtype='ner', url='http://localhost:9000')

# %%
# Get essays
essay_key = pd.read_csv('../data/essays_dataset/index.csv', sep=';')

essays = []
for filename in essay_key['filename']:
    with open('../data/essays_dataset/essays/'+filename, 'r') as f:
        essays.append(f.read().strip())
        
essay_key['essay'] = essays

# %%
essay_split = pd.read_csv('../data/essays_dataset/essay_split.csv')
essay_split.head()
# Out:
#       filename grade  word_len grader
# 0   990384.txt  high       568   Aldo
# 1   395987.txt  high       508   John
# 2  1949465.txt  high       458   Aldo
# 3    38209.txt  high       456   John
# 4  1834502.txt  high       454   Aldo

# %%
# Altered behavior of NLTK so CoreNLP performs sentence splits
def constituency_parse(parser, sentences, return_parse_obj=False):
    """Creates parse strings for each sentence.  
    Each parse string can be fed into Tree.fromstring() to create NLTK Tree objects.

    parser (CoreNLPParser): parser to parse sentences
    sentences (str): essay text
    return_parse_obj (bool): return parse object or string of trees
    RETURNS (list): a list of parses in string form
    """
    default_properties = {'outputFormat': 'json', 
                          'annotators': 'tokenize,pos,lemma,ssplit,parse'}
    parsed_data = parser.api_call(sentences, properties=default_properties)
    if return_parse_obj:
        return parsed_data
    else:
        parses = list()
        for parsed_sent in parsed_data['sentences']:
            parse = parsed_sent['parse']
            # Compress whitespace
            parse = re.sub('[\s]+', ' ', parse)
            parses.append(parse)
        return parses

def pos_tags(tagger, sentences, return_parse_obj=False):
    """Tags sentences with POS tags. Returns a list of (word, tag, start index, end index) tuples

    tagger (CoreNLPTagger): a tagger to tag sentences
    RETURNS (list): list of (word, tag) tuples
    """
    #tokenize, ssplit, pos, lemma, ner, parse, dcoref
    default_properties = {'annotators': 'tokenize,ssplit,pos,ner'}
    tagged_data = tagger.api_call(sentences, properties=default_properties)
    if return_parse_obj:
        return tagged_data
    else:
        tags = list()
        sent_index = 0
        for sent in tagged_data['sentences']:
            tags.append([(token['word'], token['pos'], token['characterOffsetBegin'], token['characterOffsetEnd'], token['index'], sent_index, token['ner']) for token in sent['tokens']])
            sent_index = sent_index + 1
        return tags

# %%
def tree_to_str(trees):
    """Joins a list of trees in string form"""
    return ' '.join(trees)

def str_to_trees(tree_str):
    """Splits a string into a list of trees in string form"""
    d = "(ROOT"
    return  [(d+sent).strip() for sent in tree_str.split(d) if sent]

# %%
def num_sentence_annotation(parsed_data, orig_text, verbose=True):
    sentences = dict()
    sentences['indices'] = list()
    
    if verbose:
        print('Format: (Start index, end index) Sentence')
        print()
        
    for sent in parsed_data['sentences']:
        start_offset = sent['tokens'][0]['characterOffsetBegin']
        end_offset = sent['tokens'][-1]['characterOffsetEnd']
        sentences['indices'].append((start_offset, end_offset))
        if verbose:
            print((start_offset, end_offset), orig_text[start_offset:end_offset])
            print()
        
    sentences['num'] = len(parsed_data['sentences'])
    if verbose:
        print('Num sentence:', len(parsed_data['sentences']))
        print()
    return sentences

# %%
def length_annotation(parsed_data, orig_text, verbose=True):
    sentences = dict()
    sentences['indices'] = list()
    sentences['constituents'] = list()
    words = nltk.word_tokenize(orig_text)
    nonPunct = re.compile('.*[A-Za-z0-9].*')  # must contain a letter or digit
    sentences['words'] = len([w for w in words if nonPunct.match(w)])
    
    if verbose:
        print('Format: (Start index, end index) Sentence')
        print()
        
    for sent in parsed_data['sentences']:
        start_offset = sent['tokens'][0]['characterOffsetBegin']
        end_offset = sent['tokens'][-1]['characterOffsetEnd']
        sentences['indices'].append((start_offset, end_offset))
        
        # Get the height of the parsed tree 
        t = Tree.fromstring(sent['parse'])
        sentences['constituents'].append(t.height())
        if verbose:
            print((start_offset, end_offset), orig_text[start_offset:end_offset])
            print()
        
    sentences['num_sentences'] = len(parsed_data['sentences'])
    sentences['num_constituents'] = sum(sentences['constituents'])
    if verbose:
        print('Num sentence:', len(parsed_data['sentences']))
        print()
    return sentences

# %%
def sentence_sanity_check(sentence_dict):
    error = False
    
    if sentence_dict['num'] != len(sentence_dict['indices']):
        print('Number of sentences does not match')
        error = True
        
    prev = 0
    for i,j in enumerate(sentence_dict['indices']):
        if j[0] >= j[1]:
            print('Sentence', i, ': Start/end indices overlap')
            error = True
        if prev >= j[0] and prev != 0:
            print('Sentence', i, ': Previous end index overlaps start index')
            error = True
        if j[0] - prev > 1:
            print('Sentence', i, ': Is gap between sentences > 1 character/space?')
            error = True
        prev = j[1]
    
    if not error:
        print('No errors')

# %%
def find_word(orig_text, word):
    matches = list()
    for m in re.finditer(word, orig_text, flags=re.I):
        #print(m)
        if m.span(0)[0] < 10:
            before_context = (' ' * (10-m.span(0)[0])) + orig_text[0:m.span(0)[0]]
        else:
            before_context = orig_text[m.span(0)[0]-10 : m.span(0)[0]]
        
        if len(orig_text) - m.span(0)[1] < 10:
            #print(orig_text[m.span(0)[1]:])
            #print(' ' * (len(orig_text) - m.span(0)[1]))
            after_context = orig_text[m.span(0)[1]:] + (' ' * (len(orig_text) - m.span(0)[1]))
        else:
            after_context = orig_text[m.span(0)[1] : m.span(0)[1]+10]
            
        matches.append((m.span(0), '...' + before_context + orig_text[m.span(0)[0]:m.span(0)[1]] + after_context + '...'))
        
    if len(matches) == 1:
        return matches[0][0]
    else:
        for i,m in enumerate(matches):
            print('Index:', i, '-', m)
        return [m[0] for m in matches]   
        #choice = int(input('Choose a match index (number) or -1 for all: '))
        #if choice == -1:
        #    return [m[0] for m in matches]
        #else:
        #    return matches[choice][0]

# %%
def check_spelling(dictionary, parsed_sentences, orig_text,verbose=True):
    false_positives = ['-LRB-','-RRB-',"''",',','\'s','\\','n\'t',':'';','!','?','\'m','\'d','\'\'','??','-','(',')','\'ve','\'','\'re','!','e.g.','[',']','_','>>','>','<','<<','!!','"','``']
    """Check the spelling of tagged words on an essay
    and return the list of misspelling words with their tags 
    and indexes of begining and end of those words"""
    wrong_words = dict()
    wrong_words['indices'] = list()
    
    if verbose:
        print('Format: (Start index, end index) word')
        print()
    
    found_words = list()
    for sentence in parsed_sentences:
        for w_tuple in sentence:
            word = w_tuple[0]
            if (word not in string.punctuation and word not in false_positives):
                if dicc.check(word) is False:
                    tag = w_tuple[1]
                    start_offset = w_tuple[2]
                    end_offset = w_tuple[3]
                    if word not in found_words:
                        wrong_words['indices'].append((word, tag, start_offset, end_offset))
                        found_words.append(word)
                    if verbose:
                        print((start_offset, end_offset), orig_text[start_offset:end_offset])
                        print()
    wrong_words['num'] = len(wrong_words['indices'])
    if verbose:
        print('Num wrong words:', len(wrong_words['indices']))
        print()
    return wrong_words

# %% [markdown]
# # Choose file

# %%
orig_filename = essay_key.loc[0,'filename']
orig_text = essay_key.loc[0,'essay']

# %% [markdown]
# <h3>Coherence</h3>

# %%
from nltk.corpus import wordnet as wn

# %%
# return (True, 'Female') if the word is a person and female, return (True, 'Male') if the word is male and (True,'Netrual') if 
# undeterminable and (False, None) if it is not a person
def person_and_gender(word_tags):
    #print("Looking for this word: ", word)
    if word_tags[6] == 'PERSON' or word_tags[0].lower()=='person':
        result = (True, None)
    else:
        check_for_nouns = wn.synsets(word_tags[0], pos='n')
        if len(check_for_nouns) > 0:
            s_word = wn.synset(check_for_nouns[0].name())
            hyper = lambda s: s.hypernyms()
            list_hyper = s_word.closure(hyper)
            assigned_tags = [x.name().split(".")[0] for x in list_hyper]
            human_tags = set(['professional','person','adult']) # this is hardcoded now
            actual_tags = set(assigned_tags)
            tag_matches = human_tags.intersection(actual_tags)
            if bool(tag_matches):
                result = (True, None)
            else:
                result =  (False, None)
        else:
            result = (False, None)
    return result

# %%
person_and_gender(('table', 'NN', 353, 358, 4, 4, 'O'))
# Out:
# (False, None)

# %%
# Return an list with sentences beginning and ending indexes
def get_sentence_indexes(constituents_parses):
    sentences_information = list()
    index = 0
    for sent in constituents_parses['sentences']:
        tokens = sent['tokens']
        sentences_information.append((index, tokens[0]['characterOffsetBegin'],tokens[len(tokens)-1]['characterOffsetEnd']))#(index,tokens[0]['characterOffsetBegin'], [len(tokens)-1]['characterOffsetEnd']))
        index = index+1
    return sentences_information

# %%
index_with_parse = pd.read_csv('../data/index_with_parse.csv')
index_with_parse
#pronouns = pd.DataFrame()
#for index, values in enumerate(index_with_parse.values):
#    print(values[2])
# Out:
#        filename  num_sentences  \
# 0   1004355.txt             14
# 1   1007363.txt             10
# 2   1079196.txt             17
# 3   1086343.txt             10
# 4   1096747.txt              6
# 5   1109085.txt             16
# 6   1164913.txt             14
# 7   1174920.txt              5
# 8   1181356.txt             11
# 9   1223368.txt             17
# 10  1239289.txt             11
# 11  1249928.txt             15
# 12  1321982.txt              2
# 13  1346734.txt              7
# 14  1365003.txt             19
# 15  1388870.txt             13
# 16  1392946.txt             20
# 17  1394540.txt              8
# 18  1414676.txt             23
# 19  1431839.txt             24
# 20  1447041.txt             10
# 21  1449555.txt             25
# 22  1453563.txt             16
# 23  1469088.txt              7
# 24  1599482.txt             16
# 25  1604419.txt              3
# 26   162639.txt             20
# 27  1648484.txt              5
# 28  1691426.txt             16
# 29  1693042.txt             21
# ..          ...            ...
# 70   496928.txt             12
# 71   526827.txt              6
# 72    52951.txt             18
# 73   535573.txt             20
# 74   562823.txt              8
# 75   586583.txt              7
# 76   589458.txt              6
# 77   594970.txt             19
# 78   599905.txt             21
# 79   609558.txt             22
# 80   618384.txt             16
# 81   643139.txt             14
# 82   644250.txt              7
# 83   656695.txt             16
# 84   661830.txt             12
# 85    67346.txt             23
# 86   711394.txt             20
# 87    71654.txt             25
# 88   716766.txt             17
# 89   746257.txt              9
# 90   749940.txt              5
# 91   755753.txt             21
# 92   757891.txt             23
# 93   806909.txt             22
# 94   832751.txt             16
# 95   844996.txt             18
# 96   871631.txt              9
# 97   913996.txt             17
# 98   937403.txt             19
# 99   990384.txt             25
#
#                                          parsed_essay
# 0   (ROOT (S (NP (DT This)) (VP (VBZ is) (NP (NP (...
# 1   (ROOT (S (NP (NP (DT A) (JJ geat) (NN challeng...
# 2   (ROOT (S (ADVP (RB Personally)) (, ,) (NP (PRP...
# 3   (ROOT (S (PP (IN In) (NP (JJ many) (NN country...
# 4   (ROOT (S (NP (PRP I)) (VP (VBP disagree) (PP (...
# 5   (ROOT (S (NP (NNS People)) (ADVP (RB often)) (...
# 6   (ROOT (S (S (NP (NP (DT Some) (NNS tipes)) (PP...
# 7   (ROOT (S (SBAR (IN In) (S (NP (PRP$ my) (NN op...
# 8   (ROOT (S (S (NP (PRP We)) (VP (VBP grow) (PRT ...
# 9   (ROOT (S (NP (NNS Universities)) (VP (VBP have...
# 10  (ROOT (S (NP (PRP It)) (VP (VBZ is) (VP (VBN b...
# 11  (ROOT (S (S (PP (IN In) (NP (PRP$ my) (NN open...
# 12  (ROOT (PP (IN Of) (NP (NP (NN curse)) (SBAR (S...
# 13  (ROOT (S (S (NP (NNP Nowdays) (NNS people)) (V...
# 14  (ROOT (S (NP (PRP I)) (VP (VBP concede) (SBAR ...
# 15  (ROOT (S (NP (DT Some) (NNS people)) (VP (VBP ...
# 16  (ROOT (FRAG (ADVP (RB Nowadays)) (NP (NP (DT a...
# 17  (ROOT (S (PP (IN In) (NP (DT the) (JJ last) (C...
# 18  (ROOT (S (PP (IN In) (NP (PRP$ my) (NN opinion...
# 19  (ROOT (S (NP (PRP I)) (ADVP (RB completely)) (...
# 20  (ROOT (S (NP (PRP I)) (VP (VBP 'm) (ADVP (RB f...
# 21  (ROOT (S (NP (NP (DT The) (NN issue)) (PP (IN ...
# 22  (ROOT (S (PP (IN In) (NP (NP (DT a) (NNS stude...
# 23  (ROOT (S (NP (DT Some) (NNS people)) (VP (VBZ ...
# 24  (ROOT (FRAG (S (VP (TO To) (VP (VB answer) (NP...
# 25  (ROOT (S (NP (NP (NP (DT all)) (PP (IN of) (NP...
# 26  (ROOT (S (PP (IN In) (NP (PRP$ my) (JJ persona...
# 27  (ROOT (S (NP (JJS Most) (NNS advertisements)) ...
# 28  (ROOT (S (SBAR (WHADVP (WRB when)) (S (NP (PRP...
# 29  (ROOT (S (NP (JJ Young) (NNS people)) (VP (VBP...
# ..                                                ...
# 70  (ROOT (S (NP (PRP I)) (VP (VBP 'm) (VP (VBP ag...
# 71  (ROOT (S (NP (PRP I)) (VP (VBP think) (SBAR (S...
# 72  (ROOT (S (PP (IN With) (NP (NP (DT the) (JJ di...
# 73  (ROOT (S (NP (DT Some) (NNS people)) (VP (MD m...
# 74  (ROOT (S (NP (NNPS Products)) (VP (VBP seem) (...
# 75  (ROOT (S (NP (PRP It)) (VP (VBZ is) (ADJP (JJ ...
# 76  (ROOT (S (NP (NN Advertising)) (VP (VBZ seems)...
# 77  (ROOT (S (PP (IN In) (NP (JJ general))) (NP (P...
# 78  (ROOT (S (NP (PRP I)) (VP (VBP do) (VP (VB agr...
# 79  (ROOT (S (NP (PRP I)) (VP (VBP believe) (PP (I...
# 80  (ROOT (S (NP (PRP It)) (VP (VBZ is) (VP (VBN a...
# 81  (ROOT (S (NP (PRP I)) (VP (VBP disagree) (PP (...
# 82  (ROOT (S (S (NP (NN Nobody)) (VP (MD can) (VP ...
# 83  (ROOT (S (S (NP (NP (DT The) (RB very) (NN tas...
# 84  (ROOT (S (NP (PRP I)) (VP (VBD did) (RB not) (...
# 85  (ROOT (S (PP (IN For) (NP (PRP$ my) (NN part))...
# 86  (ROOT (S (NP (NP (DT The) (NN use)) (PP (IN of...
# 87  (ROOT (S (NP (PRP I)) (VP (VBP dont) (VP (VB b...
# 88  (ROOT (S (NP (NNS Advertisements)) (VP (VBP ha...
# 89  (ROOT (S (PP (IN In) (NP (NN fact))) (NP (DT s...
# 90  (ROOT (S (NP (PRP I)) (VP (VBP think) (SBAR (S...
# 91  (ROOT (S (S (NP (NNS STUDENTS)) (VP (MD SHOULD...
# 92  (ROOT (S (NP (NP (JJ Many)) (PP (IN of) (NP (P...
# 93  (ROOT (S (NP (NNP Media)) (VP (VBZ has) (VP (V...
# 94  (ROOT (S (NP (NNS Advertisements)) (VP (VBP ar...
# 95  (ROOT (S (NP (PRP I)) (VP (VBP agree) (SBAR (I...
# 96  (ROOT (S (NP (PRP I)) (VP (VBP 'm) (VP (VBP ag...
# 97  (ROOT (S (NP (PRP I)) (VP (VBP disagree) (PP (...
# 98  (ROOT (S (VP (VB Find) (NP (NP (DT the) (NN su...
# 99  (ROOT (S (NP (PRP I)) (VP (VBP dont) (VP (VB t...
#
# [100 rows x 3 columns]

# %%
# Get essays
essay_key2 = pd.read_csv('../data/essays_dataset/index.csv', sep=';')

essays = []
for filename in essay_key2['filename']:
    with open('../data/essays_dataset/essays/'+filename, 'r') as f:
        essays.append(f.read().strip())
        
essay_key2['essay'] = essays

# %%
constituency_parsed_sentences = list()
for essay_text in essay_key2['essay']:
    constituency_parsed_sentences.append(constituency_parse(parser, essay_text, return_parse_obj=True))

# %%
constituency_parsed_sentences[0]
# Out:
# {'sentences': [{'basicDependencies': [{'dep': 'ROOT',
#      'dependent': 5,
#      'dependentGloss': 'aspect',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'nsubj',
#      'dependent': 1,
#      'dependentGloss': 'This',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'cop',
#      'dependent': 2,
#      'dependentGloss': 'is',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'det',
#      'dependent': 3,
#      'dependentGloss': 'an',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'amod',
#      'dependent': 4,
#      'dependentGloss': 'important',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'case',
#      'dependent': 6,
#      'dependentGloss': 'of',
#      'governor': 8,
#      'governorGloss': 'time'},
#     {'dep': 'compound',
#      'dependent': 7,
#      'dependentGloss': 'today',
#      'governor': 8,
#      'governorGloss': 'time'},
#     {'dep': 'nmod',
#      'dependent': 8,
#      'dependentGloss': 'time',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'punct',
#      'dependent': 9,
#      'dependentGloss': '.',
#      'governor': 5,
#      'governorGloss': 'aspect'}],
#    'enhancedDependencies': [{'dep': 'ROOT',
#      'dependent': 5,
#      'dependentGloss': 'aspect',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'nsubj',
#      'dependent': 1,
#      'dependentGloss': 'This',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'cop',
#      'dependent': 2,
#      'dependentGloss': 'is',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'det',
#      'dependent': 3,
#      'dependentGloss': 'an',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'amod',
#      'dependent': 4,
#      'dependentGloss': 'important',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'case',
#      'dependent': 6,
#      'dependentGloss': 'of',
#      'governor': 8,
#      'governorGloss': 'time'},
#     {'dep': 'compound',
#      'dependent': 7,
#      'dependentGloss': 'today',
#      'governor': 8,
#      'governorGloss': 'time'},
#     {'dep': 'nmod:of',
#      'dependent': 8,
#      'dependentGloss': 'time',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'punct',
#      'dependent': 9,
#      'dependentGloss': '.',
#      'governor': 5,
#      'governorGloss': 'aspect'}],
#    'enhancedPlusPlusDependencies': [{'dep': 'ROOT',
#      'dependent': 5,
#      'dependentGloss': 'aspect',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'nsubj',
#      'dependent': 1,
#      'dependentGloss': 'This',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'cop',
#      'dependent': 2,
#      'dependentGloss': 'is',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'det',
#      'dependent': 3,
#      'dependentGloss': 'an',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'amod',
#      'dependent': 4,
#      'dependentGloss': 'important',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'case',
#      'dependent': 6,
#      'dependentGloss': 'of',
#      'governor': 8,
#      'governorGloss': 'time'},
#     {'dep': 'compound',
#      'dependent': 7,
#      'dependentGloss': 'today',
#      'governor': 8,
#      'governorGloss': 'time'},
#     {'dep': 'nmod:of',
#      'dependent': 8,
#      'dependentGloss': 'time',
#      'governor': 5,
#      'governorGloss': 'aspect'},
#     {'dep': 'punct',
#      'dependent': 9,
#      'dependentGloss': '.',
#      'governor': 5,
#      'governorGloss': 'aspect'}],
#    'index': 0,
#    'parse': '(ROOT\r\n  (S\r\n    (NP (DT This))\r\n    (VP (VBZ is)\r\n      (NP\r\n        (NP (DT an) (JJ important) (NN aspect))\r\n        (PP (IN of)\r\n          (NP (NN today) (NN time)))))\r\n    (. .)))',
#    'tokens': [{'after': ' ',
#      'before': '',
#      'characterOffsetBegin': 0,
#      'characterOffsetEnd': 4,
#      'index': 1,
#      'lemma': 'this',
#      'originalText': 'This',
#      'pos': 'DT',
#      'word': 'This'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 5,
#      'characterOffsetEnd': 7,
#      'index': 2,
#      'lemma': 'be',
#      'originalText': 'is',
#      'pos': 'VBZ',
#      'word': 'is'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 8,
#      'characterOffsetEnd': 10,
#      'index': 3,
#      'lemma': 'a',
#      'originalText': 'an',
#      'pos': 'DT',
#      'word': 'an'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 11,
#      'characterOffsetEnd': 20,
#      'index': 4,
#      'lemma': 'important',
#      'originalText': 'important',
#      'pos': 'JJ',
#      'word': 'important'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 21,
#      'characterOffsetEnd': 27,
#      'index': 5,
#      'lemma': 'aspect',
#      'originalText': 'aspect',
#      'pos': 'NN',
#      'word': 'aspect'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 28,
#      'characterOffsetEnd': 30,
#      'index': 6,
#      'lemma': 'of',
#      'originalText': 'of',
#      'pos': 'IN',
#      'word': 'of'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 31,
#      'characterOffsetEnd': 36,
#      'index': 7,
#      'lemma': 'today',
#      'originalText': 'today',
#      'pos': 'NN',
#      'word': 'today'},
#     {'after': '',
#      'before': ' ',
#      'characterOffsetBegin': 37,
#      'characterOffsetEnd': 41,
#      'index': 8,
#      'lemma': 'time',
#      'originalText': 'time',
#      'pos': 'NN',
#      'word': 'time'},
#     {'after': '\n',
#      'before': '',
#      'characterOffsetBegin': 41,
#      'characterOffsetEnd': 42,
#      'index': 9,
#      'lemma': '.',
#      'originalText': '.',
#      'pos': '.',
#      'word': '.'}]},
#   {'basicDependencies': [{'dep': 'ROOT',
#      'dependent': 7,
#      'dependentGloss': 'better',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'det',
#      'dependent': 1,
#      'dependentGloss': 'This',
#      'governor': 3,
#      'governorGloss': 'rathen'},
#     {'dep': 'compound',
#      'dependent': 2,
#      'dependentGloss': 'products',
#      'governor': 3,
#      'governorGloss': 'rathen'},
#     {'dep': 'nsubj',
#      'dependent': 3,
#      'dependentGloss': 'rathen',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'cop',
#      'dependent': 4,
#      'dependentGloss': 'are',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'neg',
#      'dependent': 5,
#      'dependentGloss': 'not',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'advmod',
#      'dependent': 6,
#      'dependentGloss': 'much',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'punct',
#      'dependent': 8,
#      'dependentGloss': ',',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'cc',
#      'dependent': 9,
#      'dependentGloss': 'but',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'nsubj',
#      'dependent': 10,
#      'dependentGloss': 'today',
#      'governor': 13,
#      'governorGloss': 'important'},
#     {'dep': 'cop',
#      'dependent': 11,
#      'dependentGloss': 'is',
#      'governor': 13,
#      'governorGloss': 'important'},
#     {'dep': 'neg',
#      'dependent': 12,
#      'dependentGloss': 'not',
#      'governor': 13,
#      'governorGloss': 'important'},
#     {'dep': 'conj',
#      'dependent': 13,
#      'dependentGloss': 'important',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'det',
#      'dependent': 14,
#      'dependentGloss': 'the',
#      'governor': 16,
#      'governorGloss': 'character'},
#     {'dep': 'advmod',
#      'dependent': 15,
#      'dependentGloss': 'really',
#      'governor': 16,
#      'governorGloss': 'character'},
#     {'dep': 'nsubj',
#      'dependent': 16,
#      'dependentGloss': 'character',
#      'governor': 29,
#      'governorGloss': 'rappresented'},
#     {'dep': 'case',
#      'dependent': 17,
#      'dependentGloss': 'of',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'det',
#      'dependent': 18,
#      'dependentGloss': 'the',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'nmod',
#      'dependent': 19,
#      'dependentGloss': 'product',
#      'governor': 16,
#      'governorGloss': 'character'},
#     {'dep': 'punct',
#      'dependent': 20,
#      'dependentGloss': ',',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'cc',
#      'dependent': 21,
#      'dependentGloss': 'but',
#      'governor': 22,
#      'governorGloss': 'only'},
#     {'dep': 'cc',
#      'dependent': 22,
#      'dependentGloss': 'only',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'det',
#      'dependent': 23,
#      'dependentGloss': 'the',
#      'governor': 24,
#      'governorGloss': 'money'},
#     {'dep': 'conj',
#      'dependent': 24,
#      'dependentGloss': 'money',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'cc',
#      'dependent': 25,
#      'dependentGloss': 'and',
#      'governor': 24,
#      'governorGloss': 'money'},
#     {'dep': 'det',
#      'dependent': 26,
#      'dependentGloss': 'the',
#      'governor': 27,
#      'governorGloss': 'client'},
#     {'dep': 'conj',
#      'dependent': 27,
#      'dependentGloss': 'client',
#      'governor': 24,
#      'governorGloss': 'money'},
#     {'dep': 'neg',
#      'dependent': 28,
#      'dependentGloss': 'not',
#      'governor': 29,
#      'governorGloss': 'rappresented'},
#     {'dep': 'ccomp',
#      'dependent': 29,
#      'dependentGloss': 'rappresented',
#      'governor': 13,
#      'governorGloss': 'important'},
#     {'dep': 'det',
#      'dependent': 30,
#      'dependentGloss': 'the',
#      'governor': 32,
#      'governorGloss': 'actor'},
#     {'dep': 'amod',
#      'dependent': 31,
#      'dependentGloss': 'important',
#      'governor': 32,
#      'governorGloss': 'actor'},
#     {'dep': 'dobj',
#      'dependent': 32,
#      'dependentGloss': 'actor',
#      'governor': 29,
#      'governorGloss': 'rappresented'},
#     {'dep': 'case',
#      'dependent': 33,
#      'dependentGloss': 'in',
#      'governor': 35,
#      'governorGloss': 'process'},
#     {'dep': 'det',
#      'dependent': 34,
#      'dependentGloss': 'this',
#      'governor': 35,
#      'governorGloss': 'process'},
#     {'dep': 'nmod',
#      'dependent': 35,
#      'dependentGloss': 'process',
#      'governor': 29,
#      'governorGloss': 'rappresented'},
#     {'dep': 'punct',
#      'dependent': 36,
#      'dependentGloss': '.',
#      'governor': 7,
#      'governorGloss': 'better'}],
#    'enhancedDependencies': [{'dep': 'ROOT',
#      'dependent': 7,
#      'dependentGloss': 'better',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'det',
#      'dependent': 1,
#      'dependentGloss': 'This',
#      'governor': 3,
#      'governorGloss': 'rathen'},
#     {'dep': 'compound',
#      'dependent': 2,
#      'dependentGloss': 'products',
#      'governor': 3,
#      'governorGloss': 'rathen'},
#     {'dep': 'nsubj',
#      'dependent': 3,
#      'dependentGloss': 'rathen',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'cop',
#      'dependent': 4,
#      'dependentGloss': 'are',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'neg',
#      'dependent': 5,
#      'dependentGloss': 'not',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'advmod',
#      'dependent': 6,
#      'dependentGloss': 'much',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'punct',
#      'dependent': 8,
#      'dependentGloss': ',',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'cc',
#      'dependent': 9,
#      'dependentGloss': 'but',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'nsubj',
#      'dependent': 10,
#      'dependentGloss': 'today',
#      'governor': 13,
#      'governorGloss': 'important'},
#     {'dep': 'cop',
#      'dependent': 11,
#      'dependentGloss': 'is',
#      'governor': 13,
#      'governorGloss': 'important'},
#     {'dep': 'neg',
#      'dependent': 12,
#      'dependentGloss': 'not',
#      'governor': 13,
#      'governorGloss': 'important'},
#     {'dep': 'conj:but',
#      'dependent': 13,
#      'dependentGloss': 'important',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'det',
#      'dependent': 14,
#      'dependentGloss': 'the',
#      'governor': 16,
#      'governorGloss': 'character'},
#     {'dep': 'advmod',
#      'dependent': 15,
#      'dependentGloss': 'really',
#      'governor': 16,
#      'governorGloss': 'character'},
#     {'dep': 'nsubj',
#      'dependent': 16,
#      'dependentGloss': 'character',
#      'governor': 29,
#      'governorGloss': 'rappresented'},
#     {'dep': 'case',
#      'dependent': 17,
#      'dependentGloss': 'of',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'det',
#      'dependent': 18,
#      'dependentGloss': 'the',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'nmod:of',
#      'dependent': 19,
#      'dependentGloss': 'product',
#      'governor': 16,
#      'governorGloss': 'character'},
#     {'dep': 'punct',
#      'dependent': 20,
#      'dependentGloss': ',',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'cc',
#      'dependent': 21,
#      'dependentGloss': 'but',
#      'governor': 22,
#      'governorGloss': 'only'},
#     {'dep': 'cc',
#      'dependent': 22,
#      'dependentGloss': 'only',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'det',
#      'dependent': 23,
#      'dependentGloss': 'the',
#      'governor': 24,
#      'governorGloss': 'money'},
#     {'dep': 'nmod:of',
#      'dependent': 24,
#      'dependentGloss': 'money',
#      'governor': 16,
#      'governorGloss': 'character'},
#     {'dep': 'conj:only',
#      'dependent': 24,
#      'dependentGloss': 'money',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'cc',
#      'dependent': 25,
#      'dependentGloss': 'and',
#      'governor': 24,
#      'governorGloss': 'money'},
#     {'dep': 'det',
#      'dependent': 26,
#      'dependentGloss': 'the',
#      'governor': 27,
#      'governorGloss': 'client'},
#     {'dep': 'conj:only',
#      'dependent': 27,
#      'dependentGloss': 'client',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'conj:and',
#      'dependent': 27,
#      'dependentGloss': 'client',
#      'governor': 24,
#      'governorGloss': 'money'},
#     {'dep': 'neg',
#      'dependent': 28,
#      'dependentGloss': 'not',
#      'governor': 29,
#      'governorGloss': 'rappresented'},
#     {'dep': 'ccomp',
#      'dependent': 29,
#      'dependentGloss': 'rappresented',
#      'governor': 13,
#      'governorGloss': 'important'},
#     {'dep': 'det',
#      'dependent': 30,
#      'dependentGloss': 'the',
#      'governor': 32,
#      'governorGloss': 'actor'},
#     {'dep': 'amod',
#      'dependent': 31,
#      'dependentGloss': 'important',
#      'governor': 32,
#      'governorGloss': 'actor'},
#     {'dep': 'dobj',
#      'dependent': 32,
#      'dependentGloss': 'actor',
#      'governor': 29,
#      'governorGloss': 'rappresented'},
#     {'dep': 'case',
#      'dependent': 33,
#      'dependentGloss': 'in',
#      'governor': 35,
#      'governorGloss': 'process'},
#     {'dep': 'det',
#      'dependent': 34,
#      'dependentGloss': 'this',
#      'governor': 35,
#      'governorGloss': 'process'},
#     {'dep': 'nmod:in',
#      'dependent': 35,
#      'dependentGloss': 'process',
#      'governor': 29,
#      'governorGloss': 'rappresented'},
#     {'dep': 'punct',
#      'dependent': 36,
#      'dependentGloss': '.',
#      'governor': 7,
#      'governorGloss': 'better'}],
#    'enhancedPlusPlusDependencies': [{'dep': 'ROOT',
#      'dependent': 7,
#      'dependentGloss': 'better',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'det',
#      'dependent': 1,
#      'dependentGloss': 'This',
#      'governor': 3,
#      'governorGloss': 'rathen'},
#     {'dep': 'compound',
#      'dependent': 2,
#      'dependentGloss': 'products',
#      'governor': 3,
#      'governorGloss': 'rathen'},
#     {'dep': 'nsubj',
#      'dependent': 3,
#      'dependentGloss': 'rathen',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'cop',
#      'dependent': 4,
#      'dependentGloss': 'are',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'neg',
#      'dependent': 5,
#      'dependentGloss': 'not',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'advmod',
#      'dependent': 6,
#      'dependentGloss': 'much',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'punct',
#      'dependent': 8,
#      'dependentGloss': ',',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'cc',
#      'dependent': 9,
#      'dependentGloss': 'but',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'nsubj',
#      'dependent': 10,
#      'dependentGloss': 'today',
#      'governor': 13,
#      'governorGloss': 'important'},
#     {'dep': 'cop',
#      'dependent': 11,
#      'dependentGloss': 'is',
#      'governor': 13,
#      'governorGloss': 'important'},
#     {'dep': 'neg',
#      'dependent': 12,
#      'dependentGloss': 'not',
#      'governor': 13,
#      'governorGloss': 'important'},
#     {'dep': 'conj:but',
#      'dependent': 13,
#      'dependentGloss': 'important',
#      'governor': 7,
#      'governorGloss': 'better'},
#     {'dep': 'det',
#      'dependent': 14,
#      'dependentGloss': 'the',
#      'governor': 16,
#      'governorGloss': 'character'},
#     {'dep': 'advmod',
#      'dependent': 15,
#      'dependentGloss': 'really',
#      'governor': 16,
#      'governorGloss': 'character'},
#     {'dep': 'nsubj',
#      'dependent': 16,
#      'dependentGloss': 'character',
#      'governor': 29,
#      'governorGloss': 'rappresented'},
#     {'dep': 'case',
#      'dependent': 17,
#      'dependentGloss': 'of',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'det',
#      'dependent': 18,
#      'dependentGloss': 'the',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'nmod:of',
#      'dependent': 19,
#      'dependentGloss': 'product',
#      'governor': 16,
#      'governorGloss': 'character'},
#     {'dep': 'punct',
#      'dependent': 20,
#      'dependentGloss': ',',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'cc',
#      'dependent': 21,
#      'dependentGloss': 'but',
#      'governor': 22,
#      'governorGloss': 'only'},
#     {'dep': 'cc',
#      'dependent': 22,
#      'dependentGloss': 'only',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'det',
#      'dependent': 23,
#      'dependentGloss': 'the',
#      'governor': 24,
#      'governorGloss': 'money'},
#     {'dep': 'nmod:of',
#      'dependent': 24,
#      'dependentGloss': 'money',
#      'governor': 16,
#      'governorGloss': 'character'},
#     {'dep': 'conj:only',
#      'dependent': 24,
#      'dependentGloss': 'money',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'cc',
#      'dependent': 25,
#      'dependentGloss': 'and',
#      'governor': 24,
#      'governorGloss': 'money'},
#     {'dep': 'det',
#      'dependent': 26,
#      'dependentGloss': 'the',
#      'governor': 27,
#      'governorGloss': 'client'},
#     {'dep': 'conj:only',
#      'dependent': 27,
#      'dependentGloss': 'client',
#      'governor': 19,
#      'governorGloss': 'product'},
#     {'dep': 'conj:and',
#      'dependent': 27,
#      'dependentGloss': 'client',
#      'governor': 24,
#      'governorGloss': 'money'},
#     {'dep': 'neg',
#      'dependent': 28,
#      'dependentGloss': 'not',
#      'governor': 29,
#      'governorGloss': 'rappresented'},
#     {'dep': 'ccomp',
#      'dependent': 29,
#      'dependentGloss': 'rappresented',
#      'governor': 13,
#      'governorGloss': 'important'},
#     {'dep': 'det',
#      'dependent': 30,
#      'dependentGloss': 'the',
#      'governor': 32,
#      'governorGloss': 'actor'},
#     {'dep': 'amod',
#      'dependent': 31,
#      'dependentGloss': 'important',
#      'governor': 32,
#      'governorGloss': 'actor'},
#     {'dep': 'dobj',
#      'dependent': 32,
#      'dependentGloss': 'actor',
#      'governor': 29,
#      'governorGloss': 'rappresented'},
#     {'dep': 'case',
#      'dependent': 33,
#      'dependentGloss': 'in',
#      'governor': 35,
#      'governorGloss': 'process'},
#     {'dep': 'det',
#      'dependent': 34,
#      'dependentGloss': 'this',
#      'governor': 35,
#      'governorGloss': 'process'},
#     {'dep': 'nmod:in',
#      'dependent': 35,
#      'dependentGloss': 'process',
#      'governor': 29,
#      'governorGloss': 'rappresented'},
#     {'dep': 'punct',
#      'dependent': 36,
#      'dependentGloss': '.',
#      'governor': 7,
#      'governorGloss': 'better'}],
#    'index': 1,
#    'parse': '(ROOT\r\n  (S\r\n    (S\r\n      (NP (DT This) (NNS products) (NN rathen))\r\n      (VP (VBP are) (RB not)\r\n        (ADJP (RB much) (JJR better))))\r\n    (, ,)\r\n    (CC but)\r\n    (S\r\n      (NP (NN today))\r\n      (VP (VBZ is) (RB not)\r\n        (ADJP (JJ important)\r\n          (SBAR\r\n            (S\r\n              (NP\r\n                (NP (DT the)\r\n                  (ADVP (RB really))\r\n                  (NN character))\r\n                (PP (IN of)\r\n                  (NP\r\n                    (NP (DT the) (NN product))\r\n                    (, ,)\r\n                    (CONJP (CC but)\r\n                      (RB only))\r\n                    (NP\r\n                      (NP (DT the) (NN money))\r\n                      (CC and)\r\n                      (NP (DT the) (NN client))))))\r\n              (RB not)\r\n              (VP (VBD rappresented)\r\n                (NP (DT the) (JJ important) (NN actor))\r\n                (PP (IN in)\r\n                  (NP (DT this) (NN process)))))))))\r\n    (. .)))',
#    'tokens': [{'after': ' ',
#      'before': '\n',
#      'characterOffsetBegin': 43,
#      'characterOffsetEnd': 47,
#      'index': 1,
#      'lemma': 'this',
#      'originalText': 'This',
#      'pos': 'DT',
#      'word': 'This'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 48,
#      'characterOffsetEnd': 56,
#      'index': 2,
#      'lemma': 'product',
#      'originalText': 'products',
#      'pos': 'NNS',
#      'word': 'products'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 57,
#      'characterOffsetEnd': 63,
#      'index': 3,
#      'lemma': 'rathen',
#      'originalText': 'rathen',
#      'pos': 'NN',
#      'word': 'rathen'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 64,
#      'characterOffsetEnd': 67,
#      'index': 4,
#      'lemma': 'be',
#      'originalText': 'are',
#      'pos': 'VBP',
#      'word': 'are'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 68,
#      'characterOffsetEnd': 71,
#      'index': 5,
#      'lemma': 'not',
#      'originalText': 'not',
#      'pos': 'RB',
#      'word': 'not'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 72,
#      'characterOffsetEnd': 76,
#      'index': 6,
#      'lemma': 'much',
#      'originalText': 'much',
#      'pos': 'RB',
#      'word': 'much'},
#     {'after': '',
#      'before': ' ',
#      'characterOffsetBegin': 77,
#      'characterOffsetEnd': 83,
#      'index': 7,
#      'lemma': 'better',
#      'originalText': 'better',
#      'pos': 'JJR',
#      'word': 'better'},
#     {'after': ' ',
#      'before': '',
#      'characterOffsetBegin': 83,
#      'characterOffsetEnd': 84,
#      'index': 8,
#      'lemma': ',',
#      'originalText': ',',
#      'pos': ',',
#      'word': ','},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 85,
#      'characterOffsetEnd': 88,
#      'index': 9,
#      'lemma': 'but',
#      'originalText': 'but',
#      'pos': 'CC',
#      'word': 'but'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 89,
#      'characterOffsetEnd': 94,
#      'index': 10,
#      'lemma': 'today',
#      'originalText': 'today',
#      'pos': 'NN',
#      'word': 'today'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 95,
#      'characterOffsetEnd': 97,
#      'index': 11,
#      'lemma': 'be',
#      'originalText': 'is',
#      'pos': 'VBZ',
#      'word': 'is'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 98,
#      'characterOffsetEnd': 101,
#      'index': 12,
#      'lemma': 'not',
#      'originalText': 'not',
#      'pos': 'RB',
#      'word': 'not'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 102,
#      'characterOffsetEnd': 111,
#      'index': 13,
#      'lemma': 'important',
#      'originalText': 'important',
#      'pos': 'JJ',
#      'word': 'important'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 112,
#      'characterOffsetEnd': 115,
#      'index': 14,
#      'lemma': 'the',
#      'originalText': 'the',
#      'pos': 'DT',
#      'word': 'the'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 116,
#      'characterOffsetEnd': 122,
#      'index': 15,
#      'lemma': 'really',
#      'originalText': 'really',
#      'pos': 'RB',
#      'word': 'really'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 123,
#      'characterOffsetEnd': 132,
#      'index': 16,
#      'lemma': 'character',
#      'originalText': 'character',
#      'pos': 'NN',
#      'word': 'character'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 133,
#      'characterOffsetEnd': 135,
#      'index': 17,
#      'lemma': 'of',
#      'originalText': 'of',
#      'pos': 'IN',
#      'word': 'of'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 136,
#      'characterOffsetEnd': 139,
#      'index': 18,
#      'lemma': 'the',
#      'originalText': 'the',
#      'pos': 'DT',
#      'word': 'the'},
#     {'after': '',
#      'before': ' ',
#      'characterOffsetBegin': 140,
#      'characterOffsetEnd': 147,
#      'index': 19,
#      'lemma': 'product',
#      'originalText': 'product',
#      'pos': 'NN',
#      'word': 'product'},
#     {'after': ' ',
#      'before': '',
#      'characterOffsetBegin': 147,
#      'characterOffsetEnd': 148,
#      'index': 20,
#      'lemma': ',',
#      'originalText': ',',
#      'pos': ',',
#      'word': ','},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 149,
#      'characterOffsetEnd': 152,
#      'index': 21,
#      'lemma': 'but',
#      'originalText': 'but',
#      'pos': 'CC',
#      'word': 'but'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 153,
#      'characterOffsetEnd': 157,
#      'index': 22,
#      'lemma': 'only',
#      'originalText': 'only',
#      'pos': 'RB',
#      'word': 'only'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 158,
#      'characterOffsetEnd': 161,
#      'index': 23,
#      'lemma': 'the',
#      'originalText': 'the',
#      'pos': 'DT',
#      'word': 'the'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 162,
#      'characterOffsetEnd': 167,
#      'index': 24,
#      'lemma': 'money',
#      'originalText': 'money',
#      'pos': 'NN',
#      'word': 'money'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 168,
#      'characterOffsetEnd': 171,
#      'index': 25,
#      'lemma': 'and',
#      'originalText': 'and',
#      'pos': 'CC',
#      'word': 'and'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 172,
#      'characterOffsetEnd': 175,
#      'index': 26,
#      'lemma': 'the',
#      'originalText': 'the',
#      'pos': 'DT',
#      'word': 'the'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 176,
#      'characterOffsetEnd': 182,
#      'index': 27,
#      'lemma': 'client',
#      'originalText': 'client',
#      'pos': 'NN',
#      'word': 'client'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 183,
#      'characterOffsetEnd': 186,
#      'index': 28,
#      'lemma': 'not',
#      'originalText': 'not',
#      'pos': 'RB',
#      'word': 'not'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 187,
#      'characterOffsetEnd': 199,
#      'index': 29,
#      'lemma': 'rappresent',
#      'originalText': 'rappresented',
#      'pos': 'VBD',
#      'word': 'rappresented'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 200,
#      'characterOffsetEnd': 203,
#      'index': 30,
#      'lemma': 'the',
#      'originalText': 'the',
#      'pos': 'DT',
#      'word': 'the'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 204,
#      'characterOffsetEnd': 213,
#      'index': 31,
#      'lemma': 'important',
#      'originalText': 'important',
#      'pos': 'JJ',
#      'word': 'important'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 214,
#      'characterOffsetEnd': 219,
#      'index': 32,
#      'lemma': 'actor',
#      'originalText': 'actor',
#      'pos': 'NN',
#      'word': 'actor'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 220,
#      'characterOffsetEnd': 222,
#      'index': 33,
#      'lemma': 'in',
#      'originalText': 'in',
#      'pos': 'IN',
#      'word': 'in'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 223,
#      'characterOffsetEnd': 227,
#      'index': 34,
#      'lemma': 'this',
#      'originalText': 'this',
#      'pos': 'DT',
#      'word': 'this'},
#     {'after': '',
#      'before': ' ',
#      'characterOffsetBegin': 228,
#      'characterOffsetEnd': 235,
#      'index': 35,
#      'lemma': 'process',
#      'originalText': 'process',
#      'pos': 'NN',
#      'word': 'process'},
#     {'after': '\n',
#      'before': '',
#      'characterOffsetBegin': 235,
#      'characterOffsetEnd': 236,
#      'index': 36,
#      'lemma': '.',
#      'originalText': '.',
#      'pos': '.',
#      'word': '.'}]},
#   {'basicDependencies': [{'dep': 'ROOT',
#      'dependent': 5,
#      'dependentGloss': 'buy',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'det',
#      'dependent': 1,
#      'dependentGloss': 'Every',
#      'governor': 2,
#      'governorGloss': 'day'},
#     {'dep': 'nmod:tmod',
#      'dependent': 2,
#      'dependentGloss': 'day',
#      'governor': 5,
#      'governorGloss': 'buy'},
#     {'dep': 'det',
#      'dependent': 3,
#      'dependentGloss': 'any',
#      'governor': 4,
#      'governorGloss': 'people'},
#     {'dep': 'nsubj',
#      'dependent': 4,
#      'dependentGloss': 'people',
#      'governor': 5,
#      'governorGloss': 'buy'},
#     {'dep': 'amod',
#      'dependent': 6,
#      'dependentGloss': 'same',
#      'governor': 7,
#      'governorGloss': 'products'},
#     {'dep': 'nsubj',
#      'dependent': 7,
#      'dependentGloss': 'products',
#      'governor': 20,
#      'governorGloss': 'buy'},
#     {'dep': 'nsubjpass',
#      'dependent': 8,
#      'dependentGloss': 'that',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'auxpass',
#      'dependent': 9,
#      'dependentGloss': 'is',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'neg',
#      'dependent': 10,
#      'dependentGloss': 'not',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'acl:relcl',
#      'dependent': 11,
#      'dependentGloss': 'rappresented',
#      'governor': 7,
#      'governorGloss': 'products'},
#     {'dep': 'det:predet',
#      'dependent': 12,
#      'dependentGloss': 'the',
#      'governor': 14,
#      'governorGloss': 'necessity'},
#     {'dep': 'nmod:poss',
#      'dependent': 13,
#      'dependentGloss': 'your',
#      'governor': 14,
#      'governorGloss': 'necessity'},
#     {'dep': 'dobj',
#      'dependent': 14,
#      'dependentGloss': 'necessity',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'punct',
#      'dependent': 15,
#      'dependentGloss': ',',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'cc',
#      'dependent': 16,
#      'dependentGloss': 'but',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'cop',
#      'dependent': 17,
#      'dependentGloss': 'is',
#      'governor': 19,
#      'governorGloss': 'important'},
#     {'dep': 'advmod',
#      'dependent': 18,
#      'dependentGloss': 'only',
#      'governor': 19,
#      'governorGloss': 'important'},
#     {'dep': 'conj',
#      'dependent': 19,
#      'dependentGloss': 'important',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'ccomp',
#      'dependent': 20,
#      'dependentGloss': 'buy',
#      'governor': 5,
#      'governorGloss': 'buy'},
#     {'dep': 'det',
#      'dependent': 21,
#      'dependentGloss': 'any',
#      'governor': 22,
#      'governorGloss': 'product'},
#     {'dep': 'dobj',
#      'dependent': 22,
#      'dependentGloss': 'product',
#      'governor': 20,
#      'governorGloss': 'buy'},
#     {'dep': 'punct',
#      'dependent': 23,
#      'dependentGloss': '.',
#      'governor': 5,
#      'governorGloss': 'buy'}],
#    'enhancedDependencies': [{'dep': 'ROOT',
#      'dependent': 5,
#      'dependentGloss': 'buy',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'det',
#      'dependent': 1,
#      'dependentGloss': 'Every',
#      'governor': 2,
#      'governorGloss': 'day'},
#     {'dep': 'nmod:tmod',
#      'dependent': 2,
#      'dependentGloss': 'day',
#      'governor': 5,
#      'governorGloss': 'buy'},
#     {'dep': 'det',
#      'dependent': 3,
#      'dependentGloss': 'any',
#      'governor': 4,
#      'governorGloss': 'people'},
#     {'dep': 'nsubj',
#      'dependent': 4,
#      'dependentGloss': 'people',
#      'governor': 5,
#      'governorGloss': 'buy'},
#     {'dep': 'amod',
#      'dependent': 6,
#      'dependentGloss': 'same',
#      'governor': 7,
#      'governorGloss': 'products'},
#     {'dep': 'nsubjpass',
#      'dependent': 7,
#      'dependentGloss': 'products',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'nsubj',
#      'dependent': 7,
#      'dependentGloss': 'products',
#      'governor': 19,
#      'governorGloss': 'important'},
#     {'dep': 'nsubj',
#      'dependent': 7,
#      'dependentGloss': 'products',
#      'governor': 20,
#      'governorGloss': 'buy'},
#     {'dep': 'ref',
#      'dependent': 8,
#      'dependentGloss': 'that',
#      'governor': 7,
#      'governorGloss': 'products'},
#     {'dep': 'auxpass',
#      'dependent': 9,
#      'dependentGloss': 'is',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'neg',
#      'dependent': 10,
#      'dependentGloss': 'not',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'acl:relcl',
#      'dependent': 11,
#      'dependentGloss': 'rappresented',
#      'governor': 7,
#      'governorGloss': 'products'},
#     {'dep': 'det:predet',
#      'dependent': 12,
#      'dependentGloss': 'the',
#      'governor': 14,
#      'governorGloss': 'necessity'},
#     {'dep': 'nmod:poss',
#      'dependent': 13,
#      'dependentGloss': 'your',
#      'governor': 14,
#      'governorGloss': 'necessity'},
#     {'dep': 'dobj',
#      'dependent': 14,
#      'dependentGloss': 'necessity',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'punct',
#      'dependent': 15,
#      'dependentGloss': ',',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'cc',
#      'dependent': 16,
#      'dependentGloss': 'but',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'cop',
#      'dependent': 17,
#      'dependentGloss': 'is',
#      'governor': 19,
#      'governorGloss': 'important'},
#     {'dep': 'advmod',
#      'dependent': 18,
#      'dependentGloss': 'only',
#      'governor': 19,
#      'governorGloss': 'important'},
#     {'dep': 'acl:relcl',
#      'dependent': 19,
#      'dependentGloss': 'important',
#      'governor': 7,
#      'governorGloss': 'products'},
#     {'dep': 'conj:but',
#      'dependent': 19,
#      'dependentGloss': 'important',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'ccomp',
#      'dependent': 20,
#      'dependentGloss': 'buy',
#      'governor': 5,
#      'governorGloss': 'buy'},
#     {'dep': 'det',
#      'dependent': 21,
#      'dependentGloss': 'any',
#      'governor': 22,
#      'governorGloss': 'product'},
#     {'dep': 'dobj',
#      'dependent': 22,
#      'dependentGloss': 'product',
#      'governor': 20,
#      'governorGloss': 'buy'},
#     {'dep': 'punct',
#      'dependent': 23,
#      'dependentGloss': '.',
#      'governor': 5,
#      'governorGloss': 'buy'}],
#    'enhancedPlusPlusDependencies': [{'dep': 'ROOT',
#      'dependent': 5,
#      'dependentGloss': 'buy',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'det',
#      'dependent': 1,
#      'dependentGloss': 'Every',
#      'governor': 2,
#      'governorGloss': 'day'},
#     {'dep': 'nmod:tmod',
#      'dependent': 2,
#      'dependentGloss': 'day',
#      'governor': 5,
#      'governorGloss': 'buy'},
#     {'dep': 'det',
#      'dependent': 3,
#      'dependentGloss': 'any',
#      'governor': 4,
#      'governorGloss': 'people'},
#     {'dep': 'nsubj',
#      'dependent': 4,
#      'dependentGloss': 'people',
#      'governor': 5,
#      'governorGloss': 'buy'},
#     {'dep': 'amod',
#      'dependent': 6,
#      'dependentGloss': 'same',
#      'governor': 7,
#      'governorGloss': 'products'},
#     {'dep': 'nsubjpass',
#      'dependent': 7,
#      'dependentGloss': 'products',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'nsubj',
#      'dependent': 7,
#      'dependentGloss': 'products',
#      'governor': 19,
#      'governorGloss': 'important'},
#     {'dep': 'nsubj',
#      'dependent': 7,
#      'dependentGloss': 'products',
#      'governor': 20,
#      'governorGloss': 'buy'},
#     {'dep': 'ref',
#      'dependent': 8,
#      'dependentGloss': 'that',
#      'governor': 7,
#      'governorGloss': 'products'},
#     {'dep': 'auxpass',
#      'dependent': 9,
#      'dependentGloss': 'is',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'neg',
#      'dependent': 10,
#      'dependentGloss': 'not',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'acl:relcl',
#      'dependent': 11,
#      'dependentGloss': 'rappresented',
#      'governor': 7,
#      'governorGloss': 'products'},
#     {'dep': 'det:predet',
#      'dependent': 12,
#      'dependentGloss': 'the',
#      'governor': 14,
#      'governorGloss': 'necessity'},
#     {'dep': 'nmod:poss',
#      'dependent': 13,
#      'dependentGloss': 'your',
#      'governor': 14,
#      'governorGloss': 'necessity'},
#     {'dep': 'dobj',
#      'dependent': 14,
#      'dependentGloss': 'necessity',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'punct',
#      'dependent': 15,
#      'dependentGloss': ',',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'cc',
#      'dependent': 16,
#      'dependentGloss': 'but',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'cop',
#      'dependent': 17,
#      'dependentGloss': 'is',
#      'governor': 19,
#      'governorGloss': 'important'},
#     {'dep': 'advmod',
#      'dependent': 18,
#      'dependentGloss': 'only',
#      'governor': 19,
#      'governorGloss': 'important'},
#     {'dep': 'acl:relcl',
#      'dependent': 19,
#      'dependentGloss': 'important',
#      'governor': 7,
#      'governorGloss': 'products'},
#     {'dep': 'conj:but',
#      'dependent': 19,
#      'dependentGloss': 'important',
#      'governor': 11,
#      'governorGloss': 'rappresented'},
#     {'dep': 'ccomp',
#      'dependent': 20,
#      'dependentGloss': 'buy',
#      'governor': 5,
#      'governorGloss': 'buy'},
#     {'dep': 'det',
#      'dependent': 21,
#      'dependentGloss': 'any',
#      'governor': 22,
#      'governorGloss': 'product'},
#     {'dep': 'dobj',
#      'dependent': 22,
#      'dependentGloss': 'product',
#      'governor': 20,
#      'governorGloss': 'buy'},
#     {'dep': 'punct',
#      'dependent': 23,
#      'dependentGloss': '.',
#      'governor': 5,
#      'governorGloss': 'buy'}],
#    'index': 2,
#    'parse': '(ROOT\r\n  (S\r\n    (NP-TMP (DT Every) (NN day))\r\n    (NP (DT any) (NNS people))\r\n    (VP (VBP buy)\r\n      (S\r\n        (NP\r\n          (NP (JJ same) (NNS products))\r\n          (SBAR\r\n            (WHNP (WDT that))\r\n            (S\r\n              (VP\r\n                (VP (VBZ is) (RB not)\r\n                  (VP (VBN rappresented)\r\n                    (NP (DT the) (PRP$ your) (NN necessity))))\r\n                (, ,)\r\n                (CC but)\r\n                (VP (VBZ is)\r\n                  (ADVP (RB only))\r\n                  (ADJP (JJ important)))))))\r\n        (VP (VB buy)\r\n          (NP (DT any) (NN product)))))\r\n    (. .)))',
#    'tokens': [{'after': ' ',
#      'before': '\n',
#      'characterOffsetBegin': 237,
#      'characterOffsetEnd': 242,
#      'index': 1,
#      'lemma': 'every',
#      'originalText': 'Every',
#      'pos': 'DT',
#      'word': 'Every'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 243,
#      'characterOffsetEnd': 246,
#      'index': 2,
#      'lemma': 'day',
#      'originalText': 'day',
#      'pos': 'NN',
#      'word': 'day'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 247,
#      'characterOffsetEnd': 250,
#      'index': 3,
#      'lemma': 'any',
#      'originalText': 'any',
#      'pos': 'DT',
#      'word': 'any'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 251,
#      'characterOffsetEnd': 257,
#      'index': 4,
#      'lemma': 'people',
#      'originalText': 'people',
#      'pos': 'NNS',
#      'word': 'people'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 258,
#      'characterOffsetEnd': 261,
#      'index': 5,
#      'lemma': 'buy',
#      'originalText': 'buy',
#      'pos': 'VBP',
#      'word': 'buy'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 262,
#      'characterOffsetEnd': 266,
#      'index': 6,
#      'lemma': 'same',
#      'originalText': 'same',
#      'pos': 'JJ',
#      'word': 'same'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 267,
#      'characterOffsetEnd': 275,
#      'index': 7,
#      'lemma': 'product',
#      'originalText': 'products',
#      'pos': 'NNS',
#      'word': 'products'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 276,
#      'characterOffsetEnd': 280,
#      'index': 8,
#      'lemma': 'that',
#      'originalText': 'that',
#      'pos': 'WDT',
#      'word': 'that'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 281,
#      'characterOffsetEnd': 283,
#      'index': 9,
#      'lemma': 'be',
#      'originalText': 'is',
#      'pos': 'VBZ',
#      'word': 'is'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 284,
#      'characterOffsetEnd': 287,
#      'index': 10,
#      'lemma': 'not',
#      'originalText': 'not',
#      'pos': 'RB',
#      'word': 'not'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 288,
#      'characterOffsetEnd': 300,
#      'index': 11,
#      'lemma': 'rappresent',
#      'originalText': 'rappresented',
#      'pos': 'VBN',
#      'word': 'rappresented'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 301,
#      'characterOffsetEnd': 304,
#      'index': 12,
#      'lemma': 'the',
#      'originalText': 'the',
#      'pos': 'DT',
#      'word': 'the'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 305,
#      'characterOffsetEnd': 309,
#      'index': 13,
#      'lemma': 'you',
#      'originalText': 'your',
#      'pos': 'PRP$',
#      'word': 'your'},
#     {'after': '',
#      'before': ' ',
#      'characterOffsetBegin': 310,
#      'characterOffsetEnd': 319,
#      'index': 14,
#      'lemma': 'necessity',
#      'originalText': 'necessity',
#      'pos': 'NN',
#      'word': 'necessity'},
#     {'after': ' ',
#      'before': '',
#      'characterOffsetBegin': 319,
#      'characterOffsetEnd': 320,
#      'index': 15,
#      'lemma': ',',
#      'originalText': ',',
#      'pos': ',',
#      'word': ','},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 321,
#      'characterOffsetEnd': 324,
#      'index': 16,
#      'lemma': 'but',
#      'originalText': 'but',
#      'pos': 'CC',
#      'word': 'but'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 325,
#      'characterOffsetEnd': 327,
#      'index': 17,
#      'lemma': 'be',
#      'originalText': 'is',
#      'pos': 'VBZ',
#      'word': 'is'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 328,
#      'characterOffsetEnd': 332,
#      'index': 18,
#      'lemma': 'only',
#      'originalText': 'only',
#      'pos': 'RB',
#      'word': 'only'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 333,
#      'characterOffsetEnd': 342,
#      'index': 19,
#      'lemma': 'important',
#      'originalText': 'important',
#      'pos': 'JJ',
#      'word': 'important'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 343,
#      'characterOffsetEnd': 346,
#      'index': 20,
#      'lemma': 'buy',
#      'originalText': 'buy',
#      'pos': 'VB',
#      'word': 'buy'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 347,
#      'characterOffsetEnd': 350,
#      'index': 21,
#      'lemma': 'any',
#      'originalText': 'any',
#      'pos': 'DT',
#      'word': 'any'},
#     {'after': '',
#      'before': ' ',
#      'characterOffsetBegin': 351,
#      'characterOffsetEnd': 358,
#      'index': 22,
#      'lemma': 'product',
#      'originalText': 'product',
#      'pos': 'NN',
#      'word': 'product'},
#     {'after': '\n',
#      'before': '',
#      'characterOffsetBegin': 358,
#      'characterOffsetEnd': 359,
#      'index': 23,
#      'lemma': '.',
#      'originalText': '.',
#      'pos': '.',
#      'word': '.'}]},
#   {'basicDependencies': [{'dep': 'ROOT',
#      'dependent': 14,
#      'dependentGloss': 'is',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'mark',
#      'dependent': 1,
#      'dependentGloss': 'To',
#      'governor': 2,
#      'governorGloss': 'explain'},
#     {'dep': 'advcl',
#      'dependent': 2,
#      'dependentGloss': 'explain',
#      'governor': 14,
#      'governorGloss': 'is'},
#     {'dep': 'det',
#      'dependent': 3,
#      'dependentGloss': 'this',
#      'governor': 4,
#      'governorGloss': 'argoment'},
#     {'dep': 'dobj',
#      'dependent': 4,
#      'dependentGloss': 'argoment',
#      'governor': 2,
#      'governorGloss': 'explain'},
#     {'dep': 'case',
#      'dependent': 5,
#      'dependentGloss': 'in',
#      'governor': 7,
#      'governorGloss': 'nation'},
#     {'dep': 'nmod:poss',
#      'dependent': 6,
#      'dependentGloss': 'my',
#      'governor': 7,
#      'governorGloss': 'nation'},
#     {'dep': 'nmod',
#      'dependent': 7,
#      'dependentGloss': 'nation',
#      'governor': 4,
#      'governorGloss': 'argoment'},
#     {'dep': 'punct',
#      'dependent': 8,
#      'dependentGloss': ',',
#      'governor': 2,
#      'governorGloss': 'explain'},
#     {'dep': 'case',
#      'dependent': 9,
#      'dependentGloss': 'at',
#      'governor': 11,
#      'governorGloss': 'television'},
#     {'dep': 'det',
#      'dependent': 10,
#      'dependentGloss': 'the',
#      'governor': 11,
#      'governorGloss': 'television'},
#     {'dep': 'nmod',
#      'dependent': 11,
#      'dependentGloss': 'television',
#      'governor': 2,
#      'governorGloss': 'explain'},
#     {'dep': 'punct',
#      'dependent': 12,
#      'dependentGloss': ',',
#      'governor': 14,
#      'governorGloss': 'is'},
#     {'dep': 'expl',
#      'dependent': 13,
#      'dependentGloss': 'there',
#      'governor': 14,
#      'governorGloss': 'is'},
#     {'dep': 'det',
#      'dependent': 15,
#      'dependentGloss': 'an',
#      'governor': 16,
#      'governorGloss': 'program'},
#     {'dep': 'nsubj',
#      'dependent': 16,
#      'dependentGloss': 'program',
#      'governor': 14,
#      'governorGloss': 'is'},
#     {'dep': 'nsubj',
#      'dependent': 17,
#      'dependentGloss': 'that',
#      'governor': 18,
#      'governorGloss': 'discuss'},
#     {'dep': 'acl:relcl',
#      'dependent': 18,
#      'dependentGloss': 'discuss',
#      'governor': 16,
#      'governorGloss': 'program'},
#     {'dep': 'case',
#      'dependent': 19,
#      'dependentGloss': 'of',
#      'governor': 21,
#      'governorGloss': 'problem'},
#     {'dep': 'det',
#      'dependent': 20,
#      'dependentGloss': 'the',
#      'governor': 21,
#      'governorGloss': 'problem'},
#     {'dep': 'nmod',
#      'dependent': 21,
#      'dependentGloss': 'problem',
#      'governor': 18,
#      'governorGloss': 'discuss'},
#     {'dep': 'acl',
#      'dependent': 22,
#      'dependentGloss': 'rappresented',
#      'governor': 21,
#      'governorGloss': 'problem'},
#     {'dep': 'case',
#      'dependent': 23,
#      'dependentGloss': 'by',
#      'governor': 24,
#      'governorGloss': 'this'},
#     {'dep': 'nmod',
#      'dependent': 24,
#      'dependentGloss': 'this',
#      'governor': 22,
#      'governorGloss': 'rappresented'},
#     {'dep': 'punct',
#      'dependent': 25,
#      'dependentGloss': '.',
#      'governor': 14,
#      'governorGloss': 'is'}],
#    'enhancedDependencies': [{'dep': 'ROOT',
#      'dependent': 14,
#      'dependentGloss': 'is',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'mark',
#      'dependent': 1,
#      'dependentGloss': 'To',
#      'governor': 2,
#      'governorGloss': 'explain'},
#     {'dep': 'advcl:to',
#      'dependent': 2,
#      'dependentGloss': 'explain',
#      'governor': 14,
#      'governorGloss': 'is'},
#     {'dep': 'det',
#      'dependent': 3,
# ...
#    'tokens': [{'after': ' ',
#      'before': '\n',
#      'characterOffsetBegin': 1451,
#      'characterOffsetEnd': 1454,
#      'index': 1,
#      'lemma': 'the',
#      'originalText': 'The',
#      'pos': 'DT',
#      'word': 'The'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1455,
#      'characterOffsetEnd': 1462,
#      'index': 2,
#      'lemma': 'society',
#      'originalText': 'society',
#      'pos': 'NN',
#      'word': 'society'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1463,
#      'characterOffsetEnd': 1467,
#      'index': 3,
#      'lemma': 'lose',
#      'originalText': 'lose',
#      'pos': 'VBP',
#      'word': 'lose'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1468,
#      'characterOffsetEnd': 1471,
#      'index': 4,
#      'lemma': 'the',
#      'originalText': 'the',
#      'pos': 'DT',
#      'word': 'the'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1472,
#      'characterOffsetEnd': 1481,
#      'index': 5,
#      'lemma': 'propriety',
#      'originalText': 'propriety',
#      'pos': 'NN',
#      'word': 'propriety'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1482,
#      'characterOffsetEnd': 1486,
#      'index': 6,
#      'lemma': 'when',
#      'originalText': 'when',
#      'pos': 'WRB',
#      'word': 'when'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1487,
#      'characterOffsetEnd': 1491,
#      'index': 7,
#      'lemma': 'this',
#      'originalText': 'this',
#      'pos': 'DT',
#      'word': 'this'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1492,
#      'characterOffsetEnd': 1499,
#      'index': 8,
#      'lemma': 'problem',
#      'originalText': 'problem',
#      'pos': 'NN',
#      'word': 'problem'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1500,
#      'characterOffsetEnd': 1504,
#      'index': 9,
#      'lemma': 'will',
#      'originalText': 'will',
#      'pos': 'MD',
#      'word': 'will'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1505,
#      'characterOffsetEnd': 1515,
#      'index': 10,
#      'lemma': 'rappresent',
#      'originalText': 'rappresent',
#      'pos': 'VB',
#      'word': 'rappresent'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1516,
#      'characterOffsetEnd': 1519,
#      'index': 11,
#      'lemma': 'the',
#      'originalText': 'the',
#      'pos': 'DT',
#      'word': 'the'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1520,
#      'characterOffsetEnd': 1524,
#      'index': 12,
#      'lemma': 'must',
#      'originalText': 'must',
#      'pos': 'MD',
#      'word': 'must'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1525,
#      'characterOffsetEnd': 1533,
#      'index': 13,
#      'lemma': 'argoment',
#      'originalText': 'argoment',
#      'pos': 'VB',
#      'word': 'argoment'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1534,
#      'characterOffsetEnd': 1536,
#      'index': 14,
#      'lemma': 'of',
#      'originalText': 'of',
#      'pos': 'IN',
#      'word': 'of'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1537,
#      'characterOffsetEnd': 1540,
#      'index': 15,
#      'lemma': 'the',
#      'originalText': 'the',
#      'pos': 'DT',
#      'word': 'the'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1541,
#      'characterOffsetEnd': 1545,
#      'index': 16,
#      'lemma': 'talk',
#      'originalText': 'talk',
#      'pos': 'NN',
#      'word': 'talk'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1546,
#      'characterOffsetEnd': 1549,
#      'index': 17,
#      'lemma': 'and',
#      'originalText': 'and',
#      'pos': 'CC',
#      'word': 'and'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1550,
#      'characterOffsetEnd': 1553,
#      'index': 18,
#      'lemma': 'the',
#      'originalText': 'the',
#      'pos': 'DT',
#      'word': 'the'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1554,
#      'characterOffsetEnd': 1558,
#      'index': 19,
#      'lemma': 'life',
#      'originalText': 'life',
#      'pos': 'NN',
#      'word': 'life'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1559,
#      'characterOffsetEnd': 1561,
#      'index': 20,
#      'lemma': 'of',
#      'originalText': 'of',
#      'pos': 'IN',
#      'word': 'of'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1562,
#      'characterOffsetEnd': 1565,
#      'index': 21,
#      'lemma': 'the',
#      'originalText': 'the',
#      'pos': 'DT',
#      'word': 'the'},
#     {'after': '',
#      'before': ' ',
#      'characterOffsetBegin': 1566,
#      'characterOffsetEnd': 1572,
#      'index': 22,
#      'lemma': 'people',
#      'originalText': 'people',
#      'pos': 'NNS',
#      'word': 'people'},
#     {'after': ' ',
#      'before': '',
#      'characterOffsetBegin': 1572,
#      'characterOffsetEnd': 1573,
#      'index': 23,
#      'lemma': ',',
#      'originalText': ',',
#      'pos': ',',
#      'word': ','},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1574,
#      'characterOffsetEnd': 1581,
#      'index': 24,
#      'lemma': 'because',
#      'originalText': 'because',
#      'pos': 'IN',
#      'word': 'because'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1582,
#      'characterOffsetEnd': 1584,
#      'index': 25,
#      'lemma': 'as',
#      'originalText': 'as',
#      'pos': 'IN',
#      'word': 'as'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1585,
#      'characterOffsetEnd': 1589,
#      'index': 26,
#      'lemma': 'very',
#      'originalText': 'very',
#      'pos': 'RB',
#      'word': 'very'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1590,
#      'characterOffsetEnd': 1599,
#      'index': 27,
#      'lemma': 'difficult',
#      'originalText': 'difficult',
#      'pos': 'JJ',
#      'word': 'difficult'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1600,
#      'characterOffsetEnd': 1604,
#      'index': 28,
#      'lemma': 'live',
#      'originalText': 'live',
#      'pos': 'JJ',
#      'word': 'live'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1605,
#      'characterOffsetEnd': 1607,
#      'index': 29,
#      'lemma': 'at',
#      'originalText': 'at',
#      'pos': 'IN',
#      'word': 'at'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1608,
#      'characterOffsetEnd': 1609,
#      'index': 30,
#      'lemma': 'a',
#      'originalText': 'a',
#      'pos': 'DT',
#      'word': 'a'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1610,
#      'characterOffsetEnd': 1614,
#      'index': 31,
#      'lemma': 'time',
#      'originalText': 'time',
#      'pos': 'NN',
#      'word': 'time'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1615,
#      'characterOffsetEnd': 1619,
#      'index': 32,
#      'lemma': 'with',
#      'originalText': 'with',
#      'pos': 'IN',
#      'word': 'with'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1620,
#      'characterOffsetEnd': 1624,
#      'index': 33,
#      'lemma': 'this',
#      'originalText': 'this',
#      'pos': 'DT',
#      'word': 'this'},
#     {'after': '',
#      'before': ' ',
#      'characterOffsetBegin': 1625,
#      'characterOffsetEnd': 1633,
#      'index': 34,
#      'lemma': 'argoment',
#      'originalText': 'argoment',
#      'pos': 'NN',
#      'word': 'argoment'},
#     {'after': '\n',
#      'before': '',
#      'characterOffsetBegin': 1633,
#      'characterOffsetEnd': 1634,
#      'index': 35,
#      'lemma': '.',
#      'originalText': '.',
#      'pos': '.',
#      'word': '.'}]},
#   {'basicDependencies': [{'dep': 'ROOT',
#      'dependent': 4,
#      'dependentGloss': 'is',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'nsubj',
#      'dependent': 1,
#      'dependentGloss': 'The',
#      'governor': 4,
#      'governorGloss': 'is'},
#     {'dep': 'nmod:poss',
#      'dependent': 2,
#      'dependentGloss': 'my',
#      'governor': 3,
#      'governorGloss': 'request'},
#     {'dep': 'dep',
#      'dependent': 3,
#      'dependentGloss': 'request',
#      'governor': 1,
#      'governorGloss': 'The'},
#     {'dep': 'mark',
#      'dependent': 5,
#      'dependentGloss': 'that',
#      'governor': 9,
#      'governorGloss': 'discuss'},
#     {'dep': 'det',
#      'dependent': 6,
#      'dependentGloss': 'the',
#      'governor': 8,
#      'governorGloss': 'politics'},
#     {'dep': 'amod',
#      'dependent': 7,
#      'dependentGloss': 'new',
#      'governor': 8,
#      'governorGloss': 'politics'},
#     {'dep': 'nsubj',
#      'dependent': 8,
#      'dependentGloss': 'politics',
#      'governor': 9,
#      'governorGloss': 'discuss'},
#     {'dep': 'ccomp',
#      'dependent': 9,
#      'dependentGloss': 'discuss',
#      'governor': 4,
#      'governorGloss': 'is'},
#     {'dep': 'case',
#      'dependent': 10,
#      'dependentGloss': 'about',
#      'governor': 12,
#      'governorGloss': 'problem'},
#     {'dep': 'det',
#      'dependent': 11,
#      'dependentGloss': 'this',
#      'governor': 12,
#      'governorGloss': 'problem'},
#     {'dep': 'nmod',
#      'dependent': 12,
#      'dependentGloss': 'problem',
#      'governor': 9,
#      'governorGloss': 'discuss'},
#     {'dep': 'punct',
#      'dependent': 13,
#      'dependentGloss': '.',
#      'governor': 4,
#      'governorGloss': 'is'}],
#    'enhancedDependencies': [{'dep': 'ROOT',
#      'dependent': 4,
#      'dependentGloss': 'is',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'nsubj',
#      'dependent': 1,
#      'dependentGloss': 'The',
#      'governor': 4,
#      'governorGloss': 'is'},
#     {'dep': 'nmod:poss',
#      'dependent': 2,
#      'dependentGloss': 'my',
#      'governor': 3,
#      'governorGloss': 'request'},
#     {'dep': 'dep',
#      'dependent': 3,
#      'dependentGloss': 'request',
#      'governor': 1,
#      'governorGloss': 'The'},
#     {'dep': 'mark',
#      'dependent': 5,
#      'dependentGloss': 'that',
#      'governor': 9,
#      'governorGloss': 'discuss'},
#     {'dep': 'det',
#      'dependent': 6,
#      'dependentGloss': 'the',
#      'governor': 8,
#      'governorGloss': 'politics'},
#     {'dep': 'amod',
#      'dependent': 7,
#      'dependentGloss': 'new',
#      'governor': 8,
#      'governorGloss': 'politics'},
#     {'dep': 'nsubj',
#      'dependent': 8,
#      'dependentGloss': 'politics',
#      'governor': 9,
#      'governorGloss': 'discuss'},
#     {'dep': 'ccomp',
#      'dependent': 9,
#      'dependentGloss': 'discuss',
#      'governor': 4,
#      'governorGloss': 'is'},
#     {'dep': 'case',
#      'dependent': 10,
#      'dependentGloss': 'about',
#      'governor': 12,
#      'governorGloss': 'problem'},
#     {'dep': 'det',
#      'dependent': 11,
#      'dependentGloss': 'this',
#      'governor': 12,
#      'governorGloss': 'problem'},
#     {'dep': 'nmod:about',
#      'dependent': 12,
#      'dependentGloss': 'problem',
#      'governor': 9,
#      'governorGloss': 'discuss'},
#     {'dep': 'punct',
#      'dependent': 13,
#      'dependentGloss': '.',
#      'governor': 4,
#      'governorGloss': 'is'}],
#    'enhancedPlusPlusDependencies': [{'dep': 'ROOT',
#      'dependent': 4,
#      'dependentGloss': 'is',
#      'governor': 0,
#      'governorGloss': 'ROOT'},
#     {'dep': 'nsubj',
#      'dependent': 1,
#      'dependentGloss': 'The',
#      'governor': 4,
#      'governorGloss': 'is'},
#     {'dep': 'nmod:poss',
#      'dependent': 2,
#      'dependentGloss': 'my',
#      'governor': 3,
#      'governorGloss': 'request'},
#     {'dep': 'dep',
#      'dependent': 3,
#      'dependentGloss': 'request',
#      'governor': 1,
#      'governorGloss': 'The'},
#     {'dep': 'mark',
#      'dependent': 5,
#      'dependentGloss': 'that',
#      'governor': 9,
#      'governorGloss': 'discuss'},
#     {'dep': 'det',
#      'dependent': 6,
#      'dependentGloss': 'the',
#      'governor': 8,
#      'governorGloss': 'politics'},
#     {'dep': 'amod',
#      'dependent': 7,
#      'dependentGloss': 'new',
#      'governor': 8,
#      'governorGloss': 'politics'},
#     {'dep': 'nsubj',
#      'dependent': 8,
#      'dependentGloss': 'politics',
#      'governor': 9,
#      'governorGloss': 'discuss'},
#     {'dep': 'ccomp',
#      'dependent': 9,
#      'dependentGloss': 'discuss',
#      'governor': 4,
#      'governorGloss': 'is'},
#     {'dep': 'case',
#      'dependent': 10,
#      'dependentGloss': 'about',
#      'governor': 12,
#      'governorGloss': 'problem'},
#     {'dep': 'det',
#      'dependent': 11,
#      'dependentGloss': 'this',
#      'governor': 12,
#      'governorGloss': 'problem'},
#     {'dep': 'nmod:about',
#      'dependent': 12,
#      'dependentGloss': 'problem',
#      'governor': 9,
#      'governorGloss': 'discuss'},
#     {'dep': 'punct',
#      'dependent': 13,
#      'dependentGloss': '.',
#      'governor': 4,
#      'governorGloss': 'is'}],
#    'index': 13,
#    'parse': '(ROOT\r\n  (S\r\n    (NP\r\n      (NP (DT The))\r\n      (NP (PRP$ my) (NN request)))\r\n    (VP (VBZ is)\r\n      (SBAR (IN that)\r\n        (S\r\n          (NP (DT the) (JJ new) (NNS politics))\r\n          (VP (VBP discuss)\r\n            (PP (IN about)\r\n              (NP (DT this) (NN problem)))))))\r\n    (. .)))',
#    'tokens': [{'after': ' ',
#      'before': '\n',
#      'characterOffsetBegin': 1635,
#      'characterOffsetEnd': 1638,
#      'index': 1,
#      'lemma': 'the',
#      'originalText': 'The',
#      'pos': 'DT',
#      'word': 'The'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1639,
#      'characterOffsetEnd': 1641,
#      'index': 2,
#      'lemma': 'my',
#      'originalText': 'my',
#      'pos': 'PRP$',
#      'word': 'my'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1642,
#      'characterOffsetEnd': 1649,
#      'index': 3,
#      'lemma': 'request',
#      'originalText': 'request',
#      'pos': 'NN',
#      'word': 'request'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1650,
#      'characterOffsetEnd': 1652,
#      'index': 4,
#      'lemma': 'be',
#      'originalText': 'is',
#      'pos': 'VBZ',
#      'word': 'is'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1653,
#      'characterOffsetEnd': 1657,
#      'index': 5,
#      'lemma': 'that',
#      'originalText': 'that',
#      'pos': 'IN',
#      'word': 'that'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1658,
#      'characterOffsetEnd': 1661,
#      'index': 6,
#      'lemma': 'the',
#      'originalText': 'the',
#      'pos': 'DT',
#      'word': 'the'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1662,
#      'characterOffsetEnd': 1665,
#      'index': 7,
#      'lemma': 'new',
#      'originalText': 'new',
#      'pos': 'JJ',
#      'word': 'new'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1666,
#      'characterOffsetEnd': 1674,
#      'index': 8,
#      'lemma': 'politics',
#      'originalText': 'politics',
#      'pos': 'NNS',
#      'word': 'politics'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1675,
#      'characterOffsetEnd': 1682,
#      'index': 9,
#      'lemma': 'discuss',
#      'originalText': 'discuss',
#      'pos': 'VBP',
#      'word': 'discuss'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1683,
#      'characterOffsetEnd': 1688,
#      'index': 10,
#      'lemma': 'about',
#      'originalText': 'about',
#      'pos': 'IN',
#      'word': 'about'},
#     {'after': ' ',
#      'before': ' ',
#      'characterOffsetBegin': 1689,
#      'characterOffsetEnd': 1693,
#      'index': 11,
#      'lemma': 'this',
#      'originalText': 'this',
#      'pos': 'DT',
#      'word': 'this'},
#     {'after': '',
#      'before': ' ',
#      'characterOffsetBegin': 1694,
#      'characterOffsetEnd': 1701,
#      'index': 12,
#      'lemma': 'problem',
#      'originalText': 'problem',
#      'pos': 'NN',
#      'word': 'problem'},
#     {'after': '',
#      'before': '',
#      'characterOffsetBegin': 1701,
#      'characterOffsetEnd': 1702,
#      'index': 13,
#      'lemma': '.',
#      'originalText': '.',
#      'pos': '.',
#      'word': '.'}]}]}

# %%
tag_set = pd.DataFrame()
pos_tags_list = list()
file_names = list()
essay_content = list()
sentences_indexes = list()
# Return an array of each word with its corresponding POS (word, POS, word_start_index, word_end_index, word_index, sentence_index)
post_tag_list = list()
for index, row in essay_key2.iterrows():
    result_count = pos_tags(pos_tagger, row['essay'])
    constituency_parsed = constituency_parsed_sentences[index]
    file_names.append(row['filename'])
    essay_content.append(row['essay'])
    pos_tags_list.append(result_count)
    sentences_indexes.append(get_sentence_indexes(constituency_parsed))
#result_count = pos_tags(pos_tagger, essay_key2['essay'][0], return_parse_obj=False)
#pos_tags_list.append(result_count)
tag_set['filename'] = file_names
tag_set['essay'] = essay_content
tag_set['pos'] = pos_tags_list
tag_set['sentece_indexes'] = sentences_indexes
tag_set
# Out:
#        filename                                              essay  \
# 0   1004355.txt  This is an important aspect of today time.\nTh...
# 1   1007363.txt  A geat challenge in a person's life span is hi...
# 2   1079196.txt  Personally, I agree with the statement saying ...
# 3   1086343.txt  In many country  their are many combanies of a...
# 4   1096747.txt  I disagree with this idea. in order to make a ...
# 5   1109085.txt  People often argue about what is more importan...
# 6   1164913.txt  Some tipes of advertisements use to make diffe...
# 7   1174920.txt  In my opinion people always should try new thi...
# 8   1181356.txt  We grow up in a society wich a has the mith of...
# 9   1223368.txt  Universities have considerably different educa...
# 10  1239289.txt  It is believed that young people nowadays do n...
# 11  1249928.txt  In my openion, I really disagree with make the...
# 12  1321982.txt  Of curse it is very important for students to ...
# 13  1346734.txt  Nowdays people use advertisement  to show thei...
# 14  1365003.txt  I concede that in some respects, the young sho...
# 15  1388870.txt  Some people want to try new things while other...
# 16  1392946.txt  Nowadays a lot of people like to take riks and...
# 17  1394540.txt  In the last fifty years the number of cars in ...
# 18  1414676.txt  In my opinion the usage of cars will stay at a...
# 19  1431839.txt  I completely agree with the statement 'most ad...
# 20  1447041.txt  I'm fully agreed that we should have broad kno...
# 21  1449555.txt  The issue at hand is whether advertisements ma...
# 22  1453563.txt  In a students' life, good learning is by study...
# 23  1469088.txt  Some people says that there will be fewer cars...
# 24  1599482.txt  To answer the question, if most advertisements...
# 25  1604419.txt  all of the worled intersting young people , bu...
# 26   162639.txt  In my personal opinion, it is true that most o...
# 27  1648484.txt  Most advertisements make products seem much be...
# 28  1691426.txt  when it comes to the statement of whether a pe...
# 29  1693042.txt  Young people enjoy life more than older people...
# ..          ...                                                ...
# 70   496928.txt  I'm agree with  "Young people nowdays do not g...
# 71   526827.txt  I think that is better to have broad knowledge...
# 72    52951.txt  With the different state between young people ...
# 73   535573.txt  Some people might believe that Learning the fa...
# 74   562823.txt  Products seem much better than they really are...
# 75   586583.txt  It is important for students to understand teo...
# 76   589458.txt  Advertising seems to has became a business tec...
# 77   594970.txt  In general I agree with this statement. The ta...
# 78   599905.txt  I do agree with the statement that young peopl...
# 79   609558.txt  I believe with the statement that "Young peopl...
# 80   618384.txt  It is admitted that the optimization of alread...
# 81   643139.txt  I disagree with the following statement which ...
# 82   644250.txt  Nobody can prodict the future but in mine opoi...
# 83   656695.txt  The very task and eventually also the goal of ...
# 84   661830.txt  I did not agree the following statement. I thi...
# 85    67346.txt  For my part, I do not think that young people ...
# 86   711394.txt  The use of cars has increased rapidly over the...
# 87    71654.txt  I dont believe that in twenty years there will...
# 88   716766.txt  Advertisements have become an important factor...
# 89   746257.txt  In fact some people think  that after twenty y...
# 90   749940.txt  I think less and less young people nowadays ta...
# 91   755753.txt  STUDENTS SHOULD RELY IN FACTS \n\t\t\tAND NOT ...
# 92   757891.txt  Many of us are eager to become successful peop...
# 93   806909.txt  Media has played a major role in Globalization...
# 94   832751.txt  Advertisements are everywhere.They can randoml...
# 95   844996.txt  I agree that that it is more difficult to assi...
# 96   871631.txt  I'm agree with the following statement: most a...
# 97   913996.txt  I disagree with the prior statement for severa...
# 98   937403.txt  Find the success\n\nWho is successful nowadays...
# 99   990384.txt  I dont think that in twenty years ther will be...
#
#                                                   pos  \
# 0   [[(This, DT, 0, 4, 1, 0, O), (is, VBZ, 5, 7, 2...
# 1   [[(A, DT, 0, 1, 1, 0, O), (geat, JJ, 2, 6, 2, ...
# 2   [[(Personally, RB, 0, 10, 1, 0, O), (,, ,, 10,...
# 3   [[(In, IN, 0, 2, 1, 0, O), (many, JJ, 3, 7, 2,...
# 4   [[(I, PRP, 0, 1, 1, 0, O), (disagree, VBP, 2, ...
# 5   [[(People, NNS, 0, 6, 1, 0, O), (often, RB, 7,...
# 6   [[(Some, DT, 0, 4, 1, 0, O), (tipes, NNS, 5, 1...
# 7   [[(In, IN, 0, 2, 1, 0, O), (my, PRP$, 3, 5, 2,...
# 8   [[(We, PRP, 0, 2, 1, 0, O), (grow, VBP, 3, 7, ...
# 9   [[(Universities, NNS, 0, 12, 1, 0, O), (have, ...
# 10  [[(It, PRP, 0, 2, 1, 0, O), (is, VBZ, 3, 5, 2,...
# 11  [[(In, IN, 0, 2, 1, 0, O), (my, PRP$, 3, 5, 2,...
# 12  [[(Of, IN, 0, 2, 1, 0, O), (curse, NN, 3, 8, 2...
# 13  [[(Nowdays, NNP, 0, 7, 1, 0, O), (people, NNS,...
# 14  [[(I, PRP, 0, 1, 1, 0, O), (concede, VBP, 2, 9...
# 15  [[(Some, DT, 0, 4, 1, 0, O), (people, NNS, 5, ...
# 16  [[(Nowadays, RB, 0, 8, 1, 0, O), (a, DT, 9, 10...
# 17  [[(In, IN, 0, 2, 1, 0, O), (the, DT, 3, 6, 2, ...
# 18  [[(In, IN, 0, 2, 1, 0, O), (my, PRP$, 3, 5, 2,...
# 19  [[(I, PRP, 0, 1, 1, 0, O), (completely, RB, 2,...
# 20  [[(I, PRP, 0, 1, 1, 0, O), ('m, VBP, 1, 3, 2, ...
# 21  [[(The, DT, 0, 3, 1, 0, O), (issue, NN, 4, 9, ...
# 22  [[(In, IN, 0, 2, 1, 0, O), (a, DT, 3, 4, 2, 0,...
# 23  [[(Some, DT, 0, 4, 1, 0, O), (people, NNS, 5, ...
# 24  [[(To, TO, 0, 2, 1, 0, O), (answer, VB, 3, 9, ...
# 25  [[(all, DT, 0, 3, 1, 0, O), (of, IN, 4, 6, 2, ...
# 26  [[(In, IN, 0, 2, 1, 0, O), (my, PRP$, 3, 5, 2,...
# 27  [[(Most, JJS, 0, 4, 1, 0, O), (advertisements,...
# 28  [[(when, WRB, 0, 4, 1, 0, O), (it, PRP, 5, 7, ...
# 29  [[(Young, JJ, 0, 5, 1, 0, O), (people, NNS, 6,...
# ..                                                ...
# 70  [[(I, PRP, 0, 1, 1, 0, O), ('m, VBP, 1, 3, 2, ...
# 71  [[(I, PRP, 0, 1, 1, 0, O), (think, VBP, 2, 7, ...
# 72  [[(With, IN, 0, 4, 1, 0, O), (the, DT, 5, 8, 2...
# 73  [[(Some, DT, 0, 4, 1, 0, O), (people, NNS, 5, ...
# 74  [[(Products, NNPS, 0, 8, 1, 0, O), (seem, VBP,...
# 75  [[(It, PRP, 0, 2, 1, 0, O), (is, VBZ, 3, 5, 2,...
# 76  [[(Advertising, NN, 0, 11, 1, 0, O), (seems, V...
# 77  [[(In, IN, 0, 2, 1, 0, O), (general, JJ, 3, 10...
# 78  [[(I, PRP, 0, 1, 1, 0, O), (do, VBP, 2, 4, 2, ...
# 79  [[(I, PRP, 0, 1, 1, 0, O), (believe, VBP, 2, 9...
# 80  [[(It, PRP, 0, 2, 1, 0, O), (is, VBZ, 3, 5, 2,...
# 81  [[(I, PRP, 0, 1, 1, 0, O), (disagree, VBP, 2, ...
# 82  [[(Nobody, NN, 0, 6, 1, 0, O), (can, MD, 7, 10...
# 83  [[(The, DT, 0, 3, 1, 0, O), (very, RB, 4, 8, 2...
# 84  [[(I, PRP, 0, 1, 1, 0, O), (did, VBD, 2, 5, 2,...
# 85  [[(For, IN, 0, 3, 1, 0, O), (my, PRP$, 4, 6, 2...
# 86  [[(The, DT, 0, 3, 1, 0, O), (use, NN, 4, 7, 2,...
# 87  [[(I, PRP, 0, 1, 1, 0, O), (dont, VBP, 2, 6, 2...
# 88  [[(Advertisements, NNS, 0, 14, 1, 0, O), (have...
# 89  [[(In, IN, 0, 2, 1, 0, O), (fact, NN, 3, 7, 2,...
# 90  [[(I, PRP, 0, 1, 1, 0, O), (think, VBP, 2, 7, ...
# 91  [[(STUDENTS, NNS, 0, 8, 1, 0, O), (SHOULD, MD,...
# 92  [[(Many, JJ, 0, 4, 1, 0, O), (of, IN, 5, 7, 2,...
# 93  [[(Media, NNP, 0, 5, 1, 0, O), (has, VBZ, 6, 9...
# 94  [[(Advertisements, NNS, 0, 14, 1, 0, O), (are,...
# 95  [[(I, PRP, 0, 1, 1, 0, O), (agree, VBP, 2, 7, ...
# 96  [[(I, PRP, 0, 1, 1, 0, O), ('m, VBP, 1, 3, 2, ...
# 97  [[(I, PRP, 0, 1, 1, 0, O), (disagree, VBP, 2, ...
# 98  [[(Find, VB, 0, 4, 1, 0, O), (the, DT, 5, 8, 2...
# 99  [[(I, PRP, 0, 1, 1, 0, O), (dont, VBP, 2, 6, 2...
#
#                                       sentece_indexes
# 0   [(0, 0, 42), (1, 43, 236), (2, 237, 359), (3, ...
# 1   [(0, 0, 115), (1, 116, 148), (2, 149, 277), (3...
# 2   [(0, 0, 123), (1, 125, 191), (2, 192, 365), (3...
# 3   [(0, 0, 66), (1, 67, 113), (2, 115, 223), (3, ...
# 4   [(0, 0, 26), (1, 27, 137), (2, 138, 217), (3, ...
# 5   [(0, 0, 100), (1, 101, 242), (2, 243, 326), (3...
# 6   [(0, 0, 149), (1, 151, 171), (2, 172, 190), (3...
# 7   [(0, 0, 162), (1, 163, 337), (2, 338, 560), (3...
# 8   [(0, 0, 61), (1, 63, 193), (2, 195, 275), (3, ...
# 9   [(0, 0, 61), (1, 62, 179), (2, 180, 318), (3, ...
# 10  [(0, 0, 100), (1, 101, 197), (2, 199, 321), (3...
# 11  [(0, 0, 165), (1, 169, 266), (2, 267, 352), (3...
# 12                        [(0, 0, 96), (1, 97, 1061)]
# 13  [(0, 0, 136), (1, 137, 215), (2, 216, 261), (3...
# 14  [(0, 0, 109), (1, 110, 297), (2, 303, 385), (3...
# 15  [(0, 0, 104), (1, 106, 231), (2, 233, 267), (3...
# 16  [(0, 0, 68), (1, 69, 110), (2, 111, 228), (3, ...
# 17  [(0, 0, 132), (1, 133, 296), (2, 297, 470), (3...
# 18  [(0, 0, 77), (1, 78, 237), (2, 239, 371), (3, ...
# 19  [(0, 0, 112), (1, 113, 177), (2, 179, 268), (3...
# 20  [(0, 0, 123), (1, 124, 235), (2, 245, 365), (3...
# 21  [(0, 0, 98), (1, 99, 199), (2, 200, 278), (3, ...
# 22  [(0, 0, 69), (1, 70, 158), (2, 159, 291), (3, ...
# 23  [(0, 0, 144), (1, 145, 347), (2, 348, 562), (3...
# 24  [(0, 0, 129), (1, 130, 361), (2, 362, 424), (3...
# 25        [(0, 0, 143), (1, 144, 321), (2, 322, 448)]
# 26  [(0, 0, 127), (1, 128, 190), (2, 191, 298), (3...
# 27  [(0, 0, 72), (1, 73, 187), (2, 188, 309), (3, ...
# 28  [(0, 0, 222), (1, 223, 294), (2, 300, 418), (3...
# 29  [(0, 0, 50), (1, 51, 120), (2, 121, 241), (3, ...
# ..                                                ...
# 70  [(0, 0, 93), (1, 94, 147), (2, 149, 204), (3, ...
# 71  [(0, 0, 109), (1, 110, 176), (2, 177, 234), (3...
# 72  [(0, 0, 121), (1, 122, 232), (2, 233, 342), (3...
# 73  [(0, 0, 80), (1, 81, 230), (2, 231, 307), (3, ...
# 74  [(0, 0, 47), (1, 48, 160), (2, 161, 251), (3, ...
# 75  [(0, 0, 170), (1, 171, 308), (2, 309, 446), (3...
# 76  [(0, 0, 146), (1, 147, 276), (2, 284, 573), (3...
# 77  [(0, 0, 39), (1, 40, 165), (2, 166, 329), (3, ...
# 78  [(0, 0, 93), (1, 94, 212), (2, 213, 320), (3, ...
# 79  [(0, 0, 112), (1, 113, 287), (2, 288, 340), (3...
# 80  [(0, 0, 83), (1, 84, 220), (2, 223, 318), (3, ...
# 81  [(0, 0, 145), (1, 146, 189), (2, 194, 309), (3...
# 82  [(0, 0, 148), (1, 149, 341), (2, 346, 575), (3...
# 83  [(0, 0, 190), (1, 191, 378), (2, 379, 541), (3...
# 84  [(0, 0, 40), (1, 41, 94), (2, 95, 156), (3, 15...
# 85  [(0, 0, 80), (1, 81, 177), (2, 180, 250), (3, ...
# 86  [(0, 0, 62), (1, 63, 125), (2, 126, 225), (3, ...
# 87  [(0, 0, 89), (1, 90, 121), (2, 148, 224), (3, ...
# 88  [(0, 0, 89), (1, 90, 188), (2, 189, 256), (3, ...
# 89  [(0, 0, 105), (1, 106, 215), (2, 217, 320), (3...
# 90  [(0, 0, 181), (1, 183, 308), (2, 309, 444), (3...
# 91  [(0, 0, 167), (1, 168, 255), (2, 256, 313), (3...
# 92  [(0, 0, 49), (1, 50, 116), (2, 117, 183), (3, ...
# 93  [(0, 0, 47), (1, 49, 165), (2, 166, 234), (3, ...
# 94  [(0, 0, 148), (1, 149, 298), (2, 299, 432), (3...
# 95  [(0, 0, 106), (1, 107, 231), (2, 234, 402), (3...
# 96  [(0, 0, 209), (1, 210, 285), (2, 286, 543), (3...
# 97  [(0, 0, 56), (1, 57, 148), (2, 149, 209), (3, ...
# 98  [(0, 0, 45), (1, 46, 75), (2, 77, 151), (3, 15...
# 99  [(0, 0, 115), (1, 116, 259), (2, 260, 425), (3...
#
# [100 rows x 4 columns]

# %%
pronouns_POS_list = ['PRP','PRP$','WP','WP$']
third_pronouns_list = ['he','him','his','his','himself','she','her','her','hers','herself','it','it','its','itself','they','them','their','theirs','themselves']
pronouns_list = list()
    
for index, rows in tag_set.iterrows():
    aux_pronouns = list()
    for sentence in rows['pos']:
        for w_tuple in sentence:
            if w_tuple[1] in pronouns_POS_list:
                aux_pronouns.append(w_tuple)
    pronouns_list.append([x for x in aux_pronouns if x[0].lower() in third_pronouns_list])
tag_set['third_person_pronouns'] = pronouns_list               
# filter non third person pronouns
#filtered_list = [x for x in pronouns_list if x[0].lower() in third_pronouns_list]
#filtered_list

# %%
tag_set
# Out:
#        filename                                              essay  \
# 0   1004355.txt  This is an important aspect of today time.\nTh...
# 1   1007363.txt  A geat challenge in a person's life span is hi...
# 2   1079196.txt  Personally, I agree with the statement saying ...
# 3   1086343.txt  In many country  their are many combanies of a...
# 4   1096747.txt  I disagree with this idea. in order to make a ...
# 5   1109085.txt  People often argue about what is more importan...
# 6   1164913.txt  Some tipes of advertisements use to make diffe...
# 7   1174920.txt  In my opinion people always should try new thi...
# 8   1181356.txt  We grow up in a society wich a has the mith of...
# 9   1223368.txt  Universities have considerably different educa...
# 10  1239289.txt  It is believed that young people nowadays do n...
# 11  1249928.txt  In my openion, I really disagree with make the...
# 12  1321982.txt  Of curse it is very important for students to ...
# 13  1346734.txt  Nowdays people use advertisement  to show thei...
# 14  1365003.txt  I concede that in some respects, the young sho...
# 15  1388870.txt  Some people want to try new things while other...
# 16  1392946.txt  Nowadays a lot of people like to take riks and...
# 17  1394540.txt  In the last fifty years the number of cars in ...
# 18  1414676.txt  In my opinion the usage of cars will stay at a...
# 19  1431839.txt  I completely agree with the statement 'most ad...
# 20  1447041.txt  I'm fully agreed that we should have broad kno...
# 21  1449555.txt  The issue at hand is whether advertisements ma...
# 22  1453563.txt  In a students' life, good learning is by study...
# 23  1469088.txt  Some people says that there will be fewer cars...
# 24  1599482.txt  To answer the question, if most advertisements...
# 25  1604419.txt  all of the worled intersting young people , bu...
# 26   162639.txt  In my personal opinion, it is true that most o...
# 27  1648484.txt  Most advertisements make products seem much be...
# 28  1691426.txt  when it comes to the statement of whether a pe...
# 29  1693042.txt  Young people enjoy life more than older people...
# ..          ...                                                ...
# 70   496928.txt  I'm agree with  "Young people nowdays do not g...
# 71   526827.txt  I think that is better to have broad knowledge...
# 72    52951.txt  With the different state between young people ...
# 73   535573.txt  Some people might believe that Learning the fa...
# 74   562823.txt  Products seem much better than they really are...
# 75   586583.txt  It is important for students to understand teo...
# 76   589458.txt  Advertising seems to has became a business tec...
# 77   594970.txt  In general I agree with this statement. The ta...
# 78   599905.txt  I do agree with the statement that young peopl...
# 79   609558.txt  I believe with the statement that "Young peopl...
# 80   618384.txt  It is admitted that the optimization of alread...
# 81   643139.txt  I disagree with the following statement which ...
# 82   644250.txt  Nobody can prodict the future but in mine opoi...
# 83   656695.txt  The very task and eventually also the goal of ...
# 84   661830.txt  I did not agree the following statement. I thi...
# 85    67346.txt  For my part, I do not think that young people ...
# 86   711394.txt  The use of cars has increased rapidly over the...
# 87    71654.txt  I dont believe that in twenty years there will...
# 88   716766.txt  Advertisements have become an important factor...
# 89   746257.txt  In fact some people think  that after twenty y...
# 90   749940.txt  I think less and less young people nowadays ta...
# 91   755753.txt  STUDENTS SHOULD RELY IN FACTS \n\t\t\tAND NOT ...
# 92   757891.txt  Many of us are eager to become successful peop...
# 93   806909.txt  Media has played a major role in Globalization...
# 94   832751.txt  Advertisements are everywhere.They can randoml...
# 95   844996.txt  I agree that that it is more difficult to assi...
# 96   871631.txt  I'm agree with the following statement: most a...
# 97   913996.txt  I disagree with the prior statement for severa...
# 98   937403.txt  Find the success\n\nWho is successful nowadays...
# 99   990384.txt  I dont think that in twenty years ther will be...
#
#                                                   pos  \
# 0   [[(This, DT, 0, 4, 1, 0), (is, VBZ, 5, 7, 2, 0...
# 1   [[(A, DT, 0, 1, 1, 0), (geat, JJ, 2, 6, 2, 0),...
# 2   [[(Personally, RB, 0, 10, 1, 0), (,, ,, 10, 11...
# 3   [[(In, IN, 0, 2, 1, 0), (many, JJ, 3, 7, 2, 0)...
# 4   [[(I, PRP, 0, 1, 1, 0), (disagree, VBP, 2, 10,...
# 5   [[(People, NNS, 0, 6, 1, 0), (often, RB, 7, 12...
# 6   [[(Some, DT, 0, 4, 1, 0), (tipes, NNS, 5, 10, ...
# 7   [[(In, IN, 0, 2, 1, 0), (my, PRP$, 3, 5, 2, 0)...
# 8   [[(We, PRP, 0, 2, 1, 0), (grow, VBP, 3, 7, 2, ...
# 9   [[(Universities, NNS, 0, 12, 1, 0), (have, VBP...
# 10  [[(It, PRP, 0, 2, 1, 0), (is, VBZ, 3, 5, 2, 0)...
# 11  [[(In, IN, 0, 2, 1, 0), (my, PRP$, 3, 5, 2, 0)...
# 12  [[(Of, IN, 0, 2, 1, 0), (curse, NN, 3, 8, 2, 0...
# 13  [[(Nowdays, NNP, 0, 7, 1, 0), (people, NNS, 8,...
# 14  [[(I, PRP, 0, 1, 1, 0), (concede, VBP, 2, 9, 2...
# 15  [[(Some, DT, 0, 4, 1, 0), (people, NNS, 5, 11,...
# 16  [[(Nowadays, RB, 0, 8, 1, 0), (a, DT, 9, 10, 2...
# 17  [[(In, IN, 0, 2, 1, 0), (the, DT, 3, 6, 2, 0),...
# 18  [[(In, IN, 0, 2, 1, 0), (my, PRP$, 3, 5, 2, 0)...
# 19  [[(I, PRP, 0, 1, 1, 0), (completely, RB, 2, 12...
# 20  [[(I, PRP, 0, 1, 1, 0), ('m, VBP, 1, 3, 2, 0),...
# 21  [[(The, DT, 0, 3, 1, 0), (issue, NN, 4, 9, 2, ...
# 22  [[(In, IN, 0, 2, 1, 0), (a, DT, 3, 4, 2, 0), (...
# 23  [[(Some, DT, 0, 4, 1, 0), (people, NNS, 5, 11,...
# 24  [[(To, TO, 0, 2, 1, 0), (answer, VB, 3, 9, 2, ...
# 25  [[(all, DT, 0, 3, 1, 0), (of, IN, 4, 6, 2, 0),...
# 26  [[(In, IN, 0, 2, 1, 0), (my, PRP$, 3, 5, 2, 0)...
# 27  [[(Most, JJS, 0, 4, 1, 0), (advertisements, NN...
# 28  [[(when, WRB, 0, 4, 1, 0), (it, PRP, 5, 7, 2, ...
# 29  [[(Young, JJ, 0, 5, 1, 0), (people, NNS, 6, 12...
# ..                                                ...
# 70  [[(I, PRP, 0, 1, 1, 0), ('m, VBP, 1, 3, 2, 0),...
# 71  [[(I, PRP, 0, 1, 1, 0), (think, VBP, 2, 7, 2, ...
# 72  [[(With, IN, 0, 4, 1, 0), (the, DT, 5, 8, 2, 0...
# 73  [[(Some, DT, 0, 4, 1, 0), (people, NNS, 5, 11,...
# 74  [[(Products, NNPS, 0, 8, 1, 0), (seem, VBP, 9,...
# 75  [[(It, PRP, 0, 2, 1, 0), (is, VBZ, 3, 5, 2, 0)...
# 76  [[(Advertising, NN, 0, 11, 1, 0), (seems, VBZ,...
# 77  [[(In, IN, 0, 2, 1, 0), (general, JJ, 3, 10, 2...
# 78  [[(I, PRP, 0, 1, 1, 0), (do, VBP, 2, 4, 2, 0),...
# 79  [[(I, PRP, 0, 1, 1, 0), (believe, VBP, 2, 9, 2...
# 80  [[(It, PRP, 0, 2, 1, 0), (is, VBZ, 3, 5, 2, 0)...
# 81  [[(I, PRP, 0, 1, 1, 0), (disagree, VBP, 2, 10,...
# 82  [[(Nobody, NN, 0, 6, 1, 0), (can, MD, 7, 10, 2...
# 83  [[(The, DT, 0, 3, 1, 0), (very, RB, 4, 8, 2, 0...
# 84  [[(I, PRP, 0, 1, 1, 0), (did, VBD, 2, 5, 2, 0)...
# 85  [[(For, IN, 0, 3, 1, 0), (my, PRP$, 4, 6, 2, 0...
# 86  [[(The, DT, 0, 3, 1, 0), (use, NN, 4, 7, 2, 0)...
# 87  [[(I, PRP, 0, 1, 1, 0), (dont, VBP, 2, 6, 2, 0...
# 88  [[(Advertisements, NNS, 0, 14, 1, 0), (have, V...
# 89  [[(In, IN, 0, 2, 1, 0), (fact, NN, 3, 7, 2, 0)...
# 90  [[(I, PRP, 0, 1, 1, 0), (think, VBP, 2, 7, 2, ...
# 91  [[(STUDENTS, NNS, 0, 8, 1, 0), (SHOULD, MD, 9,...
# 92  [[(Many, JJ, 0, 4, 1, 0), (of, IN, 5, 7, 2, 0)...
# 93  [[(Media, NNP, 0, 5, 1, 0), (has, VBZ, 6, 9, 2...
# 94  [[(Advertisements, NNS, 0, 14, 1, 0), (are, VB...
# 95  [[(I, PRP, 0, 1, 1, 0), (agree, VBP, 2, 7, 2, ...
# 96  [[(I, PRP, 0, 1, 1, 0), ('m, VBP, 1, 3, 2, 0),...
# 97  [[(I, PRP, 0, 1, 1, 0), (disagree, VBP, 2, 10,...
# 98  [[(Find, VB, 0, 4, 1, 0), (the, DT, 5, 8, 2, 0...
# 99  [[(I, PRP, 0, 1, 1, 0), (dont, VBP, 2, 6, 2, 0...
#
#                                       sentece_indexes  \
# 0   [(0, 0, 42), (1, 43, 236), (2, 237, 359), (3, ...
# 1   [(0, 0, 115), (1, 116, 148), (2, 149, 277), (3...
# 2   [(0, 0, 123), (1, 125, 191), (2, 192, 365), (3...
# 3   [(0, 0, 66), (1, 67, 113), (2, 115, 223), (3, ...
# 4   [(0, 0, 26), (1, 27, 137), (2, 138, 217), (3, ...
# 5   [(0, 0, 100), (1, 101, 242), (2, 243, 326), (3...
# 6   [(0, 0, 149), (1, 151, 171), (2, 172, 190), (3...
# 7   [(0, 0, 162), (1, 163, 337), (2, 338, 560), (3...
# 8   [(0, 0, 61), (1, 63, 193), (2, 195, 275), (3, ...
# 9   [(0, 0, 61), (1, 62, 179), (2, 180, 318), (3, ...
# 10  [(0, 0, 100), (1, 101, 197), (2, 199, 321), (3...
# 11  [(0, 0, 165), (1, 169, 266), (2, 267, 352), (3...
# 12                        [(0, 0, 96), (1, 97, 1061)]
# 13  [(0, 0, 136), (1, 137, 215), (2, 216, 261), (3...
# 14  [(0, 0, 109), (1, 110, 297), (2, 303, 385), (3...
# 15  [(0, 0, 104), (1, 106, 231), (2, 233, 267), (3...
# 16  [(0, 0, 68), (1, 69, 110), (2, 111, 228), (3, ...
# 17  [(0, 0, 132), (1, 133, 296), (2, 297, 470), (3...
# 18  [(0, 0, 77), (1, 78, 237), (2, 239, 371), (3, ...
# 19  [(0, 0, 112), (1, 113, 177), (2, 179, 268), (3...
# 20  [(0, 0, 123), (1, 124, 235), (2, 245, 365), (3...
# 21  [(0, 0, 98), (1, 99, 199), (2, 200, 278), (3, ...
# 22  [(0, 0, 69), (1, 70, 158), (2, 159, 291), (3, ...
# 23  [(0, 0, 144), (1, 145, 347), (2, 348, 562), (3...
# 24  [(0, 0, 129), (1, 130, 361), (2, 362, 424), (3...
# 25        [(0, 0, 143), (1, 144, 321), (2, 322, 448)]
# 26  [(0, 0, 127), (1, 128, 190), (2, 191, 298), (3...
# 27  [(0, 0, 72), (1, 73, 187), (2, 188, 309), (3, ...
# 28  [(0, 0, 222), (1, 223, 294), (2, 300, 418), (3...
# 29  [(0, 0, 50), (1, 51, 120), (2, 121, 241), (3, ...
# ..                                                ...
# 70  [(0, 0, 93), (1, 94, 147), (2, 149, 204), (3, ...
# 71  [(0, 0, 109), (1, 110, 176), (2, 177, 234), (3...
# 72  [(0, 0, 121), (1, 122, 232), (2, 233, 342), (3...
# 73  [(0, 0, 80), (1, 81, 230), (2, 231, 307), (3, ...
# 74  [(0, 0, 47), (1, 48, 160), (2, 161, 251), (3, ...
# 75  [(0, 0, 170), (1, 171, 308), (2, 309, 446), (3...
# 76  [(0, 0, 146), (1, 147, 276), (2, 284, 573), (3...
# 77  [(0, 0, 39), (1, 40, 165), (2, 166, 329), (3, ...
# 78  [(0, 0, 93), (1, 94, 212), (2, 213, 320), (3, ...
# 79  [(0, 0, 112), (1, 113, 287), (2, 288, 340), (3...
# 80  [(0, 0, 83), (1, 84, 220), (2, 223, 318), (3, ...
# 81  [(0, 0, 145), (1, 146, 189), (2, 194, 309), (3...
# 82  [(0, 0, 148), (1, 149, 341), (2, 346, 575), (3...
# 83  [(0, 0, 190), (1, 191, 378), (2, 379, 541), (3...
# 84  [(0, 0, 40), (1, 41, 94), (2, 95, 156), (3, 15...
# 85  [(0, 0, 80), (1, 81, 177), (2, 180, 250), (3, ...
# 86  [(0, 0, 62), (1, 63, 125), (2, 126, 225), (3, ...
# 87  [(0, 0, 89), (1, 90, 121), (2, 148, 224), (3, ...
# 88  [(0, 0, 89), (1, 90, 188), (2, 189, 256), (3, ...
# 89  [(0, 0, 105), (1, 106, 215), (2, 217, 320), (3...
# 90  [(0, 0, 181), (1, 183, 308), (2, 309, 444), (3...
# 91  [(0, 0, 167), (1, 168, 255), (2, 256, 313), (3...
# 92  [(0, 0, 49), (1, 50, 116), (2, 117, 183), (3, ...
# 93  [(0, 0, 47), (1, 49, 165), (2, 166, 234), (3, ...
# 94  [(0, 0, 148), (1, 149, 298), (2, 299, 432), (3...
# 95  [(0, 0, 106), (1, 107, 231), (2, 234, 402), (3...
# 96  [(0, 0, 209), (1, 210, 285), (2, 286, 543), (3...
# 97  [(0, 0, 56), (1, 57, 148), (2, 149, 209), (3, ...
# 98  [(0, 0, 45), (1, 46, 75), (2, 77, 151), (3, 15...
# 99  [(0, 0, 115), (1, 116, 259), (2, 260, 425), (3...
#
#                                 third_person_pronouns
# 0                                                  []
# 1   [(his, PRP$, 44, 47, 11, 0), (them, PRP, 620, ...
# 2   [(they, PRP, 107, 111, 18, 0), (their, PRP$, 2...
# 3   [(their, PRP$, 17, 22, 4, 0), (their, PRP$, 12...
# 4   [(they, PRP, 114, 118, 20, 1), (they, PRP, 153...
# 5   [(it, PRP, 176, 178, 16, 1), (their, PRP$, 409...
# 6   [(them, PRP, 74, 78, 15, 0), (it, PRP, 91, 93,...
# 7   [(themselves, PRP, 102, 112, 18, 0), (they, PR...
# 8   [(it, PRP, 410, 412, 8, 4), (it, PRP, 632, 634...
# 9   [(it, PRP, 295, 297, 20, 2), (them, PRP, 313, ...
# 10  [(It, PRP, 0, 2, 1, 0), (their, PRP$, 82, 87, ...
# 11  [(they, PRP, 78, 82, 16, 0), (it, PRP, 102, 10...
# 12  [(it, PRP, 9, 11, 3, 0), (they, PRP, 254, 258,...
# 13  [(their, PRP$, 42, 47, 7, 0), (it, PRP, 77, 79...
# 14  [(their, PRP$, 64, 69, 13, 0), (they, PRP, 96,...
# 15  [(they, PRP, 74, 78, 16, 0), (their, PRP$, 93,...
# 16  [(their, PRP$, 52, 57, 12, 0), (their, PRP$, 9...
# 17  [(his, PRP$, 214, 217, 15, 1), (their, PRP$, 5...
# 18                [(their, PRP$, 1787, 1792, 13, 19)]
# 19  [(they, PRP, 95, 99, 16, 0), (they, PRP, 425, ...
# 20  [(it, PRP, 163, 165, 9, 1), (it, PRP, 1104, 11...
# 21  [(they, PRP, 75, 79, 13, 0), (they, PRP, 262, ...
# 22  [(his, PRP$, 113, 116, 10, 1), (his, PRP$, 396...
# 23  [(they, PRP, 426, 430, 12, 2), (their, PRP$, 5...
# 24  [(they, PRP, 78, 82, 14, 0), (them, PRP, 197, ...
# 25  [(him, PRP, 264, 267, 24, 1), (his, PRP$, 436,...
# 26  [(it, PRP, 24, 26, 6, 0), (their, PRP$, 109, 1...
# 27  [(they, PRP, 56, 60, 9, 0), (their, PRP$, 176,...
# 28  [(it, PRP, 5, 7, 2, 0), (their, PRP$, 82, 87, ...
# 29  [(its, PRP$, 171, 174, 10, 2), (his, PRP$, 929...
# ..                                                ...
# 70  [(their, PRP$, 74, 79, 16, 0), (it, PRP, 196, ...
# 71                     [(them, PRP, 351, 355, 20, 3)]
# 72  [(they, PRP, 74, 78, 14, 0), (they, PRP, 300, ...
# 73  [(it, PRP, 128, 130, 9, 1), (it, PRP, 200, 202...
# 74  [(they, PRP, 31, 35, 6, 0), (their, PRP$, 140,...
# 75  [(It, PRP, 0, 2, 1, 0), (they, PRP, 93, 97, 18...
# 76  [(they, PRP, 788, 792, 18, 4), (them, PRP, 963...
# 77  [(they, PRP, 237, 241, 13, 2), (his, PRP$, 129...
# 78  [(their, PRP$, 343, 348, 5, 3), (they, PRP, 42...
# 79  [(their, PRP$, 93, 98, 18, 0), (their, PRP$, 1...
# 80  [(It, PRP, 0, 2, 1, 0), (it, PRP, 347, 349, 8,...
# 81  [(it, PRP, 115, 117, 19, 0), (them, PRP, 125, ...
# 82  [(its, PRP$, 242, 245, 17, 1), (they, PRP, 375...
# 83  [(it, PRP, 64, 66, 12, 0), (it, PRP, 118, 120,...
# 84  [(They, PRP, 421, 425, 1, 6), (they, PRP, 455,...
# 85  [(their, PRP$, 52, 57, 13, 0), (their, PRP$, 3...
# 86  [(his, PRP$, 85, 88, 4, 1), (their, PRP$, 453,...
# 87  [(their, PRP$, 250, 255, 7, 3), (They, PRP, 29...
# 88  [(it, PRP, 185, 187, 21, 1), (its, PRP$, 415, ...
# 89  [(them, PRP, 114, 118, 3, 1), (they, PRP, 370,...
# 90  [(their, PRP$, 62, 67, 13, 0), (they, PRP, 129...
# 91  [(his, PRP$, 369, 372, 12, 3), (it, PRP, 424, ...
# 92  [(They, PRP, 117, 121, 1, 2), (His, PRP$, 380,...
# 93  [(It, PRP, 49, 51, 1, 1), (its, PRP$, 289, 292...
# 94  [(them, PRP, 260, 264, 25, 1), (it, PRP, 361, ...
# 95  [(it, PRP, 18, 20, 5, 0), (it, PRP, 103, 105, ...
# 96  [(they, PRP, 96, 100, 17, 0), (they, PRP, 356,...
# 97  [(it, PRP, 152, 154, 2, 2), (it, PRP, 490, 492...
# 98  [(they, PRP, 344, 348, 39, 3), (it, PRP, 590, ...
# 99  [(it, PRP, 146, 148, 7, 1), (their, PRP$, 480,...
#
# [100 rows x 5 columns]

# %%
def check_coherence(pronoun_tuple, lookup_sentences):
    # Pronoun list to check
    third_singular_person = ['he', 'she', 'his', 'her']
    third_plural_person = ['they', 'them', 'their']
    referencing_singular_pos = ['NN', 'NNP']
    referencing_plural_pos = ['NNS', 'NNPS']
    pronoun = pronoun_tuple[0]
    result = True
    """
    For singular third person pronouns and possessives he/she/his/her, 
    check the existence of appropriate male/female antecedents as mentioned earlier.
    
    For  plural  third  person  pronouns  and  possessivesthey/them/their,  
    check  if  there  are  possible  antecedents:
    """
    #print(lookup_sentences)
    if pronoun.lower() in third_singular_person:
        #print("For singular third person pronouns and possessives he/she/his/her")
        # Remove all words that do not serve as a possible referencing word
        filtered_words = filter_nouns(lookup_sentences, 'singular')
        if len(filtered_words)<=0:
            print("ERROR, POSSIBLE SINGULAR ANTECEDENT NOT FOUND!")
            result = False
        elif pronoun.lower() == 'he':
            # female or neutral and inanimate
            # check if it is a person or not
            for possible_antecedent in filtered_words:
                if person_and_gender(possible_antecedent)[0]:
                    result = True
                    return result
            print("GENDER DOES NOT MATCH WITH PRONOUN HE")
            result = False
        elif pronoun.lower() == 'she':
            for possible_antecedent in filtered_words:
                if person_and_gender(possible_antecedent)[0]:
                    result = True
                    return result
            print("GENDER DOES NOT MATCH WITH PRONOUN SHE")
            result = False
        
        # Check for male female antecedents in sentences
       
    elif pronoun.lower() in third_plural_person:
        #print("For  plural  third  person  pronouns  and  possessives they/them/their")
        filtered_words = filter_nouns(lookup_sentences, 'plural')
        if len(filtered_words)<=0 :
            filtered_words = filter_nouns(lookup_sentences, 'singular')
            if len(filtered_words)<=0:
                print("ERROR, POSSIBLE ANTECEDENT NOT FOUND!")
                result = False
            elif len(filtered_words) < 2:
                print("NOT ENOUGH SINGULAR NPs TO SERVE AS A PLURAL REFERENCING")
                result = False
        else:
            possible_antecedents = dict()
            words = list()
            for possible_antecedent in filtered_words:
                if possible_antecedent[5] not in possible_antecedents:
                    possible_antecedents[possible_antecedent[5]] = 0
                possible_antecedents[possible_antecedent[5]] = possible_antecedents[possible_antecedent[5]] + 1;
                words.append(possible_antecedent[0])
                
            sentence_id = pronoun_tuple[5]    
            for x in range(0, 3):
                # Check the possible antecedents
                if sentence_id in possible_antecedents:
                    if possible_antecedents[sentence_id] > 2:
                        print("Possible Ambiguity, 3 or more Nouns".upper())
                        result = False
                        break
                    elif possible_antecedents[sentence_id] == 1:
                        result = True
                        break
                    elif possible_antecedents[sentence_id] > 1 and x==0:
                        result = True
                        break
                    elif possible_antecedents[sentence_id] > 1:
                        print("More than one possible Antecedent in previous Sentence".upper())
                        result = False
                        break
                else:
                    result = False
                sentence_id = sentence_id - 1
    return result    
            
        #print(pronoun)
        #print(filtered_words)
        #print(pronoun)
        #print(lookup_sentences)

# %%
def filter_nouns(words_list, number):
    referencing_singular_pos = ['NN', 'NNP']
    referencing_plural_pos = ['NNS', 'NNPS']
    result = list()
    if number=='singular':
        for x in words_list:
            for y in x:
                if y[1] in referencing_singular_pos:
                    result.append(y)
    else:
        for x in words_list:
            for y in x:
                if y[1] in referencing_plural_pos:
                    result.append(y)
    return result

# %%
def coherence_tags(tagger, sentence, return_parse_obj=False):
    """Tags sentences with POS tags. Returns a list of (word, tag, start index, end index) tuples

    tagger (CoreNLPTagger): a tagger to tag sentences
    RETURNS (list): list of (word, tag) tuples
    """
    #tokenize, ssplit, pos, lemma, ner, parse, dcoref
    default_properties = {'annotators': 'dcoref,gender'}
    tagged_data = tagger.api_call(sentence, properties=default_properties)
    if return_parse_obj:
        return tagged_data
    else:
        tags = list()
        for sent in tagged_data['sentences']:
            tags.append([(token['word'], token['pos'], token['characterOffsetBegin'], token['characterOffsetEnd'], token['index'], sent_index) for token in sent['tokens']])
            sent_index = sent_index + 1
        return tags

# %%
check_coherence('his', ["A geat challenge in a person's life span is his abbility to change to a better life where life is all about change."])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-24-2162c6ebc1f7> in <module>()
# ----> 1 check_coherence('his', ["A geat challenge in a person's life span is his abbility to change to a better life where life is all about change."])
#
# <ipython-input-21-2b4bb0853d41> in check_coherence(pronoun, lookup_sentences)
#      16         #print("For singular third person pronouns and possessives he/she/his/her")
#      17         # Remove all words that do not serve as a possible referencing word
# ---> 18         filtered_words = filter_nouns(lookup_sentences, 'singular')
#      19         if len(filtered_words)<=0:
#      20             print("ERROR, POSSIBLE SINGULAR ANTECEDENT NOT FOUND!")
#
# <ipython-input-22-7ff0ed1fe1dc> in filter_nouns(words_list, number)
#       6         for x in words_list:
#       7             for y in x:
# ----> 8                 if y[1] in referencing_singular_pos:
#       9                     result.append(y)
#      10     else:
#
# IndexError: string index out of range

# %%
current_essay = tag_set['essay'][1]
current_pronouns = tag_set['third_person_pronouns'][1]
current_sentence_indexes = tag_set['sentece_indexes'][1]
current_pronouns
# Out:
# [('his', 'PRP$', 44, 47, 11, 0),
#  ('them', 'PRP', 620, 624, 14, 5),
#  ('his', 'PRP$', 637, 640, 18, 5)]

# %%
"""
Dont look for sentences but look for the POS
"""
coherence_error_list = list()
for index, row in tag_set.iterrows():
    number_of_errors = 0
    current_sentence_indexes = row['sentece_indexes']
    current_essay = row['essay']
    print(row['filename'])
    print()
    current_sentence_id = None
    for pron in row['third_person_pronouns']:
        print(pron)
        lookup_sentences = list()
        if pron[5]==0: # if the pronoun is mentioned in the first sentence of the essay just look at that sentence
            lookup_sentences.append([x for x in row['pos'][pron[5]] if x[2]<pron[3]])
        elif pron[5]>2: # if the pronoun is mentioned in the 3rd or ahead sentence of the essay look the previous 2 sentences
            lookup_sentences.append([x for x in row['pos'][pron[5]] if x[2]<pron[3]])
            lookup_sentences.append(row['pos'][pron[5]-1])
            lookup_sentences.append(row['pos'][pron[5]-2])
        else:
             # First sentence to look up
            lookup_sentences.append([x for x in row['pos'][pron[5]] if x[2]<pron[3]])
            lookup_sentences.append(row['pos'][pron[5]-1])
        #print(pron[0])
        result = check_coherence(pron, lookup_sentences)   
        if current_sentence_id is None or current_sentence_id != pron[5]:
            current_sentence_id = pron[5]
            if result is not True:
                number_of_errors = number_of_errors + 1  
        print(current_essay[current_sentence_indexes[pron[5]][1] : current_sentence_indexes[pron[5]][2]])
    coherence_error_list.append(number_of_errors)
tag_set['coherence_errors'] = coherence_error_list
# Out:
# 1004355.txt
#
# 1007363.txt
#
# ('his', 'PRP$', 44, 47, 11, 0, 'O')
# A geat challenge in a person's life span is his abbility to change to a better life where life is all about change.
# ('them', 'PRP', 620, 624, 14, 5, 'O')
# Ofcoures, there will be some risks the person has to go through them to build up his experince.
# ('his', 'PRP$', 637, 640, 18, 5, 'O')
# Ofcoures, there will be some risks the person has to go through them to build up his experince.
# 1079196.txt
#
# ('they', 'PRP', 107, 111, 18, 0, 'O')
# Personally, I agree with the statement saying that most advertisements make products seem much better than they really are.
# ('their', 'PRP$', 253, 258, 11, 2, 'O')
# I have to admit that there are several companies advertising their products in an honest way, stating only facts about the product without any misleading slogans or jingles.
# ('their', 'PRP$', 446, 451, 18, 3, 'O')
# On the other hand, the majority of today\s industries is clever enough to trick their customers into buying their products.
# ('their', 'PRP$', 474, 479, 22, 3, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# On the other hand, the majority of today\s industries is clever enough to trick their customers into buying their products.
# ('They', 'PRP', 490, 494, 1, 4, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# They do so by either creating highly convincing advertisemetns with slogans or jingles people tend to associate with the product, or they claim characteristics and facts about the products that are simply untrue.
# ('they', 'PRP', 623, 627, 23, 4, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# They do so by either creating highly convincing advertisemetns with slogans or jingles people tend to associate with the product, or they claim characteristics and facts about the products that are simply untrue.
# ('they', 'PRP', 1258, 1262, 13, 8, 'O')
# Not only do foreign products mostly seem more attractive to customers, they are often  cheap copies of orginals invented and produced in the home country.
# ('it', 'PRP', 1892, 1894, 8, 13, 'O')
# If I know about a product that it does not fulfill all the expectations the company made me believe in, I will try my best to convince others not to buy it and I hope others will do so as well.
# ('it', 'PRP', 2014, 2016, 33, 13, 'O')
# If I know about a product that it does not fulfill all the expectations the company made me believe in, I will try my best to convince others not to buy it and I hope others will do so as well.
# ('their', 'PRP$', 2153, 2158, 19, 14, 'O')
# And even if companies tend at times to overestimate a little and seem to be too euphemistic about their products, we still live in a world where people have gotten used to this kind of advertising behavior by now.
# 1086343.txt
#
# ('their', 'PRP$', 17, 22, 4, 0, 'O')
# NOT ENOUGH SINGULAR NPs TO SERVE AS A PLURAL REFERENCING
# In many country  their are many combanies of advertsment  combete.
# ('their', 'PRP$', 128, 133, 4, 2, 'O')
# the scpoe of their competion is money.Theos companies compete to the famous product  such as PEPSI or CoLa .
# ('They', 'PRP', 224, 228, 1, 3, 'O')
# They try to make some products more that what it is, and discraibe it as mignfcient.
# ('it', 'PRP', 270, 272, 10, 3, 'O')
# They try to make some products more that what it is, and discraibe it as mignfcient.
# ('it', 'PRP', 291, 293, 15, 3, 'O')
# They try to make some products more that what it is, and discraibe it as mignfcient.
# ('its', 'PRP$', 377, 380, 11, 4, 'O')
# Companies of advertisemnet offer the prodect as bigger than what its size.
# ('them', 'PRP', 395, 399, 3, 5, 'O')
# Some of them exaggerate and make some product is batter than other prodect.
# ('them', 'PRP', 560, 564, 18, 6, 'O')
# In may country, many companies advertise thire prodect and  try to attract the veiwers and makes them buy the brand .
# ('they', 'PRP', 695, 699, 4, 9, 'O')
# For example, they don't exaggerate and t
# 1096747.txt
#
# ('they', 'PRP', 114, 118, 20, 1, 'O')
# in order to make a huge success, people do not need to create new ways every time when they discover problems.
# ('they', 'PRP', 153, 157, 5, 2, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# by doing that, they are easily lost their trail and are in danger of new tisks.
# ('their', 'PRP$', 174, 179, 9, 2, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# by doing that, they are easily lost their trail and are in danger of new tisks.
# ('them', 'PRP', 295, 299, 15, 3, 'O')
# historically, the methods and discovery ended up with great success, most of them are based on old and traditional ideas.
# ('he', 'PRP', 434, 436, 19, 4, 'O')
# For example, Tomas Edison invited the tellphone as the same time an other scientists did, and he could not become the inviter of the tellphone because he turn out his work three hours leter than the other scientists.
# ('he', 'PRP', 491, 493, 29, 4, 'O')
# For example, Tomas Edison invited the tellphone as the same time an other scientists did, and he could not become the inviter of the tellphone because he turn out his work three hours leter than the other scientists.
# ('his', 'PRP$', 503, 506, 32, 4, 'O')
# For example, Tomas Edison invited the tellphone as the same time an other scientists did, and he could not become the inviter of the tellphone because he turn out his work three hours leter than the other scientists.
# ('he', 'PRP', 566, 568, 3, 5, 'O')
# HOwever, he advanse his tellphone and solve the many problems the tell phone had.
# ('his', 'PRP$', 577, 580, 5, 5, 'O')
# HOwever, he advanse his tellphone and solve the many problems the tell phone had.
# 1109085.txt
#
# ('it', 'PRP', 176, 178, 16, 1, 'O')
# Based on my four years of experience as a teacher, I strongly believe that it is far more important for students to learn ideas and concepts.
# ('their', 'PRP$', 409, 414, 15, 3, 'O')
# One of the most important objectives of education is to prepare the students for their future careers.
# ('It', 'PRP', 865, 867, 1, 7, 'O')
# It is far more important for the student to understand the fundamental concepts and ideas, and develop an ability to make use of these concepts to develop his or her own solutions to practical problems.
# ('his', 'PRP$', 1020, 1023, 29, 7, 'O')
# It is far more important for the student to understand the fundamental concepts and ideas, and develop an ability to make use of these concepts to develop his or her own solutions to practical problems.
# ('her', 'PRP$', 1027, 1030, 31, 7, 'O')
# It is far more important for the student to understand the fundamental concepts and ideas, and develop an ability to make use of these concepts to develop his or her own solutions to practical problems.
# ('it', 'PRP', 1090, 1092, 6, 8, 'O')
# Similary, in history, it is a lot more important to understand the context of a war, rather than learn the simple fact that the war took place in a certain year.
# ('it', 'PRP', 1243, 1245, 4, 9, 'O')
# For example, it would be a lot more useful to understand why and how Hitler came to power in Germany, rather than the dates of particular events.
# ('it', 'PRP', 1652, 1654, 18, 11, 'O')
# The rapid developments in science and technology change the so-called facts at such a high speed that it does not make sense for a student to spend too much time on learning facts.
# ('it', 'PRP', 1993, 1995, 7, 14, 'O')
# Moreover, in many cases, it is even possible for the students to apply a concept they learned in one area to some other areas.
# ('they', 'PRP', 2049, 2053, 18, 14, 'O')
# Moreover, in many cases, it is even possible for the students to apply a concept they learned in one area to some other areas.
# 1164913.txt
#
# ('them', 'PRP', 74, 78, 15, 0, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Some tipes of advertisements use to make different products, and a lot of them are, better it's say that they seem, much better than they really are.
# ('it', 'PRP', 91, 93, 19, 0, 'O')
# Some tipes of advertisements use to make different products, and a lot of them are, better it's say that they seem, much better than they really are.
# ('they', 'PRP', 105, 109, 23, 0, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Some tipes of advertisements use to make different products, and a lot of them are, better it's say that they seem, much better than they really are.
# ('they', 'PRP', 133, 137, 29, 0, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Some tipes of advertisements use to make different products, and a lot of them are, better it's say that they seem, much better than they really are.
# ('it', 'PRP', 154, 156, 2, 1, 'O')
# Is it true or wrong?
# ('It', 'PRP', 172, 174, 1, 2, 'O')
# It is good or bad?
# ('its', 'PRP$', 1004, 1007, 23, 10, 'O')
# So we can find advertisemtent who gives to you a products really soon and whit a lot of good things correlated at its, or at really opposite concept, an advertisements who gives in a really long period something not really good for your person.
# ('it', 'PRP', 1466, 1468, 32, 12, 'O')
# If I have to take one decision about what tipe of advertisement I will choose, I hope to find a product whio can give to me a seem better than it look likes.
# 1174920.txt
#
# ('themselves', 'PRP', 102, 112, 18, 0, 'O')
# In my opinion people always should try new things and take risks to improve themselves.If people stop themselves in front of the difficulties ,they never improve.
# ('they', 'PRP', 143, 147, 25, 0, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# In my opinion people always should try new things and take risks to improve themselves.If people stop themselves in front of the difficulties ,they never improve.
# ('they', 'PRP', 303, 307, 31, 1, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# To become  successful people , we don't must do only what we can  do but, first of all in difficult situations ,we must take risks  even if they  should be wrong  at the end.
# ('themselves', 'PRP', 630, 640, 12, 3, 'O')
# This means that people that have important  ambitions can't limitate themselves in which they already know but they must search to improve themselves.
# ('they', 'PRP', 650, 654, 15, 3, 'O')
# This means that people that have important  ambitions can't limitate themselves in which they already know but they must search to improve themselves.
# ('they', 'PRP', 672, 676, 19, 3, 'O')
# This means that people that have important  ambitions can't limitate themselves in which they already know but they must search to improve themselves.
# ('themselves', 'PRP', 700, 710, 24, 3, 'O')
# This means that people that have important  ambitions can't limitate themselves in which they already know but they must search to improve themselves.
# ('himself', 'PRP', 794, 801, 18, 4, 'O')
# At the end I want say that don 't exist any person that became important limiting himself , but to become successful people  need courage and to take difficult choise to improve more and more.
# 1181356.txt
#
# ('it', 'PRP', 410, 412, 8, 4, 'O')
# Well, in my point of view it is not so simple.
# ('it', 'PRP', 632, 634, 2, 8, 'O')
# Therefore it is important to cut costs and improve efficency.
# 1223368.txt
#
# ('it', 'PRP', 295, 297, 20, 2, 'O')
# Both of these methods have advantages and I personally think that if a perfect educational system could exist then it should combine them.
# ('them', 'PRP', 313, 317, 23, 2, 'O')
# Both of these methods have advantages and I personally think that if a perfect educational system could exist then it should combine them.
# ('they', 'PRP', 377, 381, 3, 4, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# Indeed, they should help them to understand, model and simulate phenomena.
# ('them', 'PRP', 394, 398, 6, 4, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# Indeed, they should help them to understand, model and simulate phenomena.
# ('they', 'PRP', 453, 457, 3, 5, 'O')
# No doubt they may complicated and perhaps boring to study, but students should pay attention to them and check wether they get them correctly or not.
# ('them', 'PRP', 540, 544, 18, 5, 'O')
# No doubt they may complicated and perhaps boring to study, but students should pay attention to them and check wether they get them correctly or not.
# ('they', 'PRP', 562, 566, 22, 5, 'O')
# No doubt they may complicated and perhaps boring to study, but students should pay attention to them and check wether they get them correctly or not.
# ('them', 'PRP', 571, 575, 24, 5, 'O')
# No doubt they may complicated and perhaps boring to study, but students should pay attention to them and check wether they get them correctly or not.
# ('they', 'PRP', 682, 686, 4, 7, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# In fact, they can help students to understand theorical concepts.
# ('They', 'PRP', 860, 864, 1, 9, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# They would understand it even better indeed.
# ('it', 'PRP', 882, 884, 4, 9, 'O')
# They would understand it even better indeed.
# ('they', 'PRP', 1015, 1019, 7, 11, 'O')
# In addition students understand better when they do thing by themselves through practical projects and so on.
# ('themselves', 'PRP', 1032, 1042, 11, 11, 'O')
# In addition students understand better when they do thing by themselves through practical projects and so on.
# ('they', 'PRP', 1097, 1101, 5, 12, 'O')
# In other words, they understand better what they discovered themselves than what they had been taught by others.
# ('they', 'PRP', 1125, 1129, 9, 12, 'O')
# In other words, they understand better what they discovered themselves than what they had been taught by others.
# ('themselves', 'PRP', 1141, 1151, 11, 12, 'O')
# In other words, they understand better what they discovered themselves than what they had been taught by others.
# ('they', 'PRP', 1162, 1166, 14, 12, 'O')
# In other words, they understand better what they discovered themselves than what they had been taught by others.
# 1239289.txt
#
# ('It', 'PRP', 0, 2, 1, 0, 'O')
# It is believed that young people nowadays do not give enough time and response on their communities.
# ('their', 'PRP$', 82, 87, 16, 0, 'O')
# It is believed that young people nowadays do not give enough time and response on their communities.
# ('their', 'PRP$', 257, 262, 12, 2, 'O')
# People in the past liked to communicate with people, with their neighborhood, with family members,with students at school.
# ('it', 'PRP', 326, 328, 2, 3, 'O')
# Now it seems to me that they give more response to computers they have around, to i-pods they have in their pocktes and to any technology witch is facninating them.
# ('they', 'PRP', 346, 350, 7, 3, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Now it seems to me that they give more response to computers they have around, to i-pods they have in their pocktes and to any technology witch is facninating them.
# ('they', 'PRP', 383, 387, 13, 3, 'O')
# Now it seems to me that they give more response to computers they have around, to i-pods they have in their pocktes and to any technology witch is facninating them.
# ('they', 'PRP', 411, 415, 19, 3, 'O')
# Now it seems to me that they give more response to computers they have around, to i-pods they have in their pocktes and to any technology witch is facninating them.
# ('their', 'PRP$', 424, 429, 22, 3, 'O')
# Now it seems to me that they give more response to computers they have around, to i-pods they have in their pocktes and to any technology witch is facninating them.
# ('them', 'PRP', 481, 485, 31, 3, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Now it seems to me that they give more response to computers they have around, to i-pods they have in their pocktes and to any technology witch is facninating them.
# ('They', 'PRP', 487, 491, 1, 4, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# They dont have anough time for other things beacuse they just see the fact of 0's and 1's the same as the digital life, only true and false.
# ('they', 'PRP', 539, 543, 10, 4, 'O')
# They dont have anough time for other things beacuse they just see the fact of 0's and 1's the same as the digital life, only true and false.
# ('them', 'PRP', 679, 683, 11, 5, 'O')
# So, there will be no other things around bothering them.
# ('them', 'PRP', 802, 806, 26, 6, 'O')
# Old man trying to cross the road, child running trough the car on the road, rubish trown on the road will not bother them at all because they have their own life, own world as tehy have nothing to share with others.
# ('they', 'PRP', 822, 826, 30, 6, 'O')
# Old man trying to cross the road, child running trough the car on the road, rubish trown on the road will not bother them at all because they have their own life, own world as tehy have nothing to share with others.
# ('their', 'PRP$', 832, 837, 32, 6, 'O')
# Old man trying to cross the road, child running trough the car on the road, rubish trown on the road will not bother them at all because they have their own life, own world as tehy have nothing to share with others.
# ('their', 'PRP$', 1004, 1009, 20, 7, 'O')
# The real fact is that, no education supporting the idea that young people should pay more response to their community is made.
# ('their', 'PRP$', 1115, 1120, 8, 9, 'O')
# There might be a will of helping their communities on young people but i dont really see the act suppporting them.
# ('them', 'PRP', 1191, 1195, 21, 9, 'O')
# There might be a will of helping their communities on young people but i dont really see the act suppporting them.
# ('they', 'PRP', 1208, 1212, 2, 10, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# Eventhough they have an idea to do so, they are busy with school homeworks and projects more then helping tehir community.
# ('they', 'PRP', 1236, 1240, 10, 10, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# Eventhough they have an idea to do so, they are busy with school homeworks and projects more then helping tehir community.
# 1249928.txt
#
# ('they', 'PRP', 78, 82, 16, 0, 'O')
# In my openion, I really disagree with make the producte seem much better than they really are because it will liy to the people, west the people money and west time.
# ('it', 'PRP', 102, 104, 20, 0, 'O')
# In my openion, I really disagree with make the producte seem much better than they really are because it will liy to the people, west the people money and west time.
# ('they', 'PRP', 212, 216, 8, 1, 'O')
# Most advertisements liy to the people when they make the products seem much better than they are.
# ('they', 'PRP', 257, 261, 16, 1, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Most advertisements liy to the people when they make the products seem much better than they are.
# ('They', 'PRP', 267, 271, 1, 2, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# They make tant just to take the money from the people without trouth and that unfair.
# ('himself', 'PRP', 501, 508, 31, 3, 'O')
# You have to tell the coustomer the truth to be awear for the products, and the the coustomer have the chooise to choose which one will be better to himself.
# ('it', 'PRP', 679, 681, 10, 5, 'O')
# If you make your produsts much better than is it, you aer not just liying to your coustomer, but also west they money.
# ('they', 'PRP', 740, 744, 24, 5, 'O')
# If you make your produsts much better than is it, you aer not just liying to your coustomer, but also west they money.
# ('They', 'PRP', 752, 756, 1, 6, 'O')
# They work everyday to get the money and they work hard to find thr money that can cover they family from food and clothes.
# ('they', 'PRP', 792, 796, 9, 6, 'O')
# They work everyday to get the money and they work hard to find thr money that can cover they family from food and clothes.
# ('they', 'PRP', 840, 844, 19, 6, 'O')
# They work everyday to get the money and they work hard to find thr money that can cover they family from food and clothes.
# ('them', 'PRP', 1151, 1155, 15, 10, 'O')
# last things I would like to take about is westing time for bouth of them.
# ('his', 'PRP$', 1181, 1184, 4, 11, 'O')
# The advertisements west his time to do nothing and not true, and the coustomer west his time to lisente to the advertisements when they liy.
# ('his', 'PRP$', 1241, 1244, 17, 11, 'O')
# The advertisements west his time to do nothing and not true, and the coustomer west his time to lisente to the advertisements when they liy.
# ('they', 'PRP', 1288, 1292, 25, 11, 'O')
# The advertisements west his time to do nothing and not true, and the coustomer west his time to lisente to the advertisements when they liy.
# ('them', 'PRP', 1312, 1316, 4, 12, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# Then bouth of them will det nothing and some time will be bad because to may go to fight between bouth of them.
# ('them', 'PRP', 1404, 1408, 23, 12, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# Then bouth of them will det nothing and some time will be bad because to may go to fight between bouth of them.
# ('they', 'PRP', 1520, 1524, 20, 13, 'O')
# For all that reasones, I really disagree with the advertisements to make the products seem much better than they are.
# 1321982.txt
#
# ('it', 'PRP', 9, 11, 3, 0, 'O')
# Of curse it is very important for students to understsnd ideas and concepts
# whay we say that ??
# ('they', 'PRP', 254, 258, 28, 1, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# because if students under stand ideas and concept thay can make some realiton ship between things and discover many new things in this life more than things they learning yn thear schools
# I think the main think in this topic is the theory of teaching in our class if we think by the tradshnal  way we will foucs about teaching facts but if we understsnd anew teching theory we will must go teach ideas and concepts
# I bleave that evry teacher need to study at first how to learn and teaching then they will go to our schools
# in fact most of our teachers do not now tha bad effiect  thay are leave it in students thinking way and on there life in futare of this students and also on thear socaity
# some time we need to teaching the logic in our schools to be a very good thinking people
# I think we need abig chang in our way thinking to reche to agood and active way in method of learning and teaching
# at the end i think it is the  big topiq and need more descition
# ('they', 'PRP', 593, 597, 93, 1, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# because if students under stand ideas and concept thay can make some realiton ship between things and discover many new things in this life more than things they learning yn thear schools
# I think the main think in this topic is the theory of teaching in our class if we think by the tradshnal  way we will foucs about teaching facts but if we understsnd anew teching theory we will must go teach ideas and concepts
# I bleave that evry teacher need to study at first how to learn and teaching then they will go to our schools
# in fact most of our teachers do not now tha bad effiect  thay are leave it in students thinking way and on there life in futare of this students and also on thear socaity
# some time we need to teaching the logic in our schools to be a very good thinking people
# I think we need abig chang in our way thinking to reche to agood and active way in method of learning and teaching
# at the end i think it is the  big topiq and need more descition
# ('it', 'PRP', 694, 696, 114, 1, 'O')
# because if students under stand ideas and concept thay can make some realiton ship between things and discover many new things in this life more than things they learning yn thear schools
# I think the main think in this topic is the theory of teaching in our class if we think by the tradshnal  way we will foucs about teaching facts but if we understsnd anew teching theory we will must go teach ideas and concepts
# I bleave that evry teacher need to study at first how to learn and teaching then they will go to our schools
# in fact most of our teachers do not now tha bad effiect  thay are leave it in students thinking way and on there life in futare of this students and also on thear socaity
# some time we need to teaching the logic in our schools to be a very good thinking people
# I think we need abig chang in our way thinking to reche to agood and active way in method of learning and teaching
# at the end i think it is the  big topiq and need more descition
# ('it', 'PRP', 1017, 1019, 179, 1, 'O')
# because if students under stand ideas and concept thay can make some realiton ship between things and discover many new things in this life more than things they learning yn thear schools
# I think the main think in this topic is the theory of teaching in our class if we think by the tradshnal  way we will foucs about teaching facts but if we understsnd anew teching theory we will must go teach ideas and concepts
# I bleave that evry teacher need to study at first how to learn and teaching then they will go to our schools
# in fact most of our teachers do not now tha bad effiect  thay are leave it in students thinking way and on there life in futare of this students and also on thear socaity
# some time we need to teaching the logic in our schools to be a very good thinking people
# I think we need abig chang in our way thinking to reche to agood and active way in method of learning and teaching
# at the end i think it is the  big topiq and need more descition
# 1346734.txt
#
# ('their', 'PRP$', 42, 47, 7, 0, 'O')
# Nowdays people use advertisement  to show their product; or to commercialize it; but  usualy they push much more on these advertisement.
# ('it', 'PRP', 77, 79, 13, 0, 'O')
# Nowdays people use advertisement  to show their product; or to commercialize it; but  usualy they push much more on these advertisement.
# ('they', 'PRP', 93, 97, 17, 0, 'O')
# Nowdays people use advertisement  to show their product; or to commercialize it; but  usualy they push much more on these advertisement.
# ('they', 'PRP', 144, 148, 3, 1, 'O')
# I mean they show their item pretier or say something that's not true about it.
# ('their', 'PRP$', 154, 159, 5, 1, 'O')
# I mean they show their item pretier or say something that's not true about it.
# ('it', 'PRP', 212, 214, 16, 1, 'O')
# I mean they show their item pretier or say something that's not true about it.
# ('they', 'PRP', 345, 349, 17, 3, 'O')
# Example : when you are usig a phone card  the time remaining is generaly less than they said.
# ('they', 'PRP', 396, 400, 8, 4, 'O')
# Another example is car; the preformance they said about it is false.
# ('it', 'PRP', 412, 414, 11, 4, 'O')
# Another example is car; the preformance they said about it is false.
# ('their', 'PRP$', 542, 547, 24, 5, 'O')
# So as costumer i agee with the statement, and i think people should   take time to make a right choice before buying their items.
# ('their', 'PRP$', 599, 604, 9, 6, 'O')
# And campanies should show the right side of their productions.
# 1365003.txt
#
# ('their', 'PRP$', 64, 69, 13, 0, 'O')
# I concede that in some respects, the young should contribute to their communities more in which they live in.
# ('they', 'PRP', 96, 100, 18, 0, 'O')
# I concede that in some respects, the young should contribute to their communities more in which they live in.
# ('their', 'PRP$', 206, 211, 19, 1, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# However, beyond this concession, because of the new technology, the young are beginning to help their communities in some nations.Therefore, on balance, I do not agree with the statement.
# ('they', 'PRP', 334, 338, 8, 2, 'O')
# Admittedly, at a first glance, they do not give much time to help their community.
# ('their', 'PRP$', 369, 374, 16, 2, 'O')
# Admittedly, at a first glance, they do not give much time to help their community.
# ('it', 'PRP', 415, 417, 6, 3, 'O')
# This is especially true when it comes to developed countries.
# ('they', 'PRP', 527, 531, 15, 4, 'O')
# Compared with the decades ago, young people are required to study hard because they have to master more and more diverse skills including informaiton technology.
# ('they', 'PRP', 677, 681, 15, 5, 'O')
# In my observation, due to the time required to learn these skills, they do not have much enough time to contribute to their community.
# ('their', 'PRP$', 728, 733, 25, 5, 'O')
# In my observation, due to the time required to learn these skills, they do not have much enough time to contribute to their community.
# ('their', 'PRP$', 933, 938, 16, 7, 'O')
# Thanks to the advent of the information technology, more and more young people help their communities using the technology.
# ('their', 'PRP$', 1135, 1140, 10, 9, 'O')
# The young in Japan supported the people who lost their houses because of a massive eathquake by calling for the financial support on the Internet.
# ('they', 'PRP', 1239, 1243, 3, 10, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# Thus, they can and do use the technology to solve local problems.
# ('It', 'PRP', 1304, 1306, 1, 11, 'O')
# It would be tempting to argue that the young are not interested in their community considering their apathy in politics in some nations.
# ('their', 'PRP$', 1371, 1376, 14, 11, 'O')
# It would be tempting to argue that the young are not interested in their community considering their apathy in politics in some nations.
# ('their', 'PRP$', 1399, 1404, 17, 11, 'O')
# It would be tempting to argue that the young are not interested in their community considering their apathy in politics in some nations.
# ('it', 'PRP', 1511, 1513, 2, 13, 'O')
# When it comes to nations where political situations are not stable, the young are forced to participate in their communities.
# ('their', 'PRP$', 1613, 1618, 20, 13, 'O')
# When it comes to nations where political situations are not stable, the young are forced to participate in their communities.
# ('their', 'PRP$', 1704, 1709, 3, 15, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Because of their severe condition in which the pressure from Beijing is massive, the young are serious about their future and their nation.
# ('their', 'PRP$', 1802, 1807, 20, 15, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Because of their severe condition in which the pressure from Beijing is massive, the young are serious about their future and their nation.
# ('their', 'PRP$', 1819, 1824, 23, 15, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Because of their severe condition in which the pressure from Beijing is massive, the young are serious about their future and their nation.
# ('their', 'PRP$', 1914, 1919, 6, 17, 'O')
# In sum, because of their difficulties, many young people do not have much time to helping their communities; however, the advent of the informaiton technology made it possible for them to participate in the community in new ways.
# ('their', 'PRP$', 1985, 1990, 19, 17, 'O')
# In sum, because of their difficulties, many young people do not have much time to helping their communities; however, the advent of the informaiton technology made it possible for them to participate in the community in new ways.
# ('it', 'PRP', 2059, 2061, 31, 17, 'O')
# In sum, because of their difficulties, many young people do not have much time to helping their communities; however, the advent of the informaiton technology made it possible for them to participate in the community in new ways.
# ('them', 'PRP', 2075, 2079, 34, 17, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# In sum, because of their difficulties, many young people do not have much time to helping their communities; however, the advent of the informaiton technology made it possible for them to participate in the community in new ways.
# ('They', 'PRP', 2125, 2129, 1, 18, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# They are getting involved with their communities through these means.
# ('their', 'PRP$', 2156, 2161, 6, 18, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# They are getting involved with their communities through these means.
# 1388870.txt
#
# ('they', 'PRP', 74, 78, 16, 0, 'O')
# Some people want to try new things while other prefer to do the same that they knew all over their life.
# ('their', 'PRP$', 93, 98, 20, 0, 'O')
# Some people want to try new things while other prefer to do the same that they knew all over their life.
# ('they', 'PRP', 354, 358, 15, 3, 'O')
# The frist reson is that  successful people shoud try to do new things otherwase they will not bring new things.
# ('He', 'PRP', 455, 457, 1, 5, 'O')
# GENDER DOES NOT MATCH WITH PRONOUN HE
# He looked to the apple which fall down from the tree as other but He looked to this case different from other and asked himself why did it fall.
# ('He', 'PRP', 521, 523, 15, 5, 'O')
# GENDER DOES NOT MATCH WITH PRONOUN HE
# He looked to the apple which fall down from the tree as other but He looked to this case different from other and asked himself why did it fall.
# ('himself', 'PRP', 575, 582, 25, 5, 'O')
# He looked to the apple which fall down from the tree as other but He looked to this case different from other and asked himself why did it fall.
# ('it', 'PRP', 591, 593, 28, 5, 'O')
# He looked to the apple which fall down from the tree as other but He looked to this case different from other and asked himself why did it fall.
# ('he', 'PRP', 614, 616, 5, 6, 'O')
# GENDER DOES NOT MATCH WITH PRONOUN HE
# As a result, he interdouced a new law of movement.
# ('they', 'PRP', 734, 738, 4, 8, 'O')
# Forthat, although they will not get  benefit of all things, they can success in something new.
# ('they', 'PRP', 776, 780, 13, 8, 'O')
# Forthat, although they will not get  benefit of all things, they can success in something new.
# ('they', 'PRP', 938, 942, 5, 10, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Becuse of high risk they can get high benefits and this according to the statment which says high risk gives sometime high rate.
# 1392946.txt
#
# ('their', 'PRP$', 52, 57, 12, 0, 'O')
# Nowadays a lot of people like to take riks and test their own limit.
# ('their', 'PRP$', 93, 98, 5, 1, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# Everybode tries to hone their abillities.
# ('they', 'PRP', 190, 194, 16, 2, 'O')
# Some argue that this way of life is just limited to successful people, because they achieved nearly everything else .
# ('his', 'PRP$', 667, 670, 9, 7, 'O')
# If a person is in a dangerous situation his or her adrenaline level increases.
# ('her', 'PRP$', 674, 677, 11, 7, 'O')
# If a person is in a dangerous situation his or her adrenaline level increases.
# ('their', 'PRP$', 825, 830, 11, 9, 'O')
# Successful people may have a greater need, because of their prior accomplishments, but this feeling and the hormon is common to every human being.
# ('their', 'PRP$', 1046, 1051, 7, 11, 'O')
# For examples, young children explore their surroundings and they find mostly great joy in it.
# ('they', 'PRP', 1069, 1073, 10, 11, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# For examples, young children explore their surroundings and they find mostly great joy in it.
# ('it', 'PRP', 1099, 1101, 16, 11, 'O')
# For examples, young children explore their surroundings and they find mostly great joy in it.
# ('their', 'PRP$', 1364, 1369, 7, 15, 'O')
# To learn another skill may lessen their ability to be good at their prime skill or at work.
# ('their', 'PRP$', 1392, 1397, 13, 15, 'O')
# To learn another skill may lessen their ability to be good at their prime skill or at work.
# ('they', 'PRP', 1830, 1834, 9, 19, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# The successful will not experiment extensively, because they will use the etch that made them successful.
# ('them', 'PRP', 1863, 1867, 16, 19, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# The successful will not experiment extensively, because they will use the etch that made them successful.
# 1394540.txt
#
# ('his', 'PRP$', 214, 217, 15, 1, 'O')
# In theese countries almost everybody (between eighteen and sixty years old) have his own car and the problems concerned with this situation are becoming very high.
# ('their', 'PRP$', 528, 533, 14, 3, 'O')
# Many majors, for example, suggest to close the a part of their cities to the cars and this will be good also in order to preserve the beauty of the city centres (especially if there are historical and artistical monuments, like in italian cities).
# ('it', 'PRP', 830, 832, 26, 4, 'O')
# But this will create the problem of moving from a place to another (people have to go to work or to school) so it will be necessary  to improove the public transports.
# ('It', 'PRP', 980, 982, 1, 6, 'O')
# It's really difficult to renouce to our habits, expecially if a chang means to live a little harder than before.
# 1414676.txt
#
# ('their', 'PRP$', 1787, 1792, 13, 19, 'O')
# As far as I have experienced people mostly favor individual transportation in their cars rather than in crouded buses and trains.
# 1431839.txt
#
# ('they', 'PRP', 95, 99, 16, 0, 'O')
# I completely agree with the statement 'most advertisements make products seem much better than they really are.'
# ('they', 'PRP', 425, 429, 9, 4, 'O')
# Advertisements are always exaggerated to be better than they actually are.
# ('their', 'PRP$', 461, 466, 3, 5, 'O')
# People advertise their products in order to sell it.
# ('it', 'PRP', 493, 495, 9, 5, 'O')
# People advertise their products in order to sell it.
# ('It', 'PRP', 497, 499, 1, 6, 'O')
# It is a business and no business will be successful without positive feedback.
# ('it', 'PRP', 646, 648, 17, 7, 'O')
# Of course, if the product seems good, people are going to want to buy it.
# ('it', 'PRP', 722, 724, 3, 9, 'O')
# I found it on the back of a magazine lying around at school.
# ('He', 'PRP', 861, 863, 1, 12, 'O')
# He was holding a trumpet trumpet in one hand while holding a cigarette in the other.
# ('they', 'PRP', 1003, 1007, 9, 13, 'O')
# This advertisement made cigarettes seem much better than they really are.
# ('they', 'PRP', 1208, 1212, 9, 15, 'O')
# Another example of making products look better than they truely are, are food products.
# ('their', 'PRP$', 1381, 1386, 8, 17, 'O')
# Both food companies will have to make their foods look better and sound better than that of the other company's.
# ('it', 'PRP', 1646, 1648, 15, 20, 'O')
# When you are at home, you will se advertisements on TV or receive it in the mail.
# ('it', 'PRP', 1810, 1812, 7, 22, 'O')
# People cannot get away from it, which is good for the businesses, but bad for the people.
# 1447041.txt
#
# ('it', 'PRP', 163, 165, 9, 1, 'O')
# This is will grow up the knowledge and it will increase the educational part in the personality of the people .
# ('it', 'PRP', 1104, 1106, 18, 8, 'O')
# Having a different career in the bacholer degree from the Master will also increase the knowldge and it will be better to have the bacholar speciality with the same master speciality .
# ('his', 'PRP$', 1258, 1261, 12, 9, 'O')
# Finally, I encourge and motivate  every person  that should enlarge his knowlege and know many acadmic subjects rather that stik in one specific subject .
# 1449555.txt
#
# ('they', 'PRP', 75, 79, 13, 0, 'O')
# The issue at hand is whether advertisements make products seem better than they really are or not.
# ('they', 'PRP', 262, 266, 11, 2, 'O')
# In my opinion advertisments assume products to be better than they really are.
# ('it', 'PRP', 608, 610, 12, 7, 'O')
# Maybe my hair was shinier after using the shampoo, but it was not easy to model it at all.
# ('it', 'PRP', 633, 635, 18, 7, 'O')
# Maybe my hair was shinier after using the shampoo, but it was not easy to model it at all.
# ('it', 'PRP', 655, 657, 3, 8, 'O')
# In reality it was even more difficult.
# ('it', 'PRP', 915, 917, 3, 12, 'O')
# Through this it is obvious that the advertisments are lies.
# ('it', 'PRP', 1016, 1018, 11, 13, 'O')
# Everything looks so colorful at the TV but in reality it is not colorful at all.
# ('It', 'PRP', 1043, 1045, 1, 14, 'O')
# It is just like every other product you can buy in the shop, which is not advertised.
# ('they', 'PRP', 1277, 1281, 12, 16, 'O')
# That completely convinces one that advertisments make products seeming better than they are.
# ('they', 'PRP', 1367, 1371, 8, 18, 'O')
# When people want to advertise such products they have special strategies for it.
# ('it', 'PRP', 1400, 1402, 13, 18, 'O')
# When people want to advertise such products they have special strategies for it.
# ('it', 'PRP', 1487, 1489, 4, 20, 'O')
# Advertisers just put it together with artificial materials.
# ('it', 'PRP', 1529, 1531, 2, 21, 'O')
# So it looks better and you just want to buy it.
# ('it', 'PRP', 1570, 1572, 11, 21, 'O')
# So it looks better and you just want to buy it.
# ('their', 'PRP$', 1623, 1628, 9, 22, 'O')
# You will never find products in advertisments in their original way.
# ('it', 'PRP', 1682, 1684, 11, 23, 'O')
# That is a big lie to the customers, is it not?
# ('they', 'PRP', 1756, 1760, 13, 24, 'O')
# To sum up, I think that advertisements make products better than they really are because of my own experience, compares between advertised products and the actual products in the shops  and because of the way advertisements are produced.
# 1453563.txt
#
# ('his', 'PRP$', 113, 116, 10, 1, 'O')
# This means that a student can do better if his basic knowledge of understanding is good.
# ('his', 'PRP$', 396, 399, 21, 3, 'O')
# For example, a Biology student who is doing a research in the field of microrganisms can go ahead with his research only if he has the basic idea of microorganisms and their behaivour.
# ('he', 'PRP', 417, 419, 25, 3, 'O')
# For example, a Biology student who is doing a research in the field of microrganisms can go ahead with his research only if he has the basic idea of microorganisms and their behaivour.
# ('their', 'PRP$', 461, 466, 33, 3, 'O')
# For example, a Biology student who is doing a research in the field of microrganisms can go ahead with his research only if he has the basic idea of microorganisms and their behaivour.
# ('he', 'PRP', 502, 504, 6, 4, 'O')
# By only learning facts, he cannot reach a final decision.
# ('his', 'PRP$', 544, 547, 3, 5, 'O')
# To have his findings more a  solid basis, he needs to have a strong foothold in microorganic study.
# ('he', 'PRP', 578, 580, 10, 5, 'O')
# To have his findings more a  solid basis, he needs to have a strong foothold in microorganic study.
# ('his', 'PRP$', 805, 808, 9, 7, 'O')
# For instance, a mathematics student can do his high level arithmetic and algebra only if his lower level maths skills are developed.
# ('his', 'PRP$', 851, 854, 17, 7, 'O')
# For instance, a mathematics student can do his high level arithmetic and algebra only if his lower level maths skills are developed.
# ('he', 'PRP', 953, 955, 10, 8, 'O')
# Furthermore, these skills become an inherent quality when he knows how to derive at a formula.
# ('him', 'PRP', 1028, 1031, 7, 9, 'O')
# Although learning a formula will make him work out easy problems but he will get stuck in the major issues.
# ('he', 'PRP', 1059, 1061, 13, 9, 'O')
# Although learning a formula will make him work out easy problems but he will get stuck in the major issues.
# ('It', 'PRP', 1264, 1266, 1, 12, 'O')
# It will not pave your path to reach your goal.
# ('their', 'PRP$', 1373, 1378, 10, 13, 'O')
# A clear understanding develops interest in students to pursue their future in an innovative field of any branch instead of working on the set patterns by their ancestors.
# ('their', 'PRP$', 1465, 1470, 27, 13, 'O')
# A clear understanding develops interest in students to pursue their future in an innovative field of any branch instead of working on the set patterns by their ancestors.
# ('it', 'PRP', 1662, 1664, 13, 15, 'O')
# Considering all the above facts I completely disagree to the fact that it is important for the students to understand ideas and concepts than it is for them to lern facts.
# ('it', 'PRP', 1733, 1735, 25, 15, 'O')
# Considering all the above facts I completely disagree to the fact that it is important for the students to understand ideas and concepts than it is for them to lern facts.
# ('them', 'PRP', 1743, 1747, 28, 15, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Considering all the above facts I completely disagree to the fact that it is important for the students to understand ideas and concepts than it is for them to lern facts.
# 1469088.txt
#
# ('they', 'PRP', 426, 430, 12, 2, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# secondly the affection of cars are increasing.todays when people go sonewhere they use car more than other public tranceportation.becuse going out by car is more convenions.and people want convenions more and more.
# ('their', 'PRP$', 567, 572, 2, 3, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# and their is no alternative to car.maybe you will say air craft,but there have to have to be wide land to aircraft to put on.but i think it will there will be less land in future than now.
# ('it', 'PRP', 700, 702, 30, 3, 'O')
# and their is no alternative to car.maybe you will say air craft,but there have to have to be wide land to aircraft to put on.but i think it will there will be less land in future than now.
# ('it', 'PRP', 861, 863, 20, 4, 'O')
# another reason is that willbe more population in twenty years later than today.so as number of people grower,it will also grow number of car,people want.
# 1599482.txt
#
# ('they', 'PRP', 78, 82, 14, 0, 'O')
# To answer the question, if most advertisements make products much better than they really are I want to procide in a certain way.
# ('them', 'PRP', 197, 201, 13, 1, 'O')
# Since the question states that not all advertisements, but most of them are making a product look much better than it really is, I am just going to give some examples in order to empiricly prove that the given statement is correct.
# ('it', 'PRP', 245, 247, 22, 1, 'O')
# Since the question states that not all advertisements, but most of them are making a product look much better than it really is, I am just going to give some examples in order to empiricly prove that the given statement is correct.
# ('their', 'PRP$', 438, 443, 4, 3, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# When you see their commercial on TV, where it is these tasty french fries just shouting out of that shimmering red box, they always look just fabulous.
# ('it', 'PRP', 468, 470, 10, 3, 'O')
# When you see their commercial on TV, where it is these tasty french fries just shouting out of that shimmering red box, they always look just fabulous.
# ('they', 'PRP', 545, 549, 25, 3, 'O')
# When you see their commercial on TV, where it is these tasty french fries just shouting out of that shimmering red box, they always look just fabulous.
# ('They', 'PRP', 577, 581, 1, 4, 'O')
# They are thick and have that perfect yellow-brownish color.
# ('they', 'PRP', 663, 667, 5, 5, 'O')
# And almost more important they lie in that box perfectly organized.
# ('them', 'PRP', 893, 897, 27, 7, 'O')
# Comparing that wounderful illusion of Mc Donalds french fries with the reallity one has to come to the conclusion that there is a gigantic diffrence between them.
# ('they', 'PRP', 1554, 1558, 26, 13, 'O')
# Altough I have to admit that I did not try every existing energy-drink I believe I can tell by the dozen I have tried that they are neighter as good looking, nor as good energy restoring as the advertisement wants to make one believe.
# ('it', 'PRP', 1762, 1764, 16, 14, 'O')
# As these to examples perfectly show advertisements usually make a product seem much better than it really is, which is nothing to wonder about if one looks at the purpose of an advertisement.
# ('they', 'PRP', 1949, 1953, 18, 15, 'O')
# Since advertisements are made to increase the number of sold units of a product, of course they try to make everyone believe that they are buying a perfect product.
# ('they', 'PRP', 1988, 1992, 25, 15, 'O')
# Since advertisements are made to increase the number of sold units of a product, of course they try to make everyone believe that they are buying a perfect product.
# 1604419.txt
#
# ('him', 'PRP', 264, 267, 24, 1, 'O')
# moust of big counteri worak to gather gave salion and consiederd all of praplam insied the worled ,if the are dont gave him any importante you will see many people die in ours .
# ('his', 'PRP$', 436, 439, 22, 2, 'O')
# Ihave been maney countri and isaw sam of contre helping peopel gave for poor famaily many and find jop to helping his famaly .
# 162639.txt
#
# ('it', 'PRP', 24, 26, 6, 0, 'O')
# In my personal opinion, it is true that most of the young people nowadays do not give enough time to helping their communities.
# ('their', 'PRP$', 109, 114, 23, 0, 'O')
# In my personal opinion, it is true that most of the young people nowadays do not give enough time to helping their communities.
# ('their', 'PRP$', 241, 246, 10, 2, 'O')
# One is that young people today concern more about their self-interests than the interests of the community.
# ('them', 'PRP', 375, 379, 14, 3, 'O')
# The onther reason is that yongsters today are more aloof with people around them.
# ...
# ('It', 'PRP', 1599, 1601, 1, 18, 'O')
# It is clear, then that the ideas are just a vague imaginary actions that should be put into action.
# 757891.txt
#
# ('They', 'PRP', 117, 121, 1, 2, 'O')
# They all took a risk of being a failure or overcame the struggles.
# ('His', 'PRP$', 380, 383, 1, 5, 'O')
# His great invention, Windows was nothing but a program with simple design at that time.
# ('His', 'PRP$', 468, 471, 1, 6, 'O')
# His courage and plan, however, was not simple nor easy at all.
# ('he', 'PRP', 537, 539, 3, 7, 'O')
# GENDER DOES NOT MATCH WITH PRONOUN HE
# As if he needed to prove that he is a talented businessman, he had to visit numerous numbers of people to pursuade them that his invention is amusing.
# ('he', 'PRP', 561, 563, 8, 7, 'O')
# GENDER DOES NOT MATCH WITH PRONOUN HE
# As if he needed to prove that he is a talented businessman, he had to visit numerous numbers of people to pursuade them that his invention is amusing.
# ('he', 'PRP', 591, 593, 14, 7, 'O')
# As if he needed to prove that he is a talented businessman, he had to visit numerous numbers of people to pursuade them that his invention is amusing.
# ('them', 'PRP', 646, 650, 24, 7, 'O')
# As if he needed to prove that he is a talented businessman, he had to visit numerous numbers of people to pursuade them that his invention is amusing.
# ('his', 'PRP$', 656, 659, 26, 7, 'O')
# As if he needed to prove that he is a talented businessman, he had to visit numerous numbers of people to pursuade them that his invention is amusing.
# ('His', 'PRP$', 733, 736, 1, 9, 'O')
# His business went through several hard times.
# ('His', 'PRP$', 779, 782, 1, 10, 'O')
# His business went through several trials because people were jealous of him all the time.
# ('him', 'PRP', 851, 854, 12, 10, 'O')
# His business went through several trials because people were jealous of him all the time.
# ('he', 'PRP', 875, 877, 3, 11, 'O')
# GENDER DOES NOT MATCH WITH PRONOUN HE
# Once, he had to leave the company for dominating the market.
# ('his', 'PRP$', 1480, 1483, 16, 17, 'O')
# Bill Gates took the risk of selling ungaurenteed product to the market and thanks to his idea, XBOX almost dominated the market in the North America.
# ('it', 'PRP', 1697, 1699, 3, 20, 'O')
# However, it is not the luck or fortune that makes the sucessful person.
# ('It', 'PRP', 1760, 1762, 1, 21, 'O')
# It is the courage and careful plan that creates one succesful person.
# 806909.txt
#
# ('It', 'PRP', 49, 51, 1, 1, 'O')
# It does not matter in which part of the world we live, we can be aware of all the happenings in other parts as well.
# ('its', 'PRP$', 289, 292, 10, 3, 'O')
# Before launching of any product, the company promotes its product with the help of media.
# ('its', 'PRP$', 370, 373, 10, 4, 'O')
# We know the name of a particular product and its significant feature before it is launced in the market.
# ('it', 'PRP', 401, 403, 14, 4, 'O')
# We know the name of a particular product and its significant feature before it is launced in the market.
# ('its', 'PRP$', 661, 664, 6, 8, 'O')
# Knowing about the product and its significant feature even before its market supply, greatly increase its demand.
# ('its', 'PRP$', 697, 700, 11, 8, 'O')
# Knowing about the product and its significant feature even before its market supply, greatly increase its demand.
# ('its', 'PRP$', 733, 736, 17, 8, 'O')
# Knowing about the product and its significant feature even before its market supply, greatly increase its demand.
# ('its', 'PRP$', 783, 786, 7, 9, 'O')
# But advertisement only add profits to its manufacturers and mislead its customers.
# ('its', 'PRP$', 813, 816, 11, 9, 'O')
# But advertisement only add profits to its manufacturers and mislead its customers.
# ('they', 'PRP', 1177, 1181, 31, 12, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# These advertisements lure public and portray that this perticular item is the best as this film star or sport star is using the same.The manufacturers show only those features that they want to show.
# ('They', 'PRP', 1197, 1201, 1, 13, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# They never highlight all the features of the product so that the customers can have real idea of the product.
# ('it', 'PRP', 1386, 1388, 16, 14, 'O')
# Due to the presence of many similar items, customers may have many choices but it is actually very confusing because they only have a vague idea of everyone.
# ('they', 'PRP', 1424, 1428, 22, 14, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Due to the presence of many similar items, customers may have many choices but it is actually very confusing because they only have a vague idea of everyone.
# ('it', 'PRP', 1584, 1586, 13, 16, 'O')
# Thousand and thousand of dollars are spend on these advertisement to make it more charming and colourful.
# 832751.txt
#
# ('them', 'PRP', 260, 264, 25, 1, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Posters, television, radio, newspapers, and even the internet - all the mass media - are concerned, as most of them rely on advertisement to survive.
# ('it', 'PRP', 361, 363, 11, 2, 'O')
# There are so many ocasions to come across advertisements that it is even easy to let oneself be convinced and seduced by one of them.
# ('them', 'PRP', 427, 431, 25, 2, 'O')
# There are so many ocasions to come across advertisements that it is even easy to let oneself be convinced and seduced by one of them.
# ('it', 'PRP', 441, 443, 3, 3, 'O')
# Hasn't it happened to all of us?
# ('themselves', 'PRP', 495, 505, 6, 4, 'O')
# But what about the products themselves?
# ('their', 'PRP$', 737, 742, 22, 6, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Over the last decade, advertisements professionals have developed an increasing number of sophisticated communication strategies to make the consumers buy their products.
# ('they', 'PRP', 782, 786, 6, 7, 'O')
# Advertisements make us laugh,they make us cry, and brands mark our mind and influence our judgment.
# ('It', 'PRP', 930, 932, 1, 9, 'O')
# It is true that consumers can sometimes be tricked into believing that a product is better than it really is, but the advertisement executives cannot really be blamed for it.
# ('it', 'PRP', 1026, 1028, 18, 9, 'O')
# It is true that consumers can sometimes be tricked into believing that a product is better than it really is, but the advertisement executives cannot really be blamed for it.
# ('it', 'PRP', 1101, 1103, 32, 9, 'O')
# It is true that consumers can sometimes be tricked into believing that a product is better than it really is, but the advertisement executives cannot really be blamed for it.
# ('them', 'PRP', 1153, 1157, 8, 10, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Consumers play the game.Brands are signals to them, which they use to shop quicker and to which they are often faithful by principle.
# ('they', 'PRP', 1165, 1169, 11, 10, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Consumers play the game.Brands are signals to them, which they use to shop quicker and to which they are often faithful by principle.
# ('they', 'PRP', 1203, 1207, 19, 10, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Consumers play the game.Brands are signals to them, which they use to shop quicker and to which they are often faithful by principle.
# ('they', 'PRP', 1418, 1422, 19, 12, 'O')
# These consumer society spread information and often condemn misleading advertisements and products, which quality is not what they expected.
# ('its', 'PRP$', 1721, 1724, 32, 14, 'O')
# During the American presidential campaign of 2004, the Heinz company - somehow directly linked to Democrat presidential candidate John Kerry - tried to take advantage of the campaign  by making its tomato sauce a political symbol.
# 844996.txt
#
# ('it', 'PRP', 18, 20, 5, 0, 'O')
# I agree that that it is more difficult to assimilate an idea unless there is a good example to support it.
# ('it', 'PRP', 103, 105, 21, 0, 'O')
# I agree that that it is more difficult to assimilate an idea unless there is a good example to support it.
# ('them', 'PRP', 124, 128, 5, 1, 'O')
# In order to make them reachable, ideas and concepts should be followed by real facts taken from everyday's life experiences.
# ('it', 'PRP', 332, 334, 21, 2, 'O')
# To illustrate with an example, a concept such as 'freedom' has a very broad meaning and therefore it may be difficult to categorize and confine it with a few sentences.
# ('it', 'PRP', 378, 380, 29, 2, 'O')
# To illustrate with an example, a concept such as 'freedom' has a very broad meaning and therefore it may be difficult to categorize and confine it with a few sentences.
# ('It', 'PRP', 403, 405, 1, 3, 'O')
# It should be presented with  examples from different places around the world, related to people with completely different cultural backgrounds.
# ('It', 'PRP', 706, 708, 1, 6, 'O')
# It changed the face of the world in a very positive way.
# ('their', 'PRP$', 1182, 1187, 10, 11, 'O')
# Scientists, writers who are killed violently because of their opinion should be given as examples to illustrate the danger when one overtakes another's freedom of expression.
# ('they', 'PRP', 1623, 1627, 17, 15, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# There should be no judgements on peoples' opinions based purely on which religion or culture they belong to.
# ('them', 'PRP', 1735, 1739, 7, 17, 'O')
# Every day newspapers are full of them, and I think a professor will have no difficulty to show students a few facts illustrating the examples of inequality.
# 871631.txt
#
# ('they', 'PRP', 96, 100, 17, 0, 'O')
# I'm agree with the following statement: most advertisements make products seem much better then they really are.We can separe two kinds of advertisements: those direct to products, and those direct to persons.
# ('they', 'PRP', 356, 360, 11, 2, 'O')
# Teelling about the advertisements that make products much better than they really are, we can give a lots of examples: colorants in foods, pesticides in vegetable or fruits, etc.Many people  think that a beautiful products is better than a unlikely product.
# ('It', 'PRP', 544, 546, 1, 3, 'O')
# It isn't true.
# ('its', 'PRP$', 646, 649, 18, 4, 'O')
# In fact the produces use the advertisements for sell a product than cannot be sell for its apparence; but this not means that the produtc is good.
# ('it', 'PRP', 766, 768, 6, 6, 'O')
# Nowadays,in fact, it is widesprerad the use of the chilurgie plastic for seem much beatiful or young whose the person really is.
# 913996.txt
#
# ('it', 'PRP', 152, 154, 2, 2, 'O')
# Is it better for me, for the others, for society as a whole?
# ('it', 'PRP', 490, 492, 17, 5, 'O')
# The first  argument is that if a society values knowledge, and ours does, then it should realize that the pursuit of knowledge is fostered by intense research in areas that become by necessity the object of further and further specialization.
# ('it', 'PRP', 697, 699, 9, 6, 'O')
# To increase our knowledge about things, be it nature, or the social realm, or just abstract math, we need researchers to constantly go beyond what they already know.
# ('they', 'PRP', 801, 805, 30, 6, 'O')
# To increase our knowledge about things, be it nature, or the social realm, or just abstract math, we need researchers to constantly go beyond what they already know.
# ('It', 'PRP', 820, 822, 1, 7, 'O')
# It is only by being at the forefront of a given discipline that we can gain more knowledge about it.
# ('it', 'PRP', 917, 919, 20, 7, 'O')
# It is only by being at the forefront of a given discipline that we can gain more knowledge about it.
# ('it', 'PRP', 1154, 1156, 12, 9, 'O')
# We use knowledge in order to satisfy an objective, be it the improvement of our societies, or of our health, or whatever it is we want to improve.
# ('it', 'PRP', 1221, 1223, 26, 9, 'O')
# We use knowledge in order to satisfy an objective, be it the improvement of our societies, or of our health, or whatever it is we want to improve.
# ('they', 'PRP', 2070, 2074, 12, 16, 'O')
# That said, individuals should be interested in areas in which they are not specialized, because thirst of knowledge is part of being human and it makes our societies richer in variety and more interesting.
# ('it', 'PRP', 2151, 2153, 27, 16, 'O')
# That said, individuals should be interested in areas in which they are not specialized, because thirst of knowledge is part of being human and it makes our societies richer in variety and more interesting.
# 937403.txt
#
# ('they', 'PRP', 344, 348, 39, 3, 'O')
# In my opinion, if you are successful in your job, in your career, in you social life is because you have been developing some skills and situations that you already control and you know that they work.
# ('it', 'PRP', 590, 592, 22, 6, 'O')
# I would never try something new or risky in order to be more brave if I do not know for sure it will end successfully.
# ('they', 'PRP', 675, 679, 14, 7, 'O')
# Those  who take risks to "try" to find success is because they have nothing to loose.
# ('it', 'PRP', 763, 765, 13, 8, 'O')
# For instance, imagine I had a business and for any reason it just failed.
# ('it', 'PRP', 1360, 1362, 29, 15, 'O')
# I have never done an apiceptomy (open the gum and cut the root) and I would never try to do one without the appropiate training as it can be dangerous for the patient.
# ('it', 'PRP', 1613, 1615, 3, 18, 'O')
# Look for it!
# 990384.txt
#
# ('it', 'PRP', 146, 148, 7, 1, 'O')
# More people are using cars as it is easy to own a car today and many low cost cars are coming into the depending on demand of people ans usage.
# ('their', 'PRP$', 480, 485, 11, 3, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# So after few years many people would require cars for their personal use.
# ('them', 'PRP', 649, 653, 29, 4, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Now the number of cars are less becuase becuase big car companies donot go into remote places and villages to sell the cars as many people dont buy them.
# ('they', 'PRP', 665, 669, 3, 5, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# In future they might go into remote places in order to increase their sales.
# ('their', 'PRP$', 719, 724, 13, 5, 'O')
# In future they might go into remote places in order to increase their sales.
# ('they', 'PRP', 790, 794, 11, 6, 'O')
# This is not possible today for many car companies because they dont have many funds to do provide cars and market them in villages.
# ('them', 'PRP', 846, 850, 22, 6, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# This is not possible today for many car companies because they dont have many funds to do provide cars and market them in villages.
# ('their', 'PRP$', 1314, 1319, 5, 11, 'O')
# Car companies are increasing their production day by day in order to get more profits and the company will prosper.
# ('They', 'PRP', 1402, 1406, 1, 12, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# They are increasing their production seeing the increaing demand in the market.
# ('their', 'PRP$', 1422, 1427, 4, 12, 'O')
# MORE THAN ONE POSSIBLE ANTECEDENT IN PREVIOUS SENTENCE
# They are increasing their production seeing the increaing demand in the market.
# ('it', 'PRP', 1825, 1827, 12, 15, 'O')
# Many banks and financial companies are bringing out plans so that it is easy for a person to earn a car.
# ('it', 'PRP', 1918, 1920, 12, 16, 'O')
# This plan will increase the number of cars on road as it is no longer a burden to own a car.
# ('their', 'PRP$', 2185, 2190, 18, 18, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# Growth in technology and ways of manufacturing cars are bringing out many cars which are advancement to their previous models.
# ('it', 'PRP', 2231, 2233, 5, 19, 'O')
# Through all this means it will increase the number of cars in the near future.
# ('it', 'PRP', 2344, 2346, 2, 21, 'O')
# Now it  is not like that as owning a car is a passion and even desire to some people.
# ('they', 'PRP', 2871, 2875, 20, 24, 'O')
# POSSIBLE AMBIGUITY, 3 OR MORE NOUNS
# So with all these reasons I dont think that number of cars after twenty years will come down but they will increase in number and increase in varities satisfying wide range of people using it.
# ('it', 'PRP', 2963, 2965, 35, 24, 'O')
# So with all these reasons I dont think that number of cars after twenty years will come down but they will increase in number and increase in varities satisfying wide range of people using it.

# %%
xx = get_sentence_indexes(constituency_parse(parser, current_essay, return_parse_obj=True))

# %%
xx
# Out:
# [(0, 0, 1),
#  (1, 116, 119),
#  (2, 149, 155),
#  (3, 278, 282),
#  (4, 403, 410),
#  (5, 556, 564),
#  (6, 653, 658),
#  (7, 840, 842),
#  (8, 960, 963),
#  (9, 1090, 1094)]

# %%
xx[0]['tokens'][0]['characterOffsetBegin']
# Out:
# 0

# %%
xx[0]['tokens'][len(xx[0]['tokens'])-1]['characterOffsetEnd']
# Out:
# 115

# %%
current_essay[0:115]
# Out:
# "A geat challenge in a person's life span is his abbility to change to a better life where life is all about change."

# %%
tag_set
# Out:
#        filename                                              essay  \
# 0   1004355.txt  This is an important aspect of today time.\nTh...
# 1   1007363.txt  A geat challenge in a person's life span is hi...
# 2   1079196.txt  Personally, I agree with the statement saying ...
# 3   1086343.txt  In many country  their are many combanies of a...
# 4   1096747.txt  I disagree with this idea. in order to make a ...
# 5   1109085.txt  People often argue about what is more importan...
# 6   1164913.txt  Some tipes of advertisements use to make diffe...
# 7   1174920.txt  In my opinion people always should try new thi...
# 8   1181356.txt  We grow up in a society wich a has the mith of...
# 9   1223368.txt  Universities have considerably different educa...
# 10  1239289.txt  It is believed that young people nowadays do n...
# 11  1249928.txt  In my openion, I really disagree with make the...
# 12  1321982.txt  Of curse it is very important for students to ...
# 13  1346734.txt  Nowdays people use advertisement  to show thei...
# 14  1365003.txt  I concede that in some respects, the young sho...
# 15  1388870.txt  Some people want to try new things while other...
# 16  1392946.txt  Nowadays a lot of people like to take riks and...
# 17  1394540.txt  In the last fifty years the number of cars in ...
# 18  1414676.txt  In my opinion the usage of cars will stay at a...
# 19  1431839.txt  I completely agree with the statement 'most ad...
# 20  1447041.txt  I'm fully agreed that we should have broad kno...
# 21  1449555.txt  The issue at hand is whether advertisements ma...
# 22  1453563.txt  In a students' life, good learning is by study...
# 23  1469088.txt  Some people says that there will be fewer cars...
# 24  1599482.txt  To answer the question, if most advertisements...
# 25  1604419.txt  all of the worled intersting young people , bu...
# 26   162639.txt  In my personal opinion, it is true that most o...
# 27  1648484.txt  Most advertisements make products seem much be...
# 28  1691426.txt  when it comes to the statement of whether a pe...
# 29  1693042.txt  Young people enjoy life more than older people...
# ..          ...                                                ...
# 70   496928.txt  I'm agree with  "Young people nowdays do not g...
# 71   526827.txt  I think that is better to have broad knowledge...
# 72    52951.txt  With the different state between young people ...
# 73   535573.txt  Some people might believe that Learning the fa...
# 74   562823.txt  Products seem much better than they really are...
# 75   586583.txt  It is important for students to understand teo...
# 76   589458.txt  Advertising seems to has became a business tec...
# 77   594970.txt  In general I agree with this statement. The ta...
# 78   599905.txt  I do agree with the statement that young peopl...
# 79   609558.txt  I believe with the statement that "Young peopl...
# 80   618384.txt  It is admitted that the optimization of alread...
# 81   643139.txt  I disagree with the following statement which ...
# 82   644250.txt  Nobody can prodict the future but in mine opoi...
# 83   656695.txt  The very task and eventually also the goal of ...
# 84   661830.txt  I did not agree the following statement. I thi...
# 85    67346.txt  For my part, I do not think that young people ...
# 86   711394.txt  The use of cars has increased rapidly over the...
# 87    71654.txt  I dont believe that in twenty years there will...
# 88   716766.txt  Advertisements have become an important factor...
# 89   746257.txt  In fact some people think  that after twenty y...
# 90   749940.txt  I think less and less young people nowadays ta...
# 91   755753.txt  STUDENTS SHOULD RELY IN FACTS \n\t\t\tAND NOT ...
# 92   757891.txt  Many of us are eager to become successful peop...
# 93   806909.txt  Media has played a major role in Globalization...
# 94   832751.txt  Advertisements are everywhere.They can randoml...
# 95   844996.txt  I agree that that it is more difficult to assi...
# 96   871631.txt  I'm agree with the following statement: most a...
# 97   913996.txt  I disagree with the prior statement for severa...
# 98   937403.txt  Find the success\n\nWho is successful nowadays...
# 99   990384.txt  I dont think that in twenty years ther will be...
#
#                                                   pos  \
# 0   [[(This, DT, 0, 4, 1, 0, O), (is, VBZ, 5, 7, 2...
# 1   [[(A, DT, 0, 1, 1, 0, O), (geat, JJ, 2, 6, 2, ...
# 2   [[(Personally, RB, 0, 10, 1, 0, O), (,, ,, 10,...
# 3   [[(In, IN, 0, 2, 1, 0, O), (many, JJ, 3, 7, 2,...
# 4   [[(I, PRP, 0, 1, 1, 0, O), (disagree, VBP, 2, ...
# 5   [[(People, NNS, 0, 6, 1, 0, O), (often, RB, 7,...
# 6   [[(Some, DT, 0, 4, 1, 0, O), (tipes, NNS, 5, 1...
# 7   [[(In, IN, 0, 2, 1, 0, O), (my, PRP$, 3, 5, 2,...
# 8   [[(We, PRP, 0, 2, 1, 0, O), (grow, VBP, 3, 7, ...
# 9   [[(Universities, NNS, 0, 12, 1, 0, O), (have, ...
# 10  [[(It, PRP, 0, 2, 1, 0, O), (is, VBZ, 3, 5, 2,...
# 11  [[(In, IN, 0, 2, 1, 0, O), (my, PRP$, 3, 5, 2,...
# 12  [[(Of, IN, 0, 2, 1, 0, O), (curse, NN, 3, 8, 2...
# 13  [[(Nowdays, NNP, 0, 7, 1, 0, O), (people, NNS,...
# 14  [[(I, PRP, 0, 1, 1, 0, O), (concede, VBP, 2, 9...
# 15  [[(Some, DT, 0, 4, 1, 0, O), (people, NNS, 5, ...
# 16  [[(Nowadays, RB, 0, 8, 1, 0, O), (a, DT, 9, 10...
# 17  [[(In, IN, 0, 2, 1, 0, O), (the, DT, 3, 6, 2, ...
# 18  [[(In, IN, 0, 2, 1, 0, O), (my, PRP$, 3, 5, 2,...
# 19  [[(I, PRP, 0, 1, 1, 0, O), (completely, RB, 2,...
# 20  [[(I, PRP, 0, 1, 1, 0, O), ('m, VBP, 1, 3, 2, ...
# 21  [[(The, DT, 0, 3, 1, 0, O), (issue, NN, 4, 9, ...
# 22  [[(In, IN, 0, 2, 1, 0, O), (a, DT, 3, 4, 2, 0,...
# 23  [[(Some, DT, 0, 4, 1, 0, O), (people, NNS, 5, ...
# 24  [[(To, TO, 0, 2, 1, 0, O), (answer, VB, 3, 9, ...
# 25  [[(all, DT, 0, 3, 1, 0, O), (of, IN, 4, 6, 2, ...
# 26  [[(In, IN, 0, 2, 1, 0, O), (my, PRP$, 3, 5, 2,...
# 27  [[(Most, JJS, 0, 4, 1, 0, O), (advertisements,...
# 28  [[(when, WRB, 0, 4, 1, 0, O), (it, PRP, 5, 7, ...
# 29  [[(Young, JJ, 0, 5, 1, 0, O), (people, NNS, 6,...
# ..                                                ...
# 70  [[(I, PRP, 0, 1, 1, 0, O), ('m, VBP, 1, 3, 2, ...
# 71  [[(I, PRP, 0, 1, 1, 0, O), (think, VBP, 2, 7, ...
# 72  [[(With, IN, 0, 4, 1, 0, O), (the, DT, 5, 8, 2...
# 73  [[(Some, DT, 0, 4, 1, 0, O), (people, NNS, 5, ...
# 74  [[(Products, NNPS, 0, 8, 1, 0, O), (seem, VBP,...
# 75  [[(It, PRP, 0, 2, 1, 0, O), (is, VBZ, 3, 5, 2,...
# 76  [[(Advertising, NN, 0, 11, 1, 0, O), (seems, V...
# 77  [[(In, IN, 0, 2, 1, 0, O), (general, JJ, 3, 10...
# 78  [[(I, PRP, 0, 1, 1, 0, O), (do, VBP, 2, 4, 2, ...
# 79  [[(I, PRP, 0, 1, 1, 0, O), (believe, VBP, 2, 9...
# 80  [[(It, PRP, 0, 2, 1, 0, O), (is, VBZ, 3, 5, 2,...
# 81  [[(I, PRP, 0, 1, 1, 0, O), (disagree, VBP, 2, ...
# 82  [[(Nobody, NN, 0, 6, 1, 0, O), (can, MD, 7, 10...
# 83  [[(The, DT, 0, 3, 1, 0, O), (very, RB, 4, 8, 2...
# 84  [[(I, PRP, 0, 1, 1, 0, O), (did, VBD, 2, 5, 2,...
# 85  [[(For, IN, 0, 3, 1, 0, O), (my, PRP$, 4, 6, 2...
# 86  [[(The, DT, 0, 3, 1, 0, O), (use, NN, 4, 7, 2,...
# 87  [[(I, PRP, 0, 1, 1, 0, O), (dont, VBP, 2, 6, 2...
# 88  [[(Advertisements, NNS, 0, 14, 1, 0, O), (have...
# 89  [[(In, IN, 0, 2, 1, 0, O), (fact, NN, 3, 7, 2,...
# 90  [[(I, PRP, 0, 1, 1, 0, O), (think, VBP, 2, 7, ...
# 91  [[(STUDENTS, NNS, 0, 8, 1, 0, O), (SHOULD, MD,...
# 92  [[(Many, JJ, 0, 4, 1, 0, O), (of, IN, 5, 7, 2,...
# 93  [[(Media, NNP, 0, 5, 1, 0, O), (has, VBZ, 6, 9...
# 94  [[(Advertisements, NNS, 0, 14, 1, 0, O), (are,...
# 95  [[(I, PRP, 0, 1, 1, 0, O), (agree, VBP, 2, 7, ...
# 96  [[(I, PRP, 0, 1, 1, 0, O), ('m, VBP, 1, 3, 2, ...
# 97  [[(I, PRP, 0, 1, 1, 0, O), (disagree, VBP, 2, ...
# 98  [[(Find, VB, 0, 4, 1, 0, O), (the, DT, 5, 8, 2...
# 99  [[(I, PRP, 0, 1, 1, 0, O), (dont, VBP, 2, 6, 2...
#
#                                       sentece_indexes  \
# 0   [(0, 0, 42), (1, 43, 236), (2, 237, 359), (3, ...
# 1   [(0, 0, 115), (1, 116, 148), (2, 149, 277), (3...
# 2   [(0, 0, 123), (1, 125, 191), (2, 192, 365), (3...
# 3   [(0, 0, 66), (1, 67, 113), (2, 115, 223), (3, ...
# 4   [(0, 0, 26), (1, 27, 137), (2, 138, 217), (3, ...
# 5   [(0, 0, 100), (1, 101, 242), (2, 243, 326), (3...
# 6   [(0, 0, 149), (1, 151, 171), (2, 172, 190), (3...
# 7   [(0, 0, 162), (1, 163, 337), (2, 338, 560), (3...
# 8   [(0, 0, 61), (1, 63, 193), (2, 195, 275), (3, ...
# 9   [(0, 0, 61), (1, 62, 179), (2, 180, 318), (3, ...
# 10  [(0, 0, 100), (1, 101, 197), (2, 199, 321), (3...
# 11  [(0, 0, 165), (1, 169, 266), (2, 267, 352), (3...
# 12                        [(0, 0, 96), (1, 97, 1061)]
# 13  [(0, 0, 136), (1, 137, 215), (2, 216, 261), (3...
# 14  [(0, 0, 109), (1, 110, 297), (2, 303, 385), (3...
# 15  [(0, 0, 104), (1, 106, 231), (2, 233, 267), (3...
# 16  [(0, 0, 68), (1, 69, 110), (2, 111, 228), (3, ...
# 17  [(0, 0, 132), (1, 133, 296), (2, 297, 470), (3...
# 18  [(0, 0, 77), (1, 78, 237), (2, 239, 371), (3, ...
# 19  [(0, 0, 112), (1, 113, 177), (2, 179, 268), (3...
# 20  [(0, 0, 123), (1, 124, 235), (2, 245, 365), (3...
# 21  [(0, 0, 98), (1, 99, 199), (2, 200, 278), (3, ...
# 22  [(0, 0, 69), (1, 70, 158), (2, 159, 291), (3, ...
# 23  [(0, 0, 144), (1, 145, 347), (2, 348, 562), (3...
# 24  [(0, 0, 129), (1, 130, 361), (2, 362, 424), (3...
# 25        [(0, 0, 143), (1, 144, 321), (2, 322, 448)]
# 26  [(0, 0, 127), (1, 128, 190), (2, 191, 298), (3...
# 27  [(0, 0, 72), (1, 73, 187), (2, 188, 309), (3, ...
# 28  [(0, 0, 222), (1, 223, 294), (2, 300, 418), (3...
# 29  [(0, 0, 50), (1, 51, 120), (2, 121, 241), (3, ...
# ..                                                ...
# 70  [(0, 0, 93), (1, 94, 147), (2, 149, 204), (3, ...
# 71  [(0, 0, 109), (1, 110, 176), (2, 177, 234), (3...
# 72  [(0, 0, 121), (1, 122, 232), (2, 233, 342), (3...
# 73  [(0, 0, 80), (1, 81, 230), (2, 231, 307), (3, ...
# 74  [(0, 0, 47), (1, 48, 160), (2, 161, 251), (3, ...
# 75  [(0, 0, 170), (1, 171, 308), (2, 309, 446), (3...
# 76  [(0, 0, 146), (1, 147, 276), (2, 284, 573), (3...
# 77  [(0, 0, 39), (1, 40, 165), (2, 166, 329), (3, ...
# 78  [(0, 0, 93), (1, 94, 212), (2, 213, 320), (3, ...
# 79  [(0, 0, 112), (1, 113, 287), (2, 288, 340), (3...
# 80  [(0, 0, 83), (1, 84, 220), (2, 223, 318), (3, ...
# 81  [(0, 0, 145), (1, 146, 189), (2, 194, 309), (3...
# 82  [(0, 0, 148), (1, 149, 341), (2, 346, 575), (3...
# 83  [(0, 0, 190), (1, 191, 378), (2, 379, 541), (3...
# 84  [(0, 0, 40), (1, 41, 94), (2, 95, 156), (3, 15...
# 85  [(0, 0, 80), (1, 81, 177), (2, 180, 250), (3, ...
# 86  [(0, 0, 62), (1, 63, 125), (2, 126, 225), (3, ...
# 87  [(0, 0, 89), (1, 90, 121), (2, 148, 224), (3, ...
# 88  [(0, 0, 89), (1, 90, 188), (2, 189, 256), (3, ...
# 89  [(0, 0, 105), (1, 106, 215), (2, 217, 320), (3...
# 90  [(0, 0, 181), (1, 183, 308), (2, 309, 444), (3...
# 91  [(0, 0, 167), (1, 168, 255), (2, 256, 313), (3...
# 92  [(0, 0, 49), (1, 50, 116), (2, 117, 183), (3, ...
# 93  [(0, 0, 47), (1, 49, 165), (2, 166, 234), (3, ...
# 94  [(0, 0, 148), (1, 149, 298), (2, 299, 432), (3...
# 95  [(0, 0, 106), (1, 107, 231), (2, 234, 402), (3...
# 96  [(0, 0, 209), (1, 210, 285), (2, 286, 543), (3...
# 97  [(0, 0, 56), (1, 57, 148), (2, 149, 209), (3, ...
# 98  [(0, 0, 45), (1, 46, 75), (2, 77, 151), (3, 15...
# 99  [(0, 0, 115), (1, 116, 259), (2, 260, 425), (3...
#
#                                 third_person_pronouns  coherence_errors
# 0                                                  []                 0
# 1   [(his, PRP$, 44, 47, 11, 0, O), (them, PRP, 62...                 0
# 2   [(they, PRP, 107, 111, 18, 0, O), (their, PRP$...                 1
# 3   [(their, PRP$, 17, 22, 4, 0, O), (their, PRP$,...                 1
# 4   [(they, PRP, 114, 118, 20, 1, O), (they, PRP, ...                 1
# 5   [(it, PRP, 176, 178, 16, 1, O), (their, PRP$, ...                 0
# 6   [(them, PRP, 74, 78, 15, 0, O), (it, PRP, 91, ...                 1
# 7   [(themselves, PRP, 102, 112, 18, 0, O), (they,...                 1
# 8   [(it, PRP, 410, 412, 8, 4, O), (it, PRP, 632, ...                 0
# 9   [(it, PRP, 295, 297, 20, 2, O), (them, PRP, 31...                 3
# 10  [(It, PRP, 0, 2, 1, 0, O), (their, PRP$, 82, 8...                 2
# 11  [(they, PRP, 78, 82, 16, 0, O), (it, PRP, 102,...                 2
# 12  [(it, PRP, 9, 11, 3, 0, O), (they, PRP, 254, 2...                 1
# 13  [(their, PRP$, 42, 47, 7, 0, O), (it, PRP, 77,...                 0
# 14  [(their, PRP$, 64, 69, 13, 0, O), (they, PRP, ...                 4
# 15  [(they, PRP, 74, 78, 16, 0, O), (their, PRP$, ...                 3
# 16  [(their, PRP$, 52, 57, 12, 0, O), (their, PRP$...                 2
# 17  [(his, PRP$, 214, 217, 15, 1, O), (their, PRP$...                 0
# 18             [(their, PRP$, 1787, 1792, 13, 19, O)]                 0
# 19  [(they, PRP, 95, 99, 16, 0, O), (they, PRP, 42...                 0
# 20  [(it, PRP, 163, 165, 9, 1, O), (it, PRP, 1104,...                 0
# 21  [(they, PRP, 75, 79, 13, 0, O), (they, PRP, 26...                 0
# 22  [(his, PRP$, 113, 116, 10, 1, O), (his, PRP$, ...                 0
# 23  [(they, PRP, 426, 430, 12, 2, O), (their, PRP$...                 2
# 24  [(they, PRP, 78, 82, 14, 0, O), (them, PRP, 19...                 1
# 25  [(him, PRP, 264, 267, 24, 1, O), (his, PRP$, 4...                 0
# 26  [(it, PRP, 24, 26, 6, 0, O), (their, PRP$, 109...                 3
# 27  [(they, PRP, 56, 60, 9, 0, O), (their, PRP$, 1...                 0
# 28  [(it, PRP, 5, 7, 2, 0, O), (their, PRP$, 82, 8...                 1
# 29  [(its, PRP$, 171, 174, 10, 2, O), (his, PRP$, ...                 0
# ..                                                ...               ...
# 70  [(their, PRP$, 74, 79, 16, 0, O), (it, PRP, 19...                 0
# 71                  [(them, PRP, 351, 355, 20, 3, O)]                 0
# 72  [(they, PRP, 74, 78, 14, 0, O), (they, PRP, 30...                 3
# 73  [(it, PRP, 128, 130, 9, 1, O), (it, PRP, 200, ...                 0
# 74  [(they, PRP, 31, 35, 6, 0, O), (their, PRP$, 1...                 0
# 75  [(It, PRP, 0, 2, 1, 0, O), (they, PRP, 93, 97,...                 0
# 76  [(they, PRP, 788, 792, 18, 4, O), (them, PRP, ...                 1
# 77  [(they, PRP, 237, 241, 13, 2, O), (his, PRP$, ...                 1
# 78  [(their, PRP$, 343, 348, 5, 3, O), (they, PRP,...                 1
# 79  [(their, PRP$, 93, 98, 18, 0, O), (their, PRP$...                 5
# 80  [(It, PRP, 0, 2, 1, 0, O), (it, PRP, 347, 349,...                 0
# 81  [(it, PRP, 115, 117, 19, 0, O), (them, PRP, 12...                 3
# 82  [(its, PRP$, 242, 245, 17, 1, O), (they, PRP, ...                 0
# 83  [(it, PRP, 64, 66, 12, 0, O), (it, PRP, 118, 1...                 2
# 84  [(They, PRP, 421, 425, 1, 6, O), (they, PRP, 4...                 0
# 85  [(their, PRP$, 52, 57, 13, 0, O), (their, PRP$...                 3
# 86  [(his, PRP$, 85, 88, 4, 1, O), (their, PRP$, 4...                 1
# 87  [(their, PRP$, 250, 255, 7, 3, O), (They, PRP,...                 1
# 88  [(it, PRP, 185, 187, 21, 1, O), (its, PRP$, 41...                 0
# 89  [(them, PRP, 114, 118, 3, 1, O), (they, PRP, 3...                 3
# 90  [(their, PRP$, 62, 67, 13, 0, O), (they, PRP, ...                 0
# 91  [(his, PRP$, 369, 372, 12, 3, O), (it, PRP, 42...                 0
# 92  [(They, PRP, 117, 121, 1, 2, O), (His, PRP$, 3...                 2
# 93  [(It, PRP, 49, 51, 1, 1, O), (its, PRP$, 289, ...                 2
# 94  [(them, PRP, 260, 264, 25, 1, O), (it, PRP, 36...                 3
# 95  [(it, PRP, 18, 20, 5, 0, O), (it, PRP, 103, 10...                 1
# 96  [(they, PRP, 96, 100, 17, 0, O), (they, PRP, 3...                 0
# 97  [(it, PRP, 152, 154, 2, 2, O), (it, PRP, 490, ...                 0
# 98  [(they, PRP, 344, 348, 39, 3, O), (it, PRP, 59...                 0
# 99  [(it, PRP, 146, 148, 7, 1, O), (their, PRP$, 4...                 6
#
# [100 rows x 6 columns]

# %%
humans = pd.DataFrame()
no_humans = pd.DataFrame()
referencing_singular_pos = ['NN', 'NNP']
humans_list = list()
no_humans_list = list()
human_syn_list = list()
no_human_syn_list = list()
for y_pos in tag_set['pos']:
    for s_pos in y_pos:
        for x_pos in s_pos:
            if x_pos[1] in referencing_singular_pos:
                #print(x_pos[0])
                tags_result = is_animate(x_pos[0])
                human_tags = set(['professional','person','adult'])
                actual_tags = set(tags_result)
                inter = human_tags.intersection(actual_tags)
                if bool(inter):
                    if x_pos[0] not in humans_list:
                        humans_list.append(x_pos[0])
                        human_syn_list.append(tags_result)
                else:
                    if x_pos[0] not in no_humans_list:
                        no_humans_list.append(x_pos[0])
                        no_human_syn_list.append(tags_result)
humans['word'] =  humans_list
humans['categories'] = human_syn_list

no_humans['word'] =  no_humans_list
no_humans['categories'] = no_human_syn_list
humans.to_csv('D:/UIC/Spring 2018/NLP/humans.csv', index=False)
no_humans.to_csv('D:/UIC/Spring 2018/NLP/no_humans.csv', index=False)

# %%
is_animate('Barbara')
# Out:
# []
